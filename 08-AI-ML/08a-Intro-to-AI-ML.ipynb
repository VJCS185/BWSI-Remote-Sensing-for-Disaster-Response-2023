# %% [markdown]
# # Intro to Machine Learning
# We're going to be working with CAP imagery for the second half of this week. Recall the two main guiding questions for this week:
# - _What_ is in an image (e.g. debris, buildings, etc.)?
# - _Where_ are these things located _in 3D space_ ?
#
# ## Motivation
#
# We've already seen how structure from motion can begin to answer the second of those questions, at least in a coarse manner. The first question is more difficult than the second for one crucial reason: it (so far) can not be answered *solely* using image data. Recall that structure from motion was able to leverage image metadata, features and geometric constraints without having to insert any "outside" data. When detecting the components of an image, there is a certain amount of subjectivity that so far requires human input. For example, if you want to detect flooding in an image, there need to be some set of rules that the software can determine "if (rules are satisfied), then (flooding = True)".
#
# How can you start to tackle this problem? We're going to make the problem a bit simpler by turning it into a classification problem rather than a localization problem. That is, instead of finding where flooding is in an image, we'll find whether there is flooding at all. With that in mind, let's first try a naive approach and see if we can simply enumerate the rules. Let's look at some flooding images:
#
# <img src="notebook_images/010_1282_99809b0c-fc64-46e5-957f-7ff8e7547d8c.jpg" width="500"  />
#
# <img src="notebook_images/DSC_0655_0cbbe7e5-be24-4274-bf5a-664c6f2dc3e1.jpg" width="500"  />
#
# So what do we see? It looks like flooding is this murky, brown color that covers most of the image. So let's make a rule: if some percentage of the image is this brownish color (you can think of detecting this by creating some sort of index, like you did with the satellite imagery), there is flooding in the image. This might work for the two images we saw, but the real test is seeing if it works with other images. So let's look at another one:
#
# <img src="notebook_images/DSC_8218_7bb15c80-481b-411a-a54a-a36e9d8b6098.jpg" width="500"  />
#
# This image has a large percentage of it covered by brownish looking water. However, it's clearly not flooding, but rather just a lake. No problem, let's just make another rule: if some percentage of the image is this brownish color *and* there are also lots of buildings (let's also make an index for that), there is flooding in the image. Let's see if this works:
#
# <img src="notebook_images/DSC_8192_fe6812cd-c985-4e59-a62c-04a883ec42cc.jpg" width="500"  />
#
# Again, this is just some lake (the same lake as before, in fact). At this point, we might be thinking of shifting our strategy a bit. Clearly having someone sit down and enumerate all of the rules is impractical in this case\*. There is simply too much variability in the images to come up with a set of rules that is remotely generalizable.
#
# This is one of the major motivations of machine learning. The idea is that, rather than enumerate the rules that determine flooding, we're going to just enumerate the outcomes (e.g. whether there is flooding or not) and develop algorithms for the computer to *learn* what the rules are. There is a rich literature (and a host of undergraduate and graduate courses) on how these algorithms are designed, but on these next couple of days we will instead focus on how to interpret and implement them.
#
# \* This isn't to say that enumerating the rules isn't practical in *every* case. It really depends on the characteristics of the data.

# %% [markdown]
# ## A simple case study
#
# We're going to start with a simple dataset. We will use the  Breast Cancer Wisconsin (Diagnostic) Data Set (https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+(Diagnostic)), a dataset that shows whether a tumor is benign or malign and various other features.

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.datasets import load_breast_cancer
import re # regular expressions, part of standard python library

# read the dataframe
df = load_breast_cancer(return_X_y=False, as_frame=True)["data"]
df["target"] = load_breast_cancer(return_X_y=False, as_frame=True)["target"] # benign is 1, malign is 0
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness
# 0          17.99         10.38          122.80     1001.0          0.11840  \
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry
# 0             0.27760         0.30010              0.14710         0.2419  \
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst texture  worst perimeter  worst area
# 0                   0.07871  ...          17.33           184.60      2019.0  \
# 1                   0.05667  ...          23.41           158.80      1956.0
# 2                   0.05999  ...          25.53           152.50      1709.0
# 3                   0.09744  ...          26.50            98.87       567.7
# 4                   0.05883  ...          16.67           152.20      1575.0
# ..                      ...  ...            ...              ...         ...
# 564                 0.05623  ...          26.40           166.10      2027.0
# 565                 0.05533  ...          38.25           155.00      1731.0
# 566                 0.05648  ...          34.12           126.70      1124.0
# 567                 0.07016  ...          39.42           184.60      1821.0
# 568                 0.05884  ...          30.37            59.16       268.6
#
#      worst smoothness  worst compactness  worst concavity
# 0             0.16220            0.66560           0.7119  \
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      worst concave points  worst symmetry  worst fractal dimension  target
# 0                  0.2654          0.4601                  0.11890       0
# 1                  0.1860          0.2750                  0.08902       0
# 2                  0.2430          0.3613                  0.08758       0
# 3                  0.2575          0.6638                  0.17300       0
# 4                  0.1625          0.2364                  0.07678       0
# ..                    ...             ...                      ...     ...
# 564                0.2216          0.2060                  0.07115       0
# 565                0.1628          0.2572                  0.06637       0
# 566                0.1418          0.2218                  0.07820       0
# 567                0.2650          0.4087                  0.12400       0
# 568                0.0000          0.2871                  0.07039       1
#
# [569 rows x 31 columns]

# %%
# for now we're just going to focus on mean radius and mean texture.
# we'll plot one against the other, and color code depending on survival
df_b = df[df["target"] == 1]
df_m = df[df["target"] == 0]

# plotting
plt.plot(df_b["mean radius"], df_b["mean texture"], "bo")
plt.plot(df_m["mean radius"], df_m["mean texture"], "ro")
plt.xlabel("mean radius")
plt.ylabel("mean texture")
plt.show()

# %% [markdown]
# So what do we see? Clearly there are factors beyond the ones plotted that explain whether a tumor is benign. However, it's not difficult to see a pattern here. The further up and to the right you are, the less likely you are to survive. So as a first attempt, we will have the software learn a *linear classifier*. This classifier will be a line that will classify you as benign if you are below the line, and malign otherwise.

# %%
from sklearn import svm
from sklearn.model_selection import train_test_split
try:
    from mlxtend.plotting import plot_decision_regions
except:
    # !pip install mlxtend
    from mlxtend.plotting import plot_decision_regions

# setting the features and the targets
X = df[["mean radius", "mean texture"]]
y = df["target"]

# splitting training and testing set 80/20
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Initialize SVM classifier
classifier = svm.SVC(kernel='linear')

# Fit data
classifier = classifier.fit(X_train, y_train)

# Printing parameters
coef = classifier.coef_
print(coef)

# Plot decision boundary
plot_decision_regions(X_train.values, y_train.values.astype(np.integer), clf=classifier, legend=2)
plt.xlabel("mean radius")
plt.ylabel("mean texture")
plt.show()
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.22.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 19.2 MB/s eta 0:00:0000:010:01
# Requirement already satisfied: scikit-learn>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from mlxtend) (1.2.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from mlxtend) (3.7.1)
# Requirement already satisfied: scipy>=1.2.1 in /opt/conda/lib/python3.10/site-packages (from mlxtend) (1.10.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from mlxtend) (67.6.1)
# Requirement already satisfied: joblib>=0.13.2 in /opt/conda/lib/python3.10/site-packages (from mlxtend) (1.2.0)
# Requirement already satisfied: numpy>=1.16.2 in /opt/conda/lib/python3.10/site-packages (from mlxtend) (1.23.5)
# Requirement already satisfied: pandas>=0.24.2 in /opt/conda/lib/python3.10/site-packages (from mlxtend) (2.0.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (4.39.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (23.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=1.0.2->mlxtend) (3.1.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.22.0
# [[-0.75308692 -0.12875609]]
# /tmp/ipykernel_226/357811201.py:27: DeprecationWarning: Converting `np.integer` or `np.signedinteger` to a dtype is deprecated. The current result is `np.dtype(np.int_)` which is not strictly correct. Note that the result depends on the system. To ensure stable results use may want to use `np.int64` or `np.int32`.
#   plot_decision_regions(X_train.values, y_train.values.astype(np.integer), clf=classifier, legend=2)
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %% [markdown]
# There is a lot going on here, so let's try to break it down. Recall that we are trying to determine whether a patient survives using just the (normalized) age and detected nodes. These are called the explanatory variables or *features*, and we refer to it as $X$. The variable we are trying to predict is the prediction variable or *target*, and we refer to it as $y$.
#
# The underlying notion behind machine learning is that patterns that hold in a subset of data will hold in the population as a whole. So in a sense, we care about the performance of the classifier on data that the algorithm has *not* seen by learning patterns in that data that we have seen. To this end, one of the major paradigms in machine learning is to separate our data into a *training set* and a *testing set*. The training set is a subset of the given data that we will actually provide to the algorithm to learn, while the testing set will be used solely to report the performance on data that the algorithm has not seen. In our case, we set 80% of the data as training data and 20% as testing data.
#
# There are numerous algorithms that can train on data. One of the more popular ones (especially before neural networks were introduced) are called *support vector machines* (SVM). We will not discuss how it actually does the learning, but suffice to say it takes in the training data and finds the line that minimizes the classification error. This line is called the *decision boundary* and it is defined by the following equation:
#
# \begin{equation}
# C_1(mean\ radius) + C_2(mean\ texture) = 0
# \end{equation}
#
# Where $C_1$ and $C_2$ are the coefficients of the linear classifier. So really, the function of the SVM is to find these two coefficients. The algorithm then does classification as follows:
#
# \begin{equation}
# y_{pred} =
# \begin{cases}
#     1               & \text{if } C_1(mean\ radius) + C_2(mean\ texture)\geq 0\\
#     0,              & \text{otherwise}
# \end{cases}
# \end{equation}
#
# ### Exercise
# - Look at the first 5 samples in the testing data set. Calculate the predicted target of each of the 5 samples?
# - Look at the corresponding targets. Are the predictions accurate? What proportion of the predicted values are correctly predicted?
# - Which of the two coefficients is most important? Why?

# %% [markdown]
# How good is our classifier? We can look at the performance of our classifier on the testing set to find out. Of course, an important metric to look out for is the accuracy:
#
# \begin{equation}
# \text{Accuracy} = \frac{\#\ (y_{true} == y_{pred})}{\# \ \text{samples}}
# \end{equation}
#
# However, for most applications it is also worth understanding what your *false positive* and *false negative* rate is. A false positive is a sample that is classified as a 1 but is in reality a 0, and a false negative is the opposite\*. The false positive rate is defined as $\frac{\# \text{False positives}}{\# \ \text{False positives + True negatives}}$, while the false negative rate is defined as $\frac{\# \text{False negatives}}{\# \ \text{False negatives + True positives}}$. **Why would this be a metric we care about, especially in this case?**
#
# <details>
#     <summary>ANSWER</summary>
#     Imagine your tumor is predicted as malignant but is in fact benign. There is certainly now a cost you incur in further tests or surgeries, but ultimately it is a manageable cost. Now imagine if you predicted a tumor as benign even thoguh it is malignant. Here, the mistake of the classifier could certainly cost you your life.
# </details>
#
# It turns out there is a useful tool called a *confusion matrix* that handily lays it out for you.
#
# \* It's worth putting some effort into what we call positives and negatives. Here, we use the term positive to mean 1 (benign) and negative to mean 0 (malign). However, anyone that has had a test of any sort knows that positive usually means that you have the disease (in our case, malign tumor). A lot of data science is communicating results, so something worth thinking about.

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

predictions = classifier.predict(X_test)
accuracy = np.sum(predictions == y_test)/np.size(predictions)
print(accuracy)

cm = confusion_matrix(y_test, predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=['malignant', 'benign'])

disp.plot()
plt.show()
# Out:
# 0.8859649122807017

# %% [markdown]
# As a final note, we used two variables (radius and texture) because it made it possible to visualize. However, there is nothing preventing us from using the rest of the data set columns as part of our features. While visualization in more than 2D is much more difficult, the underlying principles are exactly the same.

# %% [markdown]
# ## Deep learning
# So far, we've worked exclusively with linear decision boundaries. However, usually data is much more complicated (as you should have seen from the exercise). Therefore, we might want to look for something that has higher predictive power. One of the most popular tools in machine learning has been the *neural network*. A neural network is (loosely) inspired by the way neurons are connected and operate. Let's first look at the simplest possible neural network and work our way up:
#
# <img src="notebook_images/nn_nohidden_new.png" width="500"  />
#
# Neural networks are made up of *layers*. In the image above, the neural network has two layers. The first layer is called the *input layer*, and the last layer is called the *output layer*. Each layer is composed of *neurons*. In the input layer, each neuron is one of the features from the training data. For example, the first neuron might be the mean radius, and the second neuron might be the mean texture. We're going to refer to each neuron by $x_{l, n}$, where $l$ is the number of the layer and $n$ is the number of the neuron within the layer. Using this notation, mean radius = $x_{1, 1}$.
#
# Each neuron in the input layer is connected to *every* neuron in the following layer by a *weight*. We will denote each weight by $w_{l, i, o}$, where $l$ is the layer at the tail of the arrow, $i$ is the number of the neuron at the tail of the arrow and $o$ is the number of the neuron at the head of the arrow. In the figure above, the color of the arrow corresponds to the value of the weight (blue means negative, red means positive). Every neuron in subsequent layers is equal to the sum of the products of the neurons and the weight that connects them. In this case, the neuron in the output layer is defined as:
#
# \begin{equation}
# x_{2, 1} = x_{1, 1}w_{1, 1, 1} + x_{1, 2}w_{1, 2, 1}
# \end{equation}
#
# Once you have the value of the output layer, you can obtain the predicted classification by applying some function to $x_{2, 1}$. An example of such a function would be similar to what we did previously:
#
# \begin{equation}
# y_{pred} =
# \begin{cases}
#     1               & \text{if } x_{2, 1}\geq 0\\
#     0,              & \text{otherwise}
# \end{cases}
# \end{equation}
#
# So training a neural network is simply finding the weights $w$ that minimize the error. If you are keen-eyed though, you might have realized that the example above is identical to what we were doing before. Therefore, we still have not arrived at a more powerful classifier. Let's try a more complicated neural network.
#
# <img src="notebook_images/nn_hidden_new.png" width="500"  />
#
# This network is similar to the previous one, but now we have an additional layer in between the input and output layers. All layers that are between input and output are called *hidden layers*, though functionally they behave in exactly the same way. As a quick concept question, **what is the value of $x_{2, 3}$? What about $x_{3, 1}$?**
#
# <details>
#     <summary>ANSWER</summary>
#     $x_{2, 3} = x_{1, 1}w_{1, 1, 3} + x_{1, 2}w_{1, 2, 3}$ ,
#     $x_{3, 1} = x_{2, 1}w_{2, 1, 1} + x_{2, 2}w_{2, 2, 1} + x_{2, 3}w_{2, 3, 1} + x_{2, 4}w_{2, 4, 1} + x_{2, 5}w_{2, 5, 1}$
# </details>
#
# Why are we introducing a hidden layer? Notice that each of the neurons in the hidden layer are essentially acting as linear classifiers. By having a weighted sum of these neurons in the output layer, we are arriving at a function that, by virtue of being a sum of lines is not itself linear. One of the biggest results in machine learning is that, as you increase the number of neurons in the hidden layer, you can approximate *any* function, meaning that you can always make a more powerful classifier by just adding more neurons. However, usually this is not computationally efficient. Rather, most of the time it makes more sense to introduce more hidden layers as opposed to more neurons, as shown in the image below:
#
# <img src="notebook_images/nn_deep.png" width="500"  />
#
# The added "depth" as a result of more layers is where the "deep" in "deep learning" comes. As computational resources have increased, scientists have increasingly resorted to adding more and more layers to their neural networks.
#
# ### Discussion questions
# Let's start thinking about the LADI dataset. We want to use deep learning to detect whether there is flooding in the image.
# - Using the paradigm above, what would be the features of the dataset? What are the targets?
# - Propose a way that you would input the features into a neural network?
# - What problems might you run into if you directly put an image into the neural network above?

# %% [markdown]
# ## Convolution
# Convolution is a fairly old technique in image processing. Convolution works by multiplying a matrix (called a *kernel*) with portions of the image and adding up the result. An animation of how this works is shown below. The result of applying different kernels is also shown:
#
# <img src="notebook_images/convolution_anim.gif" width="500"  />
#
# <img src="notebook_images/convolution.png" width="500"  />
#
# As you can see, different kernels can pick up different features depending on the specific coefficients of the kernel. In the late 1980s, scientists first thought to use neural networks to learn the kernel values themselves, which created the foundation for the *convolutional* neural network (CNN). These complement the hidden layers from the previous architecture with new convolutional layers, which perform convolution on the previous layer. In so doing, these networks conserve the relationship between nearby pixels and perform very well in image classification.
#
# <img src="notebook_images/cnn.png" width="500"  />

# %% [markdown]
# ## The LADI dataset
# The LADI dataset contains CAP images as well as crowdsourced labels for a number of different categories. Today we're going to start the multi-day exercise of applying deep learning to the LADI dataset in order to do classification of flooding. This section borrows heavily from the following tutorial: https://github.com/LADI-Dataset/ladi-tutorial
#
# ### Data reading and cleaning
# We first have to go through some work to make sure that we only have the components of the dataset that we want.

# %%
# read the tsv file with the labels
ladi_responses_raw = pd.read_csv("http://ladi.s3-us-west-2.amazonaws.com/Labels/ladi_aggregated_responses_url.tsv",delimiter='\t',header='infer')
ladi_responses_raw
# Out:
#                                                       url  WorkerId
# 0       https://ladi.s3-us-west-2.amazonaws.com/Images...         0  \
# 1       https://ladi.s3-us-west-2.amazonaws.com/Images...         1
# 2       https://ladi.s3-us-west-2.amazonaws.com/Images...         2
# 3       https://ladi.s3-us-west-2.amazonaws.com/Images...        20
# 4       https://ladi.s3-us-west-2.amazonaws.com/Images...         0
# ...                                                   ...       ...
# 289835  https://ladi.s3-us-west-2.amazonaws.com/Images...       488
# 289836  https://ladi.s3-us-west-2.amazonaws.com/Images...       496
# 289837  https://ladi.s3-us-west-2.amazonaws.com/Images...       516
# 289838  https://ladi.s3-us-west-2.amazonaws.com/Images...       539
# 289839  https://ladi.s3-us-west-2.amazonaws.com/Images...       539
#
#                         Answer
# 0       ['damage:flood/water']
# 1       ['damage:flood/water']
# 2       ['damage:flood/water']
# 3       ['damage:flood/water']
# 4       ['damage:flood/water']
# ...                        ...
# 289835         ['damage:none']
# 289836         ['damage:none']
# 289837         ['damage:misc']
# 289838         ['damage:none']
# 289839         ['damage:none']
#
# [289840 rows x 3 columns]

# %%
# remove square brackets, split on comma and explode list into individual rows, then merge back with original to get url and WorkerId
ladi_responses = pd.merge(ladi_responses_raw[['url','WorkerId']], 
                          ladi_responses_raw['Answer'].str.strip('[|]').str.split(',').explode(), 
                          left_index=True, 
                          right_index=True).reset_index(drop=True)
# remove whitespace and the single quote character from either end of string
ladi_responses['Answer'] = ladi_responses['Answer'].str.strip(' ').str.strip('\'')
# add a column to help with aggregation when pivoting
ladi_responses['response_count'] = 1
# get the category of each response
ladi_responses['Category'] = ladi_responses['Answer'].str.split(':').apply(lambda x: x[0])
# drop dupes
ladi_responses = ladi_responses.drop_duplicates(ignore_index=True)
ladi_responses
# Out:
#                                                       url  WorkerId
# 0       https://ladi.s3-us-west-2.amazonaws.com/Images...         0  \
# 1       https://ladi.s3-us-west-2.amazonaws.com/Images...         1
# 2       https://ladi.s3-us-west-2.amazonaws.com/Images...         2
# 3       https://ladi.s3-us-west-2.amazonaws.com/Images...        20
# 4       https://ladi.s3-us-west-2.amazonaws.com/Images...         0
# ...                                                   ...       ...
# 394697  https://ladi.s3-us-west-2.amazonaws.com/Images...       488
# 394698  https://ladi.s3-us-west-2.amazonaws.com/Images...       496
# 394699  https://ladi.s3-us-west-2.amazonaws.com/Images...       516
# 394700  https://ladi.s3-us-west-2.amazonaws.com/Images...       539
# 394701  https://ladi.s3-us-west-2.amazonaws.com/Images...       539
#
#                     Answer  response_count Category
# 0       damage:flood/water               1   damage
# 1       damage:flood/water               1   damage
# 2       damage:flood/water               1   damage
# 3       damage:flood/water               1   damage
# 4       damage:flood/water               1   damage
# ...                    ...             ...      ...
# 394697         damage:none               1   damage
# 394698         damage:none               1   damage
# 394699         damage:misc               1   damage
# 394700         damage:none               1   damage
# 394701         damage:none               1   damage
#
# [394702 rows x 5 columns]

# %%
#figure out the total number of responses in each category
# take one entry for each worker, category, url combination, and then create pivot table from it
category_matrix = ladi_responses.groupby(['WorkerId','Category','url'])\
                                .first()\
                                .reset_index()\
                                .pivot_table(values='response_count', 
                                          index='url', 
                                          columns='Category', 
                                          aggfunc='sum',
                                          fill_value=0)
category_matrix
# Out:
# Category                                            damage  environment
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...       6            0  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...       5            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...       3            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...       3            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...       3            3
# ...                                                    ...          ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...       6            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...       8            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...       3            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...       5            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...       6            0
#
# Category                                            infrastructure  vehicle
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0        0  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0        0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0        0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0        0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               3        3
# ...                                                            ...      ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0        0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0        0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0        0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0        0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0        0
#
# Category                                            water
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...      0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...      0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...      0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...      0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...      3
# ...                                                   ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...      0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...      0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...      0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...      0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...      0
#
# [40197 rows x 5 columns]

# %%
# Create a matrix with the number of workers who answered given label for given image
# using pivot table; filling in nan values with 0
label_matrix = ladi_responses.pivot_table(values='response_count', 
                                          index='url', 
                                          columns='Answer', 
                                          aggfunc='sum',
                                          fill_value=0)
label_matrix
# Out:
# Answer                                              damage:flood/water
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                   2  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                   3
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                   1
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                   2
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                   2
# ...                                                                ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                   3
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                   1
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                   0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                   1
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                   2
#
# Answer                                              damage:landslide
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# ...                                                              ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 2
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 2
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 1
#
# Answer                                              damage:misc  damage:none
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0            4  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0            2
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0            2
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0            1
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0            1
# ...                                                         ...          ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            3            2
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            1            5
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            1            2
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            1            2
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            1            3
#
# Answer                                              damage:rubble
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# ...                                                           ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              2
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              1
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              1
#
# Answer                                              damage:smoke/fire
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# ...                                                               ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
#
# Answer                                              damage:washout
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# ...                                                            ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               1
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               1
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               1
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               1
#
# Answer                                              environment:dirt
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# ...                                                              ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0
#
# Answer                                              environment:grass
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# ...                                                               ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                  0
#
# Answer                                              environment:lava  ...
# url                                                                   ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0  ...  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0  ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0  ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0  ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0  ...
# ...                                                              ...  ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0  ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0  ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0  ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0  ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0  ...
#
# Answer                                              vehicle:boat  vehicle:car
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0            0  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0            3
# ...                                                          ...          ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0            0
#
# Answer                                              vehicle:none
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0
# ...                                                          ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...             0
#
# Answer                                              vehicle:truck
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              1
# ...                                                           ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...              0
#
# Answer                                              water:flooding
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               3
# ...                                                            ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...               0
#
# Answer                                              water:lake  water:none
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...           0           0  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...           0           0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...           0           0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...           0           0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...           0           0
# ...                                                        ...         ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...           0           0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...           0           0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...           0           0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...           0           0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...           0           0
#
# Answer                                              water:ocean  water:puddle
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0             0  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0             0
# ...                                                         ...           ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0             0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0             0
#
# Answer                                              water:river
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0
# ...                                                         ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0
#
# [40197 rows x 37 columns]

# %%
# create dataframes with percentage of responses that included that label
cat_frac_dfs = {}
for cat in category_matrix.columns:
    frac_df = pd.DataFrame(index=category_matrix.index)
    for label in label_matrix.columns[label_matrix.columns.str.match(cat)]:
        frac_df[label] = (label_matrix[label]/category_matrix[cat])
    cat_frac_dfs[cat] = frac_df.fillna(0)

# %%
def get_training_examples(cat_frac_dfs, category, label, max_samples=5000):
    '''gets the files for a given category and label where the majority of workers said that the label was present
    use max_samples to limit the number of examples
    '''
    if re.search('none', label):
        sample_df = pd.DataFrame(index=cat_frac_dfs[category].loc[cat_frac_dfs[category][label]>0.5].index)
    else:
        sample_df = pd.DataFrame(index=cat_frac_dfs[category].loc[cat_frac_dfs[category][label]>=0.5].index, data={label:1})
    if len(sample_df) > max_samples:
        sample_df = sample_df.sample(max_samples)
    return sample_df

def convert_url_to_local_path(url):
    '''
    converts the url to the location where we will download
    '''
    return url.lstrip('https://')

# %%
# get positive examples for each label of interest
flood_examples = get_training_examples(cat_frac_dfs, 'damage', 'damage:flood/water', 100)
rubble_examples = get_training_examples(cat_frac_dfs, 'damage', 'damage:rubble', 100)
misc_damage_examples = get_training_examples(cat_frac_dfs, 'damage', 'damage:misc', 100)
no_damage_examples = get_training_examples(cat_frac_dfs, 'damage', 'damage:none', 100)

# %%
# combine entries entries into single dataframe, group by url, and convert labels to 1-hot vector
damage_df = pd.concat([flood_examples, 
                       rubble_examples,
                       misc_damage_examples,
                       no_damage_examples
                      ]).fillna(0).reset_index().groupby('url').max()
damage_df['local_path'] = damage_df.reset_index()['url'].apply(convert_url_to_local_path).values
damage_df.to_csv('damage_examples.csv')
damage_df
# Out:
#                                                     damage:flood/water
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 1.0  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 1.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 1.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 1.0
# ...                                                                ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 1.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...                 0.0
#
#                                                     damage:rubble
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0.0  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0.0
# ...                                                           ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...            0.0
#
#                                                     damage:misc
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...          0.0  \
# https://ladi.s3-us-west-2.amazonaws.com/Images/...          0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...          0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...          0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...          0.0
# ...                                                         ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...          0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...          0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...          0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...          0.0
# https://ladi.s3-us-west-2.amazonaws.com/Images/...          0.0
#
#                                                                                            local_path
# url
# https://ladi.s3-us-west-2.amazonaws.com/Images/...  ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...  ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...  ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...  ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...  ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# ...                                                                                               ...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...  ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...  ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...  ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...  ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
# https://ladi.s3-us-west-2.amazonaws.com/Images/...  ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CA...
#
# [398 rows x 4 columns]

# %%
# create a csv of all the files we want to download as training data to feed into wget
damage_df.reset_index()['url'].to_csv('urls_to_download.csv', index=False, header=False)

# %%
# Load ladi_images_metadata.csv
metadata_df = pd.read_csv('http://ladi.s3-us-west-2.amazonaws.com/Labels/ladi_images_metadata.csv')
metadata_df
# Out:
#                                             uuid            timestamp
# 0       a13fb353cca1f5e8060f95c80deb0c49e9a21f91  2016-01-16 07:34:55  \
# 1       03e5da2bc5e32cd7d58a164eefce499e2f14e06f  2014-06-24 13:09:20
# 2       c97e83122e14ec5fa5cfa6e2c911e066d8a07f7c  2014-06-24 11:06:27
# 3       c534eb158948b63508eab34a667bf495e129f455  2014-06-24 11:20:03
# 4       1c702459e21e5a7e7fec5eefaab42f5e5124113a  2014-06-24 11:21:07
# ...                                          ...                  ...
# 580746  95fabbdbbb494beab517b5fea25a4e430d8fbcef  2020-01-27 12:01:31
# 580747  4b590e5634dae396db6c838844d7670e5ef9e7f6  2020-01-27 12:00:25
# 580748  bb7f86f1e9ab1a1ab3ea9e13cda998ab6e1bbb6d  2020-01-27 12:02:25
# 580749  c9e5c19cb7cccf181d11b707f1a47b80341710b6  2020-01-27 12:00:45
# 580750  a52da08206e51e3cd3b2cd0b42a3bb7e9623e92c  2020-01-27 12:00:39
#
#           gps_lat    gps_lon  gps_alt  file_size   width  height
# 0       29.623744 -95.652153     26.0  3497125.0  4608.0  3456.0  \
# 1       32.386939 -86.344467    489.0  3518243.0  4608.0  3456.0
# 2             NaN        NaN      NaN  8006650.0  6000.0  4000.0
# 3             NaN        NaN      NaN  8821238.0  6000.0  4000.0
# 4       32.371777 -86.345887    459.0  8385536.0  6000.0  4000.0
# ...           ...        ...      ...        ...     ...     ...
# 580746  18.002950 -66.896370    101.8  3413576.0  4000.0  3000.0
# 580747  18.003440 -66.896118    101.8  3307879.0  4000.0  3000.0
# 580748  18.003280 -66.895955    101.8  3989427.0  4000.0  3000.0
# 580749  18.003355 -66.896257    101.8  3722615.0  4000.0  3000.0
# 580750  18.003379 -66.896208    101.8  3696682.0  4000.0  3000.0
#
#                                                   s3_path
# 0       s3://ladi/Images/FEMA_CAP/1012/20118/VIRB0002_...  \
# 1       s3://ladi/Images/FEMA_CAP/1012/20118/VIRB0820_...
# 2       s3://ladi/Images/FEMA_CAP/1012/20118/_DSC0015_...
# 3       s3://ladi/Images/FEMA_CAP/1012/20118/_DSC0123_...
# 4       s3://ladi/Images/FEMA_CAP/1012/20118/_DSC0126_...
# ...                                                   ...
# 580746  s3://ladi/Images/FEMA_CAP/9173/616637/2020_012...
# 580747  s3://ladi/Images/FEMA_CAP/9173/616637/2020_012...
# 580748  s3://ladi/Images/FEMA_CAP/9173/616637/2020_012...
# 580749  s3://ladi/Images/FEMA_CAP/9173/616637/2020_012...
# 580750  s3://ladi/Images/FEMA_CAP/9173/616637/2020_012...
#
#                                                       url
# 0       https://ladi.s3-us-west-2.amazonaws.com/Images...
# 1       https://ladi.s3-us-west-2.amazonaws.com/Images...
# 2       https://ladi.s3-us-west-2.amazonaws.com/Images...
# 3       https://ladi.s3-us-west-2.amazonaws.com/Images...
# 4       https://ladi.s3-us-west-2.amazonaws.com/Images...
# ...                                                   ...
# 580746  https://ladi.s3-us-west-2.amazonaws.com/Images...
# 580747  https://ladi.s3-us-west-2.amazonaws.com/Images...
# 580748  https://ladi.s3-us-west-2.amazonaws.com/Images...
# 580749  https://ladi.s3-us-west-2.amazonaws.com/Images...
# 580750  https://ladi.s3-us-west-2.amazonaws.com/Images...
#
# [580751 rows x 10 columns]

# %%
#download the examples to folder
# !wget --content-disposition --trust-server-names -i urls_to_download.csv -x
# Out:
# --2023-07-27 18:05:37--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20165/CAP_1762_8d546ecc-9f20-41e0-bd2c-932f126cb57e.jpg
# Resolving ladi.s3-us-west-2.amazonaws.com (ladi.s3-us-west-2.amazonaws.com)... 52.92.197.90, 3.5.78.193, 52.92.240.130, ...
# Connecting to ladi.s3-us-west-2.amazonaws.com (ladi.s3-us-west-2.amazonaws.com)|52.92.197.90|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13137598 (13M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20165/CAP_1762_8d546ecc-9f20-41e0-bd2c-932f126cb57e.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  12.53M  32.2MB/s    in 0.4s
#
# 2023-07-27 18:05:37 (32.2 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20165/CAP_1762_8d546ecc-9f20-41e0-bd2c-932f126cb57e.jpg’ saved [13137598/13137598]
#
# --2023-07-27 18:05:37--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20173/16-1-337_6c1b2b65-b95d-47c2-953c-3c4d76c91f72.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6473577 (6.2M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20173/16-1-337_6c1b2b65-b95d-47c2-953c-3c4d76c91f72.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.17M  --.-KB/s    in 0.09s
#
# 2023-07-27 18:05:38 (66.5 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20173/16-1-337_6c1b2b65-b95d-47c2-953c-3c4d76c91f72.jpg’ saved [6473577/6473577]
#
# --2023-07-27 18:05:38--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20195/DSC_0455_b6d909f3-7516-4fc4-acd5-2b383f9824e7.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6432131 (6.1M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20195/DSC_0455_b6d909f3-7516-4fc4-acd5-2b383f9824e7.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.13M  38.2MB/s    in 0.2s
#
# 2023-07-27 18:05:38 (38.2 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20195/DSC_0455_b6d909f3-7516-4fc4-acd5-2b383f9824e7.jpg’ saved [6432131/6432131]
#
# --2023-07-27 18:05:38--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20195/DSC_0698_235ce330-16f0-4a05-9420-57341102ab78.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6546059 (6.2M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20195/DSC_0698_235ce330-16f0-4a05-9420-57341102ab78.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.24M  --.-KB/s    in 0.1s
#
# 2023-07-27 18:05:38 (60.2 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20195/DSC_0698_235ce330-16f0-4a05-9420-57341102ab78.jpg’ saved [6546059/6546059]
#
# --2023-07-27 18:05:38--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20199/DSC_0207_b25374ff-3973-48a3-9cb1-759a8b29d598.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 14199444 (14M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20199/DSC_0207_b25374ff-3973-48a3-9cb1-759a8b29d598.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  13.54M  43.0MB/s    in 0.3s
#
# 2023-07-27 18:05:39 (43.0 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20199/DSC_0207_b25374ff-3973-48a3-9cb1-759a8b29d598.jpg’ saved [14199444/14199444]
#
# --2023-07-27 18:05:39--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20253/DSC_0031_c69274ca-7578-44ec-86e1-3edd9832e58b.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6516036 (6.2M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20253/DSC_0031_c69274ca-7578-44ec-86e1-3edd9832e58b.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.21M  --.-KB/s    in 0.1s
#
# 2023-07-27 18:05:39 (42.0 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/1013/20253/DSC_0031_c69274ca-7578-44ec-86e1-3edd9832e58b.jpg’ saved [6516036/6516036]
#
# --2023-07-27 18:05:39--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2022/100454/Paincour_b078ff4d-339a-4901-9569-3cca21d8330e.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3485260 (3.3M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2022/100454/Paincour_b078ff4d-339a-4901-9569-3cca21d8330e.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   3.32M  --.-KB/s    in 0.01s
#
# 2023-07-27 18:05:39 (263 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2022/100454/Paincour_b078ff4d-339a-4901-9569-3cca21d8330e.jpg’ saved [3485260/3485260]
#
# --2023-07-27 18:05:39--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2024/221180/010_2634_f4218b8f-8114-450f-89c8-bfd817c63a4b.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 12778854 (12M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2024/221180/010_2634_f4218b8f-8114-450f-89c8-bfd817c63a4b.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  12.19M  21.9MB/s    in 0.6s
#
# 2023-07-27 18:05:40 (21.9 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/2024/221180/010_2634_f4218b8f-8114-450f-89c8-bfd817c63a4b.jpg’ saved [12778854/12778854]
#
# --2023-07-27 18:05:40--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3033/231175/CAPIberv_51471c35-2ff9-4ddc-8866-ff9815cb024c.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4713612 (4.5M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3033/231175/CAPIberv_51471c35-2ff9-4ddc-8866-ff9815cb024c.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   4.50M  25.5MB/s    in 0.2s
#
# 2023-07-27 18:05:40 (25.5 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3033/231175/CAPIberv_51471c35-2ff9-4ddc-8866-ff9815cb024c.jpg’ saved [4713612/4713612]
#
# --2023-07-27 18:05:40--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3041/241283/DSC_9565_347463b8-60ad-4f08-bd78-2225d3c0b085.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6571102 (6.3M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3041/241283/DSC_9565_347463b8-60ad-4f08-bd78-2225d3c0b085.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.27M  39.0MB/s    in 0.2s
#
# 2023-07-27 18:05:40 (39.0 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3041/241283/DSC_9565_347463b8-60ad-4f08-bd78-2225d3c0b085.jpg’ saved [6571102/6571102]
#
# --2023-07-27 18:05:40--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3041/241283/DSC_9572_90154404-64a1-49b9-9426-0526bd546ccd.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7056122 (6.7M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3041/241283/DSC_9572_90154404-64a1-49b9-9426-0526bd546ccd.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.73M  --.-KB/s    in 0.08s
#
# 2023-07-27 18:05:41 (82.2 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3041/241283/DSC_9572_90154404-64a1-49b9-9426-0526bd546ccd.jpg’ saved [7056122/7056122]
#
# --2023-07-27 18:05:41--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3041/241288/DSC_1582_a37d93da-6ae3-420d-84c3-055e91ffd1bf.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6151369 (5.9M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3041/241288/DSC_1582_a37d93da-6ae3-420d-84c3-055e91ffd1bf.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.87M  --.-KB/s    in 0.1s
#
# 2023-07-27 18:05:41 (46.5 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3041/241288/DSC_1582_a37d93da-6ae3-420d-84c3-055e91ffd1bf.jpg’ saved [6151369/6151369]
#
# --2023-07-27 18:05:41--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291483/VIRB0116_5016ad9f-bdea-4f29-9420-35bc7d6cc23a.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3507486 (3.3M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291483/VIRB0116_5016ad9f-bdea-4f29-9420-35bc7d6cc23a.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   3.34M  --.-KB/s    in 0.02s
#
# 2023-07-27 18:05:41 (183 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291483/VIRB0116_5016ad9f-bdea-4f29-9420-35bc7d6cc23a.jpg’ saved [3507486/3507486]
#
# --2023-07-27 18:05:41--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291497/DSC_0070_96deb74b-f5f3-4926-aec0-5c97ea28799b.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6920351 (6.6M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291497/DSC_0070_96deb74b-f5f3-4926-aec0-5c97ea28799b.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.60M  33.4MB/s    in 0.2s
#
# 2023-07-27 18:05:41 (33.4 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291497/DSC_0070_96deb74b-f5f3-4926-aec0-5c97ea28799b.jpg’ saved [6920351/6920351]
#
# --2023-07-27 18:05:41--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291501/DSC_0145_3cad623e-cff6-4b0b-9a6c-eb9bfb7468a2.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7344056 (7.0M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291501/DSC_0145_3cad623e-cff6-4b0b-9a6c-eb9bfb7468a2.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   7.00M  --.-KB/s    in 0.07s
#
# 2023-07-27 18:05:42 (104 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291501/DSC_0145_3cad623e-cff6-4b0b-9a6c-eb9bfb7468a2.jpg’ saved [7344056/7344056]
#
# --2023-07-27 18:05:42--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291501/DSC_0189_91bd0b50-4574-43dd-9f4a-dc2a59344b52.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5562182 (5.3M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291501/DSC_0189_91bd0b50-4574-43dd-9f4a-dc2a59344b52.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.30M  --.-KB/s    in 0.1s
#
# 2023-07-27 18:05:42 (37.9 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291501/DSC_0189_91bd0b50-4574-43dd-9f4a-dc2a59344b52.jpg’ saved [5562182/5562182]
#
# --2023-07-27 18:05:42--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291501/DSC_0226_fece5590-495a-4e1a-b900-c1147df2e980.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6775975 (6.5M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291501/DSC_0226_fece5590-495a-4e1a-b900-c1147df2e980.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.46M  --.-KB/s    in 0.1s
#
# 2023-07-27 18:05:42 (56.7 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291501/DSC_0226_fece5590-495a-4e1a-b900-c1147df2e980.jpg’ saved [6775975/6775975]
#
# --2023-07-27 18:05:42--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291505/DSC_1502_9b240a86-770e-4fd4-9d6d-8df8b6221b87.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9790179 (9.3M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291505/DSC_1502_9b240a86-770e-4fd4-9d6d-8df8b6221b87.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   9.34M  34.5MB/s    in 0.3s
#
# 2023-07-27 18:05:43 (34.5 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291505/DSC_1502_9b240a86-770e-4fd4-9d6d-8df8b6221b87.jpg’ saved [9790179/9790179]
#
# --2023-07-27 18:05:43--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291530/DSC_0782_36bdf79d-9d41-4b86-8bb9-83b637188519.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7393809 (7.1M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291530/DSC_0782_36bdf79d-9d41-4b86-8bb9-83b637188519.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   7.05M  --.-KB/s    in 0.05s
#
# 2023-07-27 18:05:43 (142 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291530/DSC_0782_36bdf79d-9d41-4b86-8bb9-83b637188519.jpg’ saved [7393809/7393809]
#
# --2023-07-27 18:05:43--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291547/DSC_2146_bb3f9466-aa92-4159-b01f-08e133677347.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7795334 (7.4M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291547/DSC_2146_bb3f9466-aa92-4159-b01f-08e133677347.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   7.43M  35.2MB/s    in 0.2s
#
# 2023-07-27 18:05:43 (35.2 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291547/DSC_2146_bb3f9466-aa92-4159-b01f-08e133677347.jpg’ saved [7795334/7795334]
#
# --2023-07-27 18:05:43--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291547/DSC_2389_a66a27a3-b18c-4445-879f-715e9f7cbe80.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10853039 (10M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291547/DSC_2389_a66a27a3-b18c-4445-879f-715e9f7cbe80.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  10.35M  18.1MB/s    in 0.6s
#
# 2023-07-27 18:05:44 (18.1 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3042/291547/DSC_2389_a66a27a3-b18c-4445-879f-715e9f7cbe80.jpg’ saved [10853039/10853039]
#
# --2023-07-27 18:05:44--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291554/DSC_0907_29a74c25-6eb4-442f-ae28-5d05035fbe66.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 14754482 (14M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291554/DSC_0907_29a74c25-6eb4-442f-ae28-5d05035fbe66.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  14.07M  23.6MB/s    in 0.6s
#
# 2023-07-27 18:05:45 (23.6 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291554/DSC_0907_29a74c25-6eb4-442f-ae28-5d05035fbe66.jpg’ saved [14754482/14754482]
#
# --2023-07-27 18:05:45--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291579/DSC_5101_d4c13923-3ddf-469c-8d66-29308b8458e9.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13073639 (12M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291579/DSC_5101_d4c13923-3ddf-469c-8d66-29308b8458e9.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  12.47M  23.4MB/s    in 0.5s
#
# 2023-07-27 18:05:45 (23.4 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291579/DSC_5101_d4c13923-3ddf-469c-8d66-29308b8458e9.jpg’ saved [13073639/13073639]
#
# --2023-07-27 18:05:45--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291579/DSC_5329_593af840-bd7b-48cc-a43c-c247425df502.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 12503796 (12M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291579/DSC_5329_593af840-bd7b-48cc-a43c-c247425df502.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  11.92M  44.7MB/s    in 0.3s
#
# 2023-07-27 18:05:46 (44.7 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291579/DSC_5329_593af840-bd7b-48cc-a43c-c247425df502.jpg’ saved [12503796/12503796]
#
# --2023-07-27 18:05:46--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291593/CAP_0571_d5b18065-3154-47ba-a299-17b6b95dd292.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10056923 (9.6M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291593/CAP_0571_d5b18065-3154-47ba-a299-17b6b95dd292.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   9.59M  30.0MB/s    in 0.3s
#
# 2023-07-27 18:05:46 (30.0 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291593/CAP_0571_d5b18065-3154-47ba-a299-17b6b95dd292.jpg’ saved [10056923/10056923]
#
# --2023-07-27 18:05:46--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291595/DSC_5605_adcfb5f7-0d61-4d88-a5d3-c617a585c489.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 12082646 (12M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291595/DSC_5605_adcfb5f7-0d61-4d88-a5d3-c617a585c489.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  11.52M  30.2MB/s    in 0.4s
#
# 2023-07-27 18:05:47 (30.2 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291595/DSC_5605_adcfb5f7-0d61-4d88-a5d3-c617a585c489.jpg’ saved [12082646/12082646]
#
# --2023-07-27 18:05:47--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291595/DSC_5696_fce420d4-bb02-402b-b904-cf5a24decdef.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10550954 (10M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291595/DSC_5696_fce420d4-bb02-402b-b904-cf5a24decdef.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  10.06M  23.9MB/s    in 0.4s
#
# 2023-07-27 18:05:48 (23.9 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291595/DSC_5696_fce420d4-bb02-402b-b904-cf5a24decdef.jpg’ saved [10550954/10550954]
#
# --2023-07-27 18:05:48--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291595/DSC_5845_d4f33330-ab15-43e0-89b1-49f997f72e79.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11720304 (11M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291595/DSC_5845_d4f33330-ab15-43e0-89b1-49f997f72e79.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  11.18M  23.1MB/s    in 0.5s
#
# 2023-07-27 18:05:48 (23.1 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291595/DSC_5845_d4f33330-ab15-43e0-89b1-49f997f72e79.jpg’ saved [11720304/11720304]
#
# --2023-07-27 18:05:48--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291610/DSC_0093_c40c57d2-b870-49b0-8aba-e577b3d9c1e0.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5859454 (5.6M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291610/DSC_0093_c40c57d2-b870-49b0-8aba-e577b3d9c1e0.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.59M  18.8MB/s    in 0.3s
#
# 2023-07-27 18:05:49 (18.8 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291610/DSC_0093_c40c57d2-b870-49b0-8aba-e577b3d9c1e0.jpg’ saved [5859454/5859454]
#
# --2023-07-27 18:05:49--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291611/DSC_0418_432bd1f8-ab20-4909-b49b-5d0b41391f61.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6609357 (6.3M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291611/DSC_0418_432bd1f8-ab20-4909-b49b-5d0b41391f61.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.30M  --.-KB/s    in 0.05s
#
# 2023-07-27 18:05:49 (131 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291611/DSC_0418_432bd1f8-ab20-4909-b49b-5d0b41391f61.jpg’ saved [6609357/6609357]
#
# --2023-07-27 18:05:49--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291616/DSC_0986_7273fe93-db70-4caf-b9c8-97dae5e1953f.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6400764 (6.1M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291616/DSC_0986_7273fe93-db70-4caf-b9c8-97dae5e1953f.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.10M  34.7MB/s    in 0.2s
#
# 2023-07-27 18:05:49 (34.7 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291616/DSC_0986_7273fe93-db70-4caf-b9c8-97dae5e1953f.jpg’ saved [6400764/6400764]
#
# --2023-07-27 18:05:49--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291618/DSC_7235_086d234f-de1f-455d-8930-f7ee2fa01aa9.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5705957 (5.4M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291618/DSC_7235_086d234f-de1f-455d-8930-f7ee2fa01aa9.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.44M  --.-KB/s    in 0.02s
#
# 2023-07-27 18:05:49 (280 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291618/DSC_7235_086d234f-de1f-455d-8930-f7ee2fa01aa9.jpg’ saved [5705957/5705957]
#
# --2023-07-27 18:05:49--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291619/DSC_0113_0b261542-bd5a-4855-bdb2-efb67ba2a4f3.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6143664 (5.9M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291619/DSC_0113_0b261542-bd5a-4855-bdb2-efb67ba2a4f3.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.86M  --.-KB/s    in 0.06s
#
# 2023-07-27 18:05:50 (95.6 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291619/DSC_0113_0b261542-bd5a-4855-bdb2-efb67ba2a4f3.jpg’ saved [6143664/6143664]
#
# --2023-07-27 18:05:50--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291619/DSC_0166_dc4bdd4d-9a7f-496a-b4cd-24917222e1e4.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6861916 (6.5M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291619/DSC_0166_dc4bdd4d-9a7f-496a-b4cd-24917222e1e4.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.54M  20.5MB/s    in 0.3s
#
# 2023-07-27 18:05:50 (20.5 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291619/DSC_0166_dc4bdd4d-9a7f-496a-b4cd-24917222e1e4.jpg’ saved [6861916/6861916]
#
# --2023-07-27 18:05:50--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291632/DSC_0279_5f2c7999-9cb5-40cd-89b0-5344ccac79c4.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6330546 (6.0M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291632/DSC_0279_5f2c7999-9cb5-40cd-89b0-5344ccac79c4.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.04M  36.8MB/s    in 0.2s
#
# 2023-07-27 18:05:50 (36.8 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291632/DSC_0279_5f2c7999-9cb5-40cd-89b0-5344ccac79c4.jpg’ saved [6330546/6330546]
#
# --2023-07-27 18:05:50--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291633/DSC_3712_56352327-9b68-4aaf-8eba-2635321dccdf.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6119441 (5.8M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291633/DSC_3712_56352327-9b68-4aaf-8eba-2635321dccdf.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.84M  31.1MB/s    in 0.2s
#
# 2023-07-27 18:05:51 (31.1 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291633/DSC_3712_56352327-9b68-4aaf-8eba-2635321dccdf.jpg’ saved [6119441/6119441]
#
# --2023-07-27 18:05:51--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291636/DSC_0157_20e9f5ea-7ff5-4f0f-bbe1-d6b03266332a.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6038037 (5.8M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291636/DSC_0157_20e9f5ea-7ff5-4f0f-bbe1-d6b03266332a.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.76M  --.-KB/s    in 0.1s
#
# 2023-07-27 18:05:51 (57.3 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291636/DSC_0157_20e9f5ea-7ff5-4f0f-bbe1-d6b03266332a.jpg’ saved [6038037/6038037]
#
# --2023-07-27 18:05:51--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291663/DSC_0340_a72d6d6b-7f4a-4eee-8695-0aea5a235620.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5048200 (4.8M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291663/DSC_0340_a72d6d6b-7f4a-4eee-8695-0aea5a235620.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   4.81M  --.-KB/s    in 0.08s
#
# 2023-07-27 18:05:51 (58.3 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3043/291663/DSC_0340_a72d6d6b-7f4a-4eee-8695-0aea5a235620.jpg’ saved [5048200/5048200]
#
# --2023-07-27 18:05:51--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291508/DSC_1319_2ea5e9e6-1387-4d0a-98ba-ffa35c2dabd2.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6396408 (6.1M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291508/DSC_1319_2ea5e9e6-1387-4d0a-98ba-ffa35c2dabd2.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.10M  18.6MB/s    in 0.3s
#
# 2023-07-27 18:05:52 (18.6 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291508/DSC_1319_2ea5e9e6-1387-4d0a-98ba-ffa35c2dabd2.jpg’ saved [6396408/6396408]
#
# --2023-07-27 18:05:52--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291543/DSC_2665_b942a8b4-085d-4120-9535-ddd6aa0162e5.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6308359 (6.0M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291543/DSC_2665_b942a8b4-085d-4120-9535-ddd6aa0162e5.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.02M  17.8MB/s    in 0.3s
#
# 2023-07-27 18:05:52 (17.8 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3045/291543/DSC_2665_b942a8b4-085d-4120-9535-ddd6aa0162e5.jpg’ saved [6308359/6308359]
#
# --2023-07-27 18:05:52--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3047/291526/CAP_0022_b0677225-398c-42dd-b8e6-ffedaaf33bcc.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6751416 (6.4M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3047/291526/CAP_0022_b0677225-398c-42dd-b8e6-ffedaaf33bcc.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.44M  35.5MB/s    in 0.2s
#
# 2023-07-27 18:05:53 (35.5 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/3047/291526/CAP_0022_b0677225-398c-42dd-b8e6-ffedaaf33bcc.jpg’ saved [6751416/6751416]
#
# --2023-07-27 18:05:53--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/583511/DSC_0071_dfd89d10-b471-4dfc-a6e2-0a6800f35ec5.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6895468 (6.6M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/583511/DSC_0071_dfd89d10-b471-4dfc-a6e2-0a6800f35ec5.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.58M  39.9MB/s    in 0.2s
#
# 2023-07-27 18:05:53 (39.9 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/583511/DSC_0071_dfd89d10-b471-4dfc-a6e2-0a6800f35ec5.jpg’ saved [6895468/6895468]
#
# --2023-07-27 18:05:53--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/614892/VIRB0154_f2871c17-d96d-4721-a430-66e29890742c.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4315350 (4.1M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/614892/VIRB0154_f2871c17-d96d-4721-a430-66e29890742c.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   4.12M  --.-KB/s    in 0.04s
#
# 2023-07-27 18:05:53 (109 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/614892/VIRB0154_f2871c17-d96d-4721-a430-66e29890742c.jpg’ saved [4315350/4315350]
#
# --2023-07-27 18:05:53--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/615428/VIRB0200_ced1649c-2a59-4be4-a649-6324c201b480.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3484781 (3.3M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/615428/VIRB0200_ced1649c-2a59-4be4-a649-6324c201b480.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   3.32M  18.1MB/s    in 0.2s
#
# 2023-07-27 18:05:53 (18.1 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/615428/VIRB0200_ced1649c-2a59-4be4-a649-6324c201b480.jpg’ saved [3484781/3484781]
#
# --2023-07-27 18:05:53--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/615428/VIRB0205_937a25ed-55f6-4962-9de9-fdfa327adb1d.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3566250 (3.4M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/615428/VIRB0205_937a25ed-55f6-4962-9de9-fdfa327adb1d.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   3.40M  --.-KB/s    in 0.1s
#
# 2023-07-27 18:05:54 (25.7 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/615428/VIRB0205_937a25ed-55f6-4962-9de9-fdfa327adb1d.jpg’ saved [3566250/3566250]
#
# --2023-07-27 18:05:54--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/615474/Dec17201_ea009398-e193-409c-9a99-2a271d9c1879.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5214219 (5.0M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/615474/Dec17201_ea009398-e193-409c-9a99-2a271d9c1879.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   4.97M  --.-KB/s    in 0.1s
#
# 2023-07-27 18:05:54 (36.1 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/5/615474/Dec17201_ea009398-e193-409c-9a99-2a271d9c1879.jpg’ saved [5214219/5214219]
#
# --2023-07-27 18:05:54--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/7068/615404/DSC_7852_c89e3bd6-46d6-4cf6-b59f-a8f44547b98d.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13045028 (12M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/7068/615404/DSC_7852_c89e3bd6-46d6-4cf6-b59f-a8f44547b98d.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  12.44M  25.7MB/s    in 0.5s
#
# 2023-07-27 18:05:55 (25.7 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/7068/615404/DSC_7852_c89e3bd6-46d6-4cf6-b59f-a8f44547b98d.jpg’ saved [13045028/13045028]
#
# --2023-07-27 18:05:55--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613531/DSC_0764_79e3bcff-77a0-47e4-bae3-bb2fb3e325e6.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11987163 (11M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613531/DSC_0764_79e3bcff-77a0-47e4-bae3-bb2fb3e325e6.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  11.43M  25.5MB/s    in 0.4s
#
# 2023-07-27 18:05:55 (25.5 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613531/DSC_0764_79e3bcff-77a0-47e4-bae3-bb2fb3e325e6.jpg’ saved [11987163/11987163]
#
# --2023-07-27 18:05:55--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613531/DSC_1911_83852853-4722-4687-a47d-7cd486106444.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11690704 (11M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613531/DSC_1911_83852853-4722-4687-a47d-7cd486106444.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  11.15M  23.9MB/s    in 0.5s
#
# 2023-07-27 18:05:56 (23.9 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613531/DSC_1911_83852853-4722-4687-a47d-7cd486106444.jpg’ saved [11690704/11690704]
#
# --2023-07-27 18:05:56--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613538/DSC_0891_535109f6-3c9d-4af2-96da-45cfbc2009c6.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 15415134 (15M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613538/DSC_0891_535109f6-3c9d-4af2-96da-45cfbc2009c6.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  14.70M  36.2MB/s    in 0.4s
#
# 2023-07-27 18:05:56 (36.2 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613538/DSC_0891_535109f6-3c9d-4af2-96da-45cfbc2009c6.jpg’ saved [15415134/15415134]
#
# --2023-07-27 18:05:56--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613538/DSC_1213_329d03b7-6aec-4ff4-9ad6-a76ebfd170b8.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 12097687 (12M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613538/DSC_1213_329d03b7-6aec-4ff4-9ad6-a76ebfd170b8.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  11.54M  30.2MB/s    in 0.4s
#
# 2023-07-27 18:05:57 (30.2 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613538/DSC_1213_329d03b7-6aec-4ff4-9ad6-a76ebfd170b8.jpg’ saved [12097687/12097687]
#
# --2023-07-27 18:05:57--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613538/DSC_1266_b10e0e73-ae87-4ea2-bde6-7f4daa671397.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 12894773 (12M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613538/DSC_1266_b10e0e73-ae87-4ea2-bde6-7f4daa671397.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  12.30M  23.4MB/s    in 0.5s
#
# 2023-07-27 18:05:58 (23.4 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613538/DSC_1266_b10e0e73-ae87-4ea2-bde6-7f4daa671397.jpg’ saved [12894773/12894773]
#
# --2023-07-27 18:05:58--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613546/DSC_0223_2ef80cfe-122c-4886-9f28-8526c2179b33.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9841860 (9.4M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613546/DSC_0223_2ef80cfe-122c-4886-9f28-8526c2179b33.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   9.39M  18.2MB/s    in 0.5s
#
# 2023-07-27 18:05:58 (18.2 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613546/DSC_0223_2ef80cfe-122c-4886-9f28-8526c2179b33.jpg’ saved [9841860/9841860]
#
# --2023-07-27 18:05:58--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613546/DSC_1011_34f22cc4-3be0-4d4a-86e8-1efc5184e56f.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7876741 (7.5M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613546/DSC_1011_34f22cc4-3be0-4d4a-86e8-1efc5184e56f.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   7.51M  37.4MB/s    in 0.2s
#
# 2023-07-27 18:05:59 (37.4 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613546/DSC_1011_34f22cc4-3be0-4d4a-86e8-1efc5184e56f.jpg’ saved [7876741/7876741]
#
# --2023-07-27 18:05:59--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_1122_addc7a37-0604-4e44-8ae0-f6546074e70f.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9493066 (9.1M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_1122_addc7a37-0604-4e44-8ae0-f6546074e70f.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   9.05M  41.6MB/s    in 0.2s
#
# 2023-07-27 18:05:59 (41.6 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_1122_addc7a37-0604-4e44-8ae0-f6546074e70f.jpg’ saved [9493066/9493066]
#
# --2023-07-27 18:05:59--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_3280_40a017aa-a8aa-40ff-9b22-b9f3f586270a.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10993709 (10M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_3280_40a017aa-a8aa-40ff-9b22-b9f3f586270a.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  10.48M  15.1MB/s    in 0.7s
#
# 2023-07-27 18:06:00 (15.1 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_3280_40a017aa-a8aa-40ff-9b22-b9f3f586270a.jpg’ saved [10993709/10993709]
#
# --2023-07-27 18:06:00--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_3618_29918321-477f-44ec-8fe8-04fe227c92e3.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10291256 (9.8M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_3618_29918321-477f-44ec-8fe8-04fe227c92e3.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   9.81M  22.8MB/s    in 0.4s
#
# 2023-07-27 18:06:00 (22.8 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613547/DSC_3618_29918321-477f-44ec-8fe8-04fe227c92e3.jpg’ saved [10291256/10291256]
#
# --2023-07-27 18:06:00--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613548/DSC_2048_3cca2ef3-91df-4809-8046-f186020056c8.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9585353 (9.1M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613548/DSC_2048_3cca2ef3-91df-4809-8046-f186020056c8.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   9.14M  27.9MB/s    in 0.3s
#
# 2023-07-27 18:06:01 (27.9 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613548/DSC_2048_3cca2ef3-91df-4809-8046-f186020056c8.jpg’ saved [9585353/9585353]
#
# --2023-07-27 18:06:01--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613549/DSC_1172_473ae6b1-f0b0-4fa7-9ae1-01674b135a3e.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11316091 (11M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613549/DSC_1172_473ae6b1-f0b0-4fa7-9ae1-01674b135a3e.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  10.79M  16.7MB/s    in 0.6s
#
# 2023-07-27 18:06:02 (16.7 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613549/DSC_1172_473ae6b1-f0b0-4fa7-9ae1-01674b135a3e.jpg’ saved [11316091/11316091]
#
# --2023-07-27 18:06:02--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613550/DSC_0132_96d990bc-e89c-4740-98a9-22cd5f6b8533.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11424308 (11M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613550/DSC_0132_96d990bc-e89c-4740-98a9-22cd5f6b8533.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  10.89M  35.6MB/s    in 0.3s
#
# 2023-07-27 18:06:02 (35.6 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613550/DSC_0132_96d990bc-e89c-4740-98a9-22cd5f6b8533.jpg’ saved [11424308/11424308]
#
# --2023-07-27 18:06:02--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613550/DSC_1184_6652b0f7-32fa-4f5b-8c18-fb3c4cecc3e2.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10696363 (10M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613550/DSC_1184_6652b0f7-32fa-4f5b-8c18-fb3c4cecc3e2.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  10.20M  25.4MB/s    in 0.4s
#
# 2023-07-27 18:06:03 (25.4 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613550/DSC_1184_6652b0f7-32fa-4f5b-8c18-fb3c4cecc3e2.jpg’ saved [10696363/10696363]
#
# --2023-07-27 18:06:03--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613551/DSC_1379_2515d999-9f7a-460b-8d21-a5797471f4f3.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 8832676 (8.4M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613551/DSC_1379_2515d999-9f7a-460b-8d21-a5797471f4f3.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   8.42M  --.-KB/s    in 0.1s
#
# 2023-07-27 18:06:03 (68.0 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613551/DSC_1379_2515d999-9f7a-460b-8d21-a5797471f4f3.jpg’ saved [8832676/8832676]
#
# --2023-07-27 18:06:03--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613555/DSC_0416_27ae17b8-2cbf-4e36-9a4d-f7ad6496dc6e.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11751294 (11M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613555/DSC_0416_27ae17b8-2cbf-4e36-9a4d-f7ad6496dc6e.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  11.21M  45.8MB/s    in 0.2s
#
# 2023-07-27 18:06:04 (45.8 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613555/DSC_0416_27ae17b8-2cbf-4e36-9a4d-f7ad6496dc6e.jpg’ saved [11751294/11751294]
#
# --2023-07-27 18:06:04--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613555/DSC_0553_1314e3bf-f2b5-41f5-b232-1caba436b248.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13637499 (13M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613555/DSC_0553_1314e3bf-f2b5-41f5-b232-1caba436b248.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  13.00M  27.1MB/s    in 0.5s
#
# 2023-07-27 18:06:04 (27.1 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613555/DSC_0553_1314e3bf-f2b5-41f5-b232-1caba436b248.jpg’ saved [13637499/13637499]
#
# --2023-07-27 18:06:04--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613556/DSC_0439_db7b321b-d51b-4598-be41-f05dcb8c3196.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9507161 (9.1M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613556/DSC_0439_db7b321b-d51b-4598-be41-f05dcb8c3196.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   9.07M  33.5MB/s    in 0.3s
#
# 2023-07-27 18:06:05 (33.5 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613556/DSC_0439_db7b321b-d51b-4598-be41-f05dcb8c3196.jpg’ saved [9507161/9507161]
#
# --2023-07-27 18:06:05--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613560/DSC_0491_68e808f3-0532-4b00-a720-d059edfc7fe4.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11601211 (11M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613560/DSC_0491_68e808f3-0532-4b00-a720-d059edfc7fe4.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  11.06M  20.2MB/s    in 0.5s
#
# 2023-07-27 18:06:05 (20.2 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613560/DSC_0491_68e808f3-0532-4b00-a720-d059edfc7fe4.jpg’ saved [11601211/11601211]
#
# --2023-07-27 18:06:05--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613560/DSC_0650_8b4d829a-b0a2-4861-97aa-4485f0e99dcc.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 12988820 (12M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613560/DSC_0650_8b4d829a-b0a2-4861-97aa-4485f0e99dcc.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  12.39M  22.5MB/s    in 0.6s
#
# 2023-07-27 18:06:06 (22.5 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613560/DSC_0650_8b4d829a-b0a2-4861-97aa-4485f0e99dcc.jpg’ saved [12988820/12988820]
#
# --2023-07-27 18:06:06--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613560/DSC_0672_13ce6ea8-6217-447b-8c6f-9b335626f0ff.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 12262747 (12M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613560/DSC_0672_13ce6ea8-6217-447b-8c6f-9b335626f0ff.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  11.69M  31.9MB/s    in 0.4s
#
# 2023-07-27 18:06:07 (31.9 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613560/DSC_0672_13ce6ea8-6217-447b-8c6f-9b335626f0ff.jpg’ saved [12262747/12262747]
#
# --2023-07-27 18:06:07--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613574/A67_0045_cf5c0339-53dd-4e4b-b4e7-ee0831cfc55d.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11097366 (11M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613574/A67_0045_cf5c0339-53dd-4e4b-b4e7-ee0831cfc55d.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  10.58M  42.8MB/s    in 0.2s
#
# 2023-07-27 18:06:07 (42.8 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613574/A67_0045_cf5c0339-53dd-4e4b-b4e7-ee0831cfc55d.jpg’ saved [11097366/11097366]
#
# --2023-07-27 18:06:07--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613574/A67_0090_864984f6-960b-42a3-bf41-c47cbc93d7ea.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 10425218 (9.9M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613574/A67_0090_864984f6-960b-42a3-bf41-c47cbc93d7ea.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   9.94M  36.7MB/s    in 0.3s
#
# 2023-07-27 18:06:08 (36.7 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613574/A67_0090_864984f6-960b-42a3-bf41-c47cbc93d7ea.jpg’ saved [10425218/10425218]
#
# --2023-07-27 18:06:08--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613574/A67_0423_548d5168-9b5d-40f9-adb0-4df1ac1f1cc1.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 12612338 (12M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613574/A67_0423_548d5168-9b5d-40f9-adb0-4df1ac1f1cc1.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  12.03M  50.9MB/s    in 0.2s
#
# 2023-07-27 18:06:08 (50.9 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613574/A67_0423_548d5168-9b5d-40f9-adb0-4df1ac1f1cc1.jpg’ saved [12612338/12612338]
#
# --2023-07-27 18:06:08--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9073/613574/A67_0458_661b8ea6-2b3d-4c22-8cbd-13625bfad27c.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# ...
# HTTP request sent, awaiting response... 200 OK
# Length: 5615232 (5.4M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615127/TimCooli_1b140164-f153-40b9-9526-7ad2aa99a457.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.35M  32.9MB/s    in 0.2s
#
# 2023-07-27 18:08:02 (32.9 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615127/TimCooli_1b140164-f153-40b9-9526-7ad2aa99a457.jpg’ saved [5615232/5615232]
#
# --2023-07-27 18:08:02--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615127/TimCooli_e227c0d0-115f-432c-95ec-8d97fe2795b6.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5810549 (5.5M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615127/TimCooli_e227c0d0-115f-432c-95ec-8d97fe2795b6.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.54M  35.0MB/s    in 0.2s
#
# 2023-07-27 18:08:02 (35.0 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615127/TimCooli_e227c0d0-115f-432c-95ec-8d97fe2795b6.jpg’ saved [5810549/5810549]
#
# --2023-07-27 18:08:02--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615132/JoeBell-_949a5727-8831-426c-93c5-ca438dc85ee1.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3515787 (3.4M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615132/JoeBell-_949a5727-8831-426c-93c5-ca438dc85ee1.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   3.35M  --.-KB/s    in 0.1s
#
# 2023-07-27 18:08:03 (23.2 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9096/615132/JoeBell-_949a5727-8831-426c-93c5-ca438dc85ee1.jpg’ saved [3515787/3515787]
#
# --2023-07-27 18:08:03--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615138/DSC_7274_8660a940-4d22-4ed0-876a-b1fb9be79ad4.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6213994 (5.9M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615138/DSC_7274_8660a940-4d22-4ed0-876a-b1fb9be79ad4.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.93M  --.-KB/s    in 0.1s
#
# 2023-07-27 18:08:03 (60.0 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615138/DSC_7274_8660a940-4d22-4ed0-876a-b1fb9be79ad4.jpg’ saved [6213994/6213994]
#
# --2023-07-27 18:08:03--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615165/DSC_4318_239d147a-248b-4a1e-a9c3-be265e81990c.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 15558934 (15M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615165/DSC_4318_239d147a-248b-4a1e-a9c3-be265e81990c.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  14.84M  30.5MB/s    in 0.5s
#
# 2023-07-27 18:08:04 (30.5 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615165/DSC_4318_239d147a-248b-4a1e-a9c3-be265e81990c.jpg’ saved [15558934/15558934]
#
# --2023-07-27 18:08:04--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615165/DSC_4382_ae96f4c3-f6d6-4967-a331-bf10b735cb5d.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 14089432 (13M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615165/DSC_4382_ae96f4c3-f6d6-4967-a331-bf10b735cb5d.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  13.44M  28.6MB/s    in 0.5s
#
# 2023-07-27 18:08:04 (28.6 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615165/DSC_4382_ae96f4c3-f6d6-4967-a331-bf10b735cb5d.jpg’ saved [14089432/14089432]
#
# --2023-07-27 18:08:04--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615192/-193_d3638b4f-21cc-4def-93a8-9b89c8dc14e5.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13596828 (13M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615192/-193_d3638b4f-21cc-4def-93a8-9b89c8dc14e5.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  12.97M  27.5MB/s    in 0.5s
#
# 2023-07-27 18:08:05 (27.5 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615192/-193_d3638b4f-21cc-4def-93a8-9b89c8dc14e5.jpg’ saved [13596828/13596828]
#
# --2023-07-27 18:08:05--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615193/DSC_3768_f16b8d1c-26f3-4861-b639-4f1d47989d6f.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9607086 (9.2M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615193/DSC_3768_f16b8d1c-26f3-4861-b639-4f1d47989d6f.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   9.16M  18.9MB/s    in 0.5s
#
# 2023-07-27 18:08:06 (18.9 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615193/DSC_3768_f16b8d1c-26f3-4861-b639-4f1d47989d6f.jpg’ saved [9607086/9607086]
#
# --2023-07-27 18:08:06--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615222/DSC_0015_add210ea-83f7-4ec8-b7fc-1696ce79f6d9.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5883675 (5.6M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615222/DSC_0015_add210ea-83f7-4ec8-b7fc-1696ce79f6d9.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.61M  36.4MB/s    in 0.2s
#
# 2023-07-27 18:08:06 (36.4 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615222/DSC_0015_add210ea-83f7-4ec8-b7fc-1696ce79f6d9.jpg’ saved [5883675/5883675]
#
# --2023-07-27 18:08:06--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615227/DSC_0141_f7eb96ae-e67c-4300-8384-310a1959c71b.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6717202 (6.4M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615227/DSC_0141_f7eb96ae-e67c-4300-8384-310a1959c71b.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   6.41M  --.-KB/s    in 0.1s
#
# 2023-07-27 18:08:06 (48.1 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615227/DSC_0141_f7eb96ae-e67c-4300-8384-310a1959c71b.jpg’ saved [6717202/6717202]
#
# --2023-07-27 18:08:06--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615229/DSC_5026_94d9a873-0eb4-4305-a71b-3420f5d08ced.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13538486 (13M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615229/DSC_5026_94d9a873-0eb4-4305-a71b-3420f5d08ced.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  12.91M  40.4MB/s    in 0.3s
#
# 2023-07-27 18:08:07 (40.4 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615229/DSC_5026_94d9a873-0eb4-4305-a71b-3420f5d08ced.jpg’ saved [13538486/13538486]
#
# --2023-07-27 18:08:07--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615229/DSC_5048_c0350c41-faf6-48ec-adc8-1787a372ae26.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 12968796 (12M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615229/DSC_5048_c0350c41-faf6-48ec-adc8-1787a372ae26.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  12.37M  20.8MB/s    in 0.6s
#
# 2023-07-27 18:08:08 (20.8 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615229/DSC_5048_c0350c41-faf6-48ec-adc8-1787a372ae26.jpg’ saved [12968796/12968796]
#
# --2023-07-27 18:08:08--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615233/Bay-Gulf_7cf02db3-93c8-484a-a67d-290b09d89f5e.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13381969 (13M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615233/Bay-Gulf_7cf02db3-93c8-484a-a67d-290b09d89f5e.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  12.76M  28.9MB/s    in 0.4s
#
# 2023-07-27 18:08:08 (28.9 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615233/Bay-Gulf_7cf02db3-93c8-484a-a67d-290b09d89f5e.jpg’ saved [13381969/13381969]
#
# --2023-07-27 18:08:08--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615233/Bay-Gulf_c6507bcf-909d-4ee8-84fe-800a4ff8845f.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 14245222 (14M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615233/Bay-Gulf_c6507bcf-909d-4ee8-84fe-800a4ff8845f.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  13.58M  30.0MB/s    in 0.5s
#
# 2023-07-27 18:08:09 (30.0 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615233/Bay-Gulf_c6507bcf-909d-4ee8-84fe-800a4ff8845f.jpg’ saved [14245222/14245222]
#
# --2023-07-27 18:08:09--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615265/DSC_6531_543c2dd6-add7-42db-b58f-cb60f3291067.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13611376 (13M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615265/DSC_6531_543c2dd6-add7-42db-b58f-cb60f3291067.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  12.98M  29.0MB/s    in 0.4s
#
# 2023-07-27 18:08:10 (29.0 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9099/615265/DSC_6531_543c2dd6-add7-42db-b58f-cb60f3291067.jpg’ saved [13611376/13611376]
#
# --2023-07-27 18:08:10--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9150/616087/DSC_4038_a4edf0fc-f550-4d0d-8c58-2398f0c6089d.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6131237 (5.8M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9150/616087/DSC_4038_a4edf0fc-f550-4d0d-8c58-2398f0c6089d.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   5.85M  --.-KB/s    in 0.03s
#
# 2023-07-27 18:08:10 (188 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9150/616087/DSC_4038_a4edf0fc-f550-4d0d-8c58-2398f0c6089d.jpg’ saved [6131237/6131237]
#
# --2023-07-27 18:08:10--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_8063_09f235b4-f6b3-43fe-a265-38a209f038c6.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 15105037 (14M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_8063_09f235b4-f6b3-43fe-a265-38a209f038c6.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  14.41M  30.3MB/s    in 0.5s
#
# 2023-07-27 18:08:10 (30.3 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_8063_09f235b4-f6b3-43fe-a265-38a209f038c6.jpg’ saved [15105037/15105037]
#
# --2023-07-27 18:08:10--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_8155_5b296565-0f79-45cd-9912-36e01f2eb00e.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13114071 (13M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_8155_5b296565-0f79-45cd-9912-36e01f2eb00e.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  12.51M  19.5MB/s    in 0.6s
#
# 2023-07-27 18:08:11 (19.5 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_8155_5b296565-0f79-45cd-9912-36e01f2eb00e.jpg’ saved [13114071/13114071]
#
# --2023-07-27 18:08:11--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_8225_3e81c7b6-8294-4d51-9be9-9545d6fce1d4.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13744844 (13M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_8225_3e81c7b6-8294-4d51-9be9-9545d6fce1d4.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  13.11M  31.0MB/s    in 0.4s
#
# 2023-07-27 18:08:12 (31.0 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_8225_3e81c7b6-8294-4d51-9be9-9545d6fce1d4.jpg’ saved [13744844/13744844]
#
# --2023-07-27 18:08:12--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_8319_a3f9ae19-b948-42d4-a4b9-880eb318debc.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11517890 (11M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_8319_a3f9ae19-b948-42d4-a4b9-880eb318debc.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]  10.98M  18.3MB/s    in 0.6s
#
# 2023-07-27 18:08:12 (18.3 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9157/616220/DSC_8319_a3f9ae19-b948-42d4-a4b9-880eb318debc.jpg’ saved [11517890/11517890]
#
# --2023-07-27 18:08:12--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616226/FEMA_Reg_feab0af2-5d32-4f58-ab0d-7687a24b0131.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3678591 (3.5M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616226/FEMA_Reg_feab0af2-5d32-4f58-ab0d-7687a24b0131.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   3.51M  19.7MB/s    in 0.2s
#
# 2023-07-27 18:08:13 (19.7 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616226/FEMA_Reg_feab0af2-5d32-4f58-ab0d-7687a24b0131.jpg’ saved [3678591/3678591]
#
# --2023-07-27 18:08:13--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616227/FEMA_Reg_57640970-2f57-40d8-8edc-973d30ffb3ef.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 8598895 (8.2M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616227/FEMA_Reg_57640970-2f57-40d8-8edc-973d30ffb3ef.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   8.20M  40.7MB/s    in 0.2s
#
# 2023-07-27 18:08:13 (40.7 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616227/FEMA_Reg_57640970-2f57-40d8-8edc-973d30ffb3ef.jpg’ saved [8598895/8598895]
#
# --2023-07-27 18:08:13--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616227/FEMA_Reg_cd074b53-b15c-4726-84f1-cad4276b400c.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9251871 (8.8M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616227/FEMA_Reg_cd074b53-b15c-4726-84f1-cad4276b400c.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   8.82M  35.9MB/s    in 0.2s
#
# 2023-07-27 18:08:13 (35.9 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616227/FEMA_Reg_cd074b53-b15c-4726-84f1-cad4276b400c.jpg’ saved [9251871/9251871]
#
# --2023-07-27 18:08:13--  https://ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616227/FEMA_Reg_ec7e3eb6-8d5d-43fd-a7b6-b9e935da1d89.jpg
# Reusing existing connection to ladi.s3-us-west-2.amazonaws.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9568121 (9.1M) [image/jpeg]
# Saving to: ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616227/FEMA_Reg_ec7e3eb6-8d5d-43fd-a7b6-b9e935da1d89.jpg’
#
# ladi.s3-us-west-2.a 100%[===================>]   9.12M  --.-KB/s    in 0.1s
#
# 2023-07-27 18:08:14 (63.6 MB/s) - ‘ladi.s3-us-west-2.amazonaws.com/Images/FEMA_CAP/9161/616227/FEMA_Reg_ec7e3eb6-8d5d-43fd-a7b6-b9e935da1d89.jpg’ saved [9568121/9568121]
#
# FINISHED --2023-07-27 18:08:14--
# Total wall clock time: 2m 37s
# Downloaded: 398 files, 3.2G in 1m 31s (36.2 MB/s)
