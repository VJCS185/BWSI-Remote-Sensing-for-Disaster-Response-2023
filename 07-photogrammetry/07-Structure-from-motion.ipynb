# %% [markdown]
# # 3D Reconstruction and Structure from Motion
#
# Suppose we are given a series of images from a disaster situation. How can we begin to make sense of the contents of the image? Typically this involves answering two questions:
#
# - _What_ is in an image (e.g. debris, buildings, etc.)?
# - _Where_ are these things located _in 3D space_ ?
#
# We are first going to set the first question aside and focus entirely on the second. This will be the first in two lectures on so called "structure from motion", which is the idea that you can recreate a 3D scene from a series of 2D images by taking those images from a moving camera. Today's lecture will focus on the theory of 3D reconstruction and how to implement it. Tomorrow's lecture will focus on a real world example of structure from motion, and we will work to assign GPS coordinates to pixels on an image.
#
# We will first start with two images and work our way up to multiple images.

# %% [markdown]
# ## The Camera Model:
#
# Let's first introduce the model that we will be basing our analysis on. For this session, we will be using the _pinhole model_ of a camera, depicted in the following picture:
#
# <img src="notebook_images/pinhole.png" width="300"  />
#
# In this model of the camera, light rays are reflected off of an object (in this case a kettle), they pass through an infinitesimally small pinhole, and arrive at the opposite wall of the camera, creating a photo-negative (think upside down) image of the object. The pinhole is located at a point called the _center of projection_. Because the image on the actual camera is a photo-negative, we typically instead center our reference frame on the center of projection and work as if the image were on the opposite side, which we will call the _image plane_. The distance _f_ between the center of projection and the image plane is called the _focal length_ which is usually measured in millimeters. On the image plane, the center of the plane is called the _principal point_ and the line that connects the center of projection and the principal point is called the _principal axis_.
#
# We can align our coordinate frame as follows: let's center our coordinate system such that the origin is the center of projection, let's align the Z-axis such that it passes through principal axis, and let's align the X- and Y-axis such that the X-axis goes along the horizonal direction of the image plane and the Y-axis goes along the vertical direction of the image plane. Note that X increases to the right, but Y increases *downward*. This is shown in the following image:
#
# <img src="notebook_images/reference_frame.png" width="500"  />
#
# The image plane is given by a _uv-plane_ that is centered on the principal point and is orthogonal to the principal axis. Note that cameras typically measure coordinates starting from the upper-left corner, and increasing to the left and downwards (which motivates our decision to align our Y axis downwards). Furthermore, note that cameras cannot capture an image with perfect precision. Rather, they are composed of small elements called _pixels_ that vary in intensity in order to capture the scene. Therefore, we would rather operate on the discrete pixel plane, which we will call the lowercase xy-plane. You can compare both planes in the image below:
#
# <img src="notebook_images/xy_plane.png" width="500"  />
#
# All objects create a projection on the xy-plane, which is what we actually see on the image. For example, the point $M$ on the kettle is projected onto the xy-plane on the point _m_. Suppose we have the coordinates ($X$, $Y$, $Z$) of the point $M$. **What are the coordinates on the xy-plane of the point $m$?** State your answer in terms of $\alpha$ (the focal length measured in pixels, not millimeters), $p_x$ and $p_y$ (the coordinates of the principal point $p$ in the xy-plane), and $X$, $Y$ and $Z$, the coordinates of the point $M$.
#
# <details>
#     <summary>ANSWER</summary>
#     We can use geometry to arrive at the answer. Note that $C$, $p$ and $m$ form a similar triangle with $C$, $Z$ and $M$. Therefore, $\frac{x-p_x}{\alpha} = \frac{X}{Z}$ and $\frac{y-p_y}{\alpha} = \frac{Y}{Z}$. Now it's a matter of solving: $x = \alpha\frac{X}{Z} + p_x$ and $y = \alpha\frac{Y}{Z} + p_y$
# </details>

# %% [markdown]
# ### List of variables used in this lesson
# | Variable |                                               Meaning                                              |
# |:--------:|:--------------------------------------------------------------------------------------------------:|
# |     M    |                                         A point in 3D space                                        |
# |  m1, m2  |                                  Projection of M on image 1 and 2                                  |
# |  C1, C2  |                             Center of camera 1, 2 (a point in 3D space)                            |
# |     p    |         A point on the z axis of C (directly in front of it) at the center of a given photo        |
# |     a    |                                      Focal length of a camera                                      |
# |     R    |                                     Rotation of a camera image                                     |
# |     t    |                                    Translation of a camera image                                   |
# |     K    | A intrinsic matrix used to calculate a camera's offset, a function of its focal length and point p |

# %% [markdown]
# ## The Problem: Depth Ambiguity
#
# Scene reconstruction requires us to go the other way around: we know the coordinates ($x$, $y$) of $m$ and we want the ($X$, $Y$, $Z$) coordinates of the point $M$. This presents a problem: we have two equations and three unknowns. Specifically, there is an ambiguity in the depth $Z$ that is impossible to resolve with just one image. Therefore, the point $M$ can be anywhere along the ray connecting the center of projection and the point $m$. This is shown in the image below:
#
# <img src="notebook_images/ambiguity.png" width="150"  />
#
# However, this can be remediated by adding a second image into the equation. This is because, assuming we have perfect cameras*, the rays connecting both centers of projection to the point $M$ should only intersect at one point, as is shown in the image below:
#
# <img src="notebook_images/two_images.png" width="250"  />
#
# Let's assume that $C_1$ and $C_2$ are both from the same camera but different locations. Furthermore, let's center our coordinate system such that $C_1$ is at the origin. What do we need in order to find the coordinates of point $M$ ?
# - The corresponding points $m_1$ and $m_2$
# - The focal length $\alpha$ and the coordinates $p_x$ and $p_y$. Because these are internal to the camera, we call these the _intrinsic parameters_.
# - The relative rotation $R$ and translation $t$ of $C_2$ with respect to $C_1$. Here, $R$ is a 3x3 matrix and $t$ is a 3x1 vector. We call $R$ and $t$ the _extrinsic parameters_.
#
# \* The perfect cameras assumption is actually critical. To see why, imagine if by some measurement error (imperfect lens, pixel accuracy, etc), $m_2$ is slightly off. **What would happen in the previous example?**
#
# <details>
#     <summary>ANSWER</summary>
#     The rays corresponding to points $m_1$ and $m_2$ will not intersect, so there is no solution to this problem!
# </details>
#
# In practice, no camera is actually perfect. There are tools that work under the hood to mitigate this. We will briefly discuss them, but will not go in depth.
#
# Let's get started!

# %%
# !conda install plotly -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.3
#   latest version: 23.5.2
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - plotly
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.7.22  |       hbcca054_0         146 KB  conda-forge
#     certifi-2023.7.22          |     pyhd8ed1ab_0         150 KB  conda-forge
#     plotly-5.9.0               |     pyhd8ed1ab_0         7.0 MB  conda-forge
#     tenacity-8.2.2             |     pyhd8ed1ab_0          22 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         7.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   plotly             conda-forge/noarch::plotly-5.9.0-pyhd8ed1ab_0
#   tenacity           conda-forge/noarch::tenacity-8.2.2-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2020.6.20-hecda079_0 --> 2023.7.22-hbcca054_0
#   certifi            conda-forge/linux-64::certifi-2020.6.~ --> conda-forge/noarch::certifi-2023.7.22-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages
# plotly-5.9.0         | 7.0 MB    | ##################################### | 100%
# ca-certificates-2023 | 146 KB    | ##################################### | 100%
# tenacity-8.2.2       | 22 KB     | ##################################### | 100%
# certifi-2023.7.22    | 150 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import os
import sys
import pathlib
import open3d as o3d
import plotly
import plotly.graph_objects as go

# %%
# Load and display the two images
img1 = cv2.imread("dumbell/images/Dumbell1.jpg", cv2.IMREAD_COLOR)
img1_rgb = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
plt.imshow(img1_rgb)
plt.show()

img2 = cv2.imread("dumbell/images/Dumbell5.jpg", cv2.IMREAD_COLOR)
img2_rgb = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
plt.imshow(img2_rgb)
plt.show()

# %% [markdown]
# ## Corresponding points
#
# Our first task is to find the points $m_1$ and $m_2$. Note that it's not just a matter of finding arbitrary points, but also of ensuring the $m_1$ is actually pointing to the same object $M$ as $m_2$. Of course, one way to do this is to manually go through both images and match points on one image with points on the other. This is not a scalable solution as you increase the number of images. To this end, experts in computer vision work with the concept of _features_ which represent points of interest within an image. To understand how features work, consider the image below. **Which of the options, A through F are most easily identifiable in the image?**
#
# <img src="notebook_images/feature_building.jpg" width="400"  />
#
# <details>
#     <summary>ANSWER</summary>
#     A and B are the hardest because they could be anywhere on the surface, so surfaces are not good. C and D are a bit easier, because edges are more immediately recognizable. However, the points can still be anywhere along the edge. E and F are the easiest, since there is only one corner that looks like them. What this shows is that corners are good points to track, followed by edges and finally surfaces.
# </details>
#
# Features, therefore, are typically corners that are automatically extracted based on color differences around the corner. Features are composed of both the _coordinates_ of the point of interest as well as a _descriptor_ of what those points look like.
#
# There are all sorts of features that will do the job. Here, we will show ORB features, which were created by the makers of OpenCV. We first extract the features and then match them with a feature in the opposite image that has the closest descriptor. It's worth noting that most of these matches will not be very good, so we only want to keep the best matches we have.
#
# ### Feature extraction

# %%
MAX_FEATURES = 5000

# creating the ORB feature extractor
orb = cv2.ORB_create(MAX_FEATURES)

# creating feature points for first and second images
kp1, dc1 = orb.detectAndCompute(img1_rgb, None)
kp2, dc2 = orb.detectAndCompute(img2_rgb, None)

img1_ORB = cv2.drawKeypoints(img1_rgb, kp1, None, flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
plt.imshow(img1_ORB)
plt.show()

# %% [markdown]
# ### Feature matching

# %%
# most matches are not very good, so we want to keep only the best ones.
# here, we keep only the top 20%
GOOD_MATCH_PERCENT = 0.2

# create BFMatcher object
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck = True)

# match descriptors
matches = bf.match(dc1, dc2)

# Sort matches by score
matches.sort(key=lambda x: x.distance, reverse=False)

# Remove worst matches
numGoodMatches = int(len(matches) * GOOD_MATCH_PERCENT)
matches = matches[:numGoodMatches]

img_match = cv2.drawMatches(img1_rgb,kp1,img2_rgb,kp2,matches,None, flags=2)
plt.figure(figsize=(10,10))
plt.imshow(img_match)
plt.show()

pts1 = np.float32([ kp1[m.queryIdx].pt for m in matches ]).reshape(-1,1,2)
pts2 = np.float32([ kp2[m.trainIdx].pt for m in matches ]).reshape(-1,1,2)

# %% [markdown]
# ## Intrinsic parameters
#
# We now proceed to obtain the intrinsic parameters. We have already seen that we can gather important data about the image by looking at its metadata. We can do something similar here:

# %%
import exifread

with open("kitchen_example/images/kitchen01.jpg", 'rb') as image_file:
    tags = exifread.process_file(image_file, details=False)
    print(tags["EXIF FocalLength"])
    print(img1.shape)
# Out:
# 219/50
# (3024, 4032, 3)

# %% [markdown]
# It might seem tempting to take the focal length as is, and to take the height and width of the image, divide by two and call that the coordinates of the principal point. While this might certainly be a start if you have no other options, there are some limitations to take into account. First, recall that the focal length here is measured in millimeters, but we need the length in pixels $\alpha = m*f$, where $m$ is the size in millimeters of each pixel. This information is rarely found in the metadata. Usually, if you want to get the focal length in pixels just from the metadata, you would have to find the camera specifications online and make the conversion of millimeters to pixels. Also, the focal length is typically rounded to the nearest integer in the metadata, further complicating matters.
#
# Second, because of manufacturing constraints in positioning the sensor the principal point is always off from the middle of an image by a few pixels. While the middle of an image is most likely a good approximation, the error will continue to add up as you go farther away from the camera center.
#
# Finally, even if you have the focal length and principal point coordinates, the reconstruction must account for _distortion_. Distortion typically comes from imperfect lenses. The most well known form of distortion is _radial distortion_. This has the effect of making straight lines bulge outwards the farther away you are from the center. The figure below shows an example of this:
#
# <img src="notebook_images/distortion.jpg" width="300"  />
#
# Distortion is rarely in the image metadata. Sometimes cameras have distortion control that corrects for distortion when it's taking the image, so you don't have to worry about it. Still, this is relatively rare and it does not show up in the metadata whether distortion control was applied. So if you're not familiar with the camera you're using, you're still in the dark.
#
# One way to get around this is to perform explicit camera calibration. A common way to do this is to map points with a known 3D-to-2D correspondence (like a chessboard) and perform an optimization to correct for the distortion. How this typically works is by assigning coordinates to the inner corners of the camera (e.g. the top left corner will be (0, 0, 0), the one on the right might be (1, 0, 0), the one below would be (0, 1, 0)), and then choosing the focal length, principal point and distortion parameters that best explain deviations in the expected 2D coordinates. Typically you have to take something on the order of 20-30 images of a chessboard from slightly varying locations for this procedure to work.

# %%
# # termination criteria
# criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 30, 0.001)

# # prepare object points, like (0,0,0), (1,0,0), (2,0,0) ....,(6,5,0)
# objp = np.zeros((6*9,3), np.float32) 
# objp[:,:2] = np.mgrid[0:6,0:9].T.reshape(-1,2)

# # Arrays to store object points and image points from all the images.
# objpoints = [] # 3d point in real world space
# imgpoints = [] # 2d points in image plane.

# images = pathlib.Path('chessboard').glob('*.jpg')

# for fname in images:
#     img = cv2.imread(str(fname))
#     gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

#     # Find the chess board corners
#     ret, corners = cv2.findChessboardCorners(gray, (6,9),None)

#     # If found, add object points, image points (after refining them)
#     if ret == True:
#         print("corners found!")
#         objpoints.append(objp)

#         corners2 = cv2.cornerSubPix(gray,corners,(11,11),(-1,-1),criteria)
#         imgpoints.append(corners2)

#         # Draw and display the corners
#         img = cv2.drawChessboardCorners(img, (6,9), corners2,ret)
#         plt.imshow(img, cmap="gray")
#         plt.show()
#     else:
#         print("corners not found, trying next image.")

# ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, gray.shape[::-1],None,None)
# print(mtx)
# np.save('camera_mat.npy', mtx)
# print(dist)

# %% [markdown]
# Usually the intrinsic parameters are stored as a matrix, called the *intrinsic matrix*. The form of the intrinsic matrix is as follows:
#
# \begin{equation}
# K = \begin{bmatrix}
# \alpha_x & 0 & p_x\\
# 0 & \alpha_y & p_y\\
# 0 & 0 & 1
# \end{bmatrix}
# \end{equation}
#
# I loaded the camera matrix from my phone below. Notice that the coordinates of the principal point are close to, but not quite, the middle of the image. Also notice that we introduced $\alpha_x$ and $\alpha_y$, even though we've only worked with $\alpha$ thus far. This is a more general notation, and it takes into account the possibility that cameras might not have square pixels. If one side of a pixel is larger than the other, it makes more sense to talk about focal length measured in pixel width or height. Still, cameras typically have square pixels, and this is reflected in the fact that $\alpha_x$ is very close to $\alpha_y$, so we can chalk up the discrepancy to measurement error.
#
# As a final note, some very specialized cameras have non-rectangular pixels. It turns out $K$ can account for that by changing the value of $K_{1, 2}$, otherwise known as the skew. For most cameras, you can assume it equals 0.

# %%
# the cell above takes a very long time to run. I already ran it and saved the matrix.
K = np.load('camera_mat.npy')
print(K)
# Out:
# [[3.33137457e+03 0.00000000e+00 1.99790436e+03]
#  [0.00000000e+00 3.32450615e+03 1.54307405e+03]
#  [0.00000000e+00 0.00000000e+00 1.00000000e+00]]

# %% [markdown]
# ### Exercise
# Print out the chessboard that was provided to you in chessboard_original/ (or use your own chessboard). Using your phone (or whatever other camera), take 20 or so photos of the chessboard lying on a flat surface and upload them to the chessboard/ directory.
#
# Uncomment the cell with the callibration code and run the callibration with your images. Compare the values in the estimated camera matrix with the values you would have expected. How similar are they to the expected values? What is the size of a pixel in your camera in millimeters?

# %% [markdown]
# ## Extrinsic parameters
#
# We now need to find the rotation and translation $R$ and $t$ of both cameras. To reiterate, $t$ is a 3x1 vector that denotes the distance from the origin in $X$, $Y$ and $Z$\*. $R$ is a 3x3 matrix that encodes the rotation of the camera. We made our lives a bit easier by centering the coordinate system on the first camera, such that $t_1 = [0, 0, 0]'$ and $R_1$ is the identity matrix. Remember that we also aligned the coordinate system such that the vector $[0, 0, 1]'$ is in the direction that the camera is pointing. One way to interpret the rotation matrix $R_2$ is by saying that it is the matrix that rotates the vector $[0, 0, 1]'$ into the vector that is aligned with the direction of the second camera.
#
# One of the most amazing results in multiview geometry is that $R_2$ and $t_2$ can both be recovered (up to scale, in the case of $t_2$) just by knowing the corresponding points and the intrinsic parameters. At a very high level, this is a key tenet of something called _epipolar geometry_. Consider images (a) and (b) below. On the image you will find random corresponding points between the two images. On image (a), clearly the camera that took (b) is somewhere to the right. Imagine we could extend (a) so much that you could actually see the camera that took (b), and let's draw a line between the camera that took (b) and all of the corresponding points. What you would find is a series of lines, called epipolar lines, that all converge at the camera that took (b), whose point is called the epipole. This is what we see in (c) and (d).
#
# <img src="notebook_images/epipolar.jpg" width="500"  />
#
# (source: https://www.youtube.com/watch?v=QzYn0OPO0Yw)
#
# It turns out there is a matrix called the _fundamental matrix_ that encodes this information. This matrix can be estimated using the corresponding points we got before. Furthermore, by combining it with the intrinsic parameters, we get another matrix called the _essential matrix_ which can then be decomposed into a relative rotation and translation $R_2$ and $t_2$, which is what we're after! This is of course a criminally high level summary of how this works. For more information, this is an excellent source: https://www.youtube.com/watch?v=QzYn0OPO0Yw.
#
# \* This is actually a bit incorrect. $t$ represents the vector connecting the center of projection to the origin *from the point of view of the camera being considered*, not the first camera. Still, the general idea is that it denotes displacement.

# %%
# converting to pixel coordinates
pts1 = np.int32(pts1)
pts2 = np.int32(pts2)

# Estimate the essential matrix
E, mask = cv2.findEssentialMat(pts1,pts2,K)

# We select only inlier points
pts1_inliers = (pts1[mask.ravel()==1])
pts2_inliers = (pts2[mask.ravel()==1])

# %%
# Recover pose using what we've learned so far
retval, R, t, mask = cv2.recoverPose(E, pts1_inliers, pts2_inliers, K)
print(R)
print(t)
# Out:
# [[-0.83697429 -0.54514288 -0.04788822]
#  [ 0.54418764 -0.81987662 -0.1779386 ]
#  [ 0.05773953 -0.17499021  0.98287567]]
# [[-0.27980191]
#  [-0.03766404]
#  [ 0.95931867]]

# %% [markdown]
# ## Finalizing the reconstruction
#
# We now have everything we need to reconstruct the scene in 3D! We have corresponding points in two images, the intrinsic parameters of the camera and the extrinsic parameters as the camera took the two images. There is just one caveat. Remember that the value $t_2$ that we obtained was up to scale. It turns out that our entire scene is scaled such that the length of $t_2 = 1$. This means that while the relative distances between the reconstructed points are conserved, the absolute positions are not.
#
# Because we want to take advantage of visualization software that currently exists, we will use a package called OpenSfM (https://github.com/mapillary/OpenSfM). OpenSfM automatically goes through the trouble of extracting the features, matching them, finding the poses of the cameras and doing the triangulation. One thing it does not do, however, is the camera calibration. We can either provide our own intrinsic camera parameters or we can let the algorithm take its best guess through a process called _bundle adjustment_. Bundle adjustment essentially works by identifying the _reprojection error_ (the error in reprojecting the reconstructed 3D features back onto the image) and slightly modifying the camera positions and parameters, as well as the positions of the features, so that the error is minimized.
#
# As a final note, what do we do when we have more than three images? Clearly if you can find the camera pose of image 2 relative to image 1, then it's possible to find the pose of image 3 relative to image 2. Therefore, multiple images can take part in a reconstruction. Here, bundle adjustment is very important to ensure that errors in the reconstruction do not keep adding up.
#
# Here are the steps to reconstruct a scene:
# - Extract the focal length from the metadata
# - Detect features from images (in this particular case, we are using so called HAHOG features)
# - Match features across images
# - Reconstruct the scene using the inferred rotations and translations
# - Visualize the scene
#
# OpenSfM has a very good command line interface, so we'll move to the terminal for this portion. However, the commands are on the following cell in case you want to refer back to them.

# %%
# Take initial guess of intrinsic parameters through metadata
# !opensfm extract_metadata dumbell/

# Detect features points 
# !opensfm detect_features dumbell/

# Match feature points across images
# !opensfm match_features dumbell/

# This creates "tracks" for the features. That is to say, if a feature in image 1 is matched with one in image 2,
# and in turn that one is matched with one in image 3, then it links the matches between 1 and 3. In this case, 
# it does not matter since we only have two images
# !opensfm create_tracks dumbell/

# Calculates the essential matrix, the camera pose and the reconstructed feature points
# !opensfm reconstruct dumbell/

# For visualization using Open3D
# !opensfm export_ply dumbell/
# Out:
# 2023-07-26 20:47:37,531 INFO: Loading existing EXIF for Dumbell1.jpg
# 2023-07-26 20:47:37,531 INFO: Loading existing EXIF for Dumbell10.jpg
# 2023-07-26 20:47:37,532 INFO: Extracting EXIF for IMG_4781.jpg
# 2023-07-26 20:47:37,534 INFO: Image file "dumbell/images/IMG_4781.jpg" has no valid time stamp
# 2023-07-26 20:47:37,542 INFO: Extracting EXIF for IMG_4793.jpg
# 2023-07-26 20:47:37,543 INFO: Image file "dumbell/images/IMG_4793.jpg" has no valid time stamp
# 2023-07-26 20:47:37,543 INFO: Loading existing EXIF for Dumbell7.jpg
# 2023-07-26 20:47:37,543 INFO: Extracting EXIF for IMG_4789.jpg
# 2023-07-26 20:47:37,544 INFO: Image file "dumbell/images/IMG_4789.jpg" has no valid time stamp
# 2023-07-26 20:47:37,545 INFO: Extracting EXIF for IMG_4800.jpg
# 2023-07-26 20:47:37,546 INFO: Image file "dumbell/images/IMG_4800.jpg" has no valid time stamp
# 2023-07-26 20:47:37,546 INFO: Extracting EXIF for IMG_4778.jpg
# 2023-07-26 20:47:37,547 INFO: Image file "dumbell/images/IMG_4778.jpg" has no valid time stamp
# 2023-07-26 20:47:37,548 INFO: Loading existing EXIF for Dumbell2.jpg
# 2023-07-26 20:47:37,548 INFO: Extracting EXIF for IMG_4779.jpg
# 2023-07-26 20:47:37,550 INFO: Image file "dumbell/images/IMG_4779.jpg" has no valid time stamp
# 2023-07-26 20:47:37,550 INFO: Extracting EXIF for IMG_4788.jpg
# 2023-07-26 20:47:37,551 INFO: Image file "dumbell/images/IMG_4788.jpg" has no valid time stamp
# 2023-07-26 20:47:37,552 INFO: Extracting EXIF for IMG_4790.jpg
# 2023-07-26 20:47:37,553 INFO: Image file "dumbell/images/IMG_4790.jpg" has no valid time stamp
# 2023-07-26 20:47:37,553 INFO: Extracting EXIF for IMG_4799.jpg
# 2023-07-26 20:47:37,554 INFO: Image file "dumbell/images/IMG_4799.jpg" has no valid time stamp
# 2023-07-26 20:47:37,554 INFO: Loading existing EXIF for Dumbell8.jpg
# 2023-07-26 20:47:37,554 INFO: Extracting EXIF for IMG_4796.jpg
# 2023-07-26 20:47:37,556 INFO: Image file "dumbell/images/IMG_4796.jpg" has no valid time stamp
# 2023-07-26 20:47:37,556 INFO: Extracting EXIF for IMG_4792.jpg
# 2023-07-26 20:47:37,557 INFO: Image file "dumbell/images/IMG_4792.jpg" has no valid time stamp
# 2023-07-26 20:47:37,557 INFO: Extracting EXIF for IMG_4794.jpg
# 2023-07-26 20:47:37,559 INFO: Image file "dumbell/images/IMG_4794.jpg" has no valid time stamp
# 2023-07-26 20:47:37,559 INFO: Loading existing EXIF for Dumbell9.jpg
# 2023-07-26 20:47:37,559 INFO: Extracting EXIF for IMG_4782.jpg
# 2023-07-26 20:47:37,561 INFO: Image file "dumbell/images/IMG_4782.jpg" has no valid time stamp
# 2023-07-26 20:47:37,562 INFO: Loading existing EXIF for Dumbell12.jpg
# 2023-07-26 20:47:37,562 INFO: Extracting EXIF for IMG_4791.jpg
# 2023-07-26 20:47:37,563 INFO: Image file "dumbell/images/IMG_4791.jpg" has no valid time stamp
# 2023-07-26 20:47:37,563 INFO: Extracting EXIF for IMG_4780.jpg
# 2023-07-26 20:47:37,565 INFO: Image file "dumbell/images/IMG_4780.jpg" has no valid time stamp
# 2023-07-26 20:47:37,566 INFO: Extracting EXIF for IMG_4801.jpg
# 2023-07-26 20:47:37,567 INFO: Image file "dumbell/images/IMG_4801.jpg" has no valid time stamp
# 2023-07-26 20:47:37,567 INFO: Loading existing EXIF for Dumbell5.jpg
# 2023-07-26 20:47:37,567 INFO: Extracting EXIF for IMG_4776.jpg
# 2023-07-26 20:47:37,569 INFO: Image file "dumbell/images/IMG_4776.jpg" has no valid time stamp
# 2023-07-26 20:47:37,569 INFO: Loading existing EXIF for Dumbell11.jpg
# 2023-07-26 20:47:37,570 INFO: Extracting EXIF for IMG_4786.jpg
# 2023-07-26 20:47:37,571 INFO: Image file "dumbell/images/IMG_4786.jpg" has no valid time stamp
# 2023-07-26 20:47:37,571 INFO: Loading existing EXIF for Dumbell4.jpg
# 2023-07-26 20:47:37,571 INFO: Extracting EXIF for IMG_4783.jpg
# 2023-07-26 20:47:37,573 INFO: Image file "dumbell/images/IMG_4783.jpg" has no valid time stamp
# 2023-07-26 20:47:37,574 INFO: Extracting EXIF for IMG_4785.jpg
# 2023-07-26 20:47:37,575 INFO: Image file "dumbell/images/IMG_4785.jpg" has no valid time stamp
# 2023-07-26 20:47:37,576 INFO: Extracting EXIF for IMG_4797.jpg
# 2023-07-26 20:47:37,577 INFO: Image file "dumbell/images/IMG_4797.jpg" has no valid time stamp
# 2023-07-26 20:47:37,577 INFO: Loading existing EXIF for Dumbell3.jpg
# 2023-07-26 20:47:37,577 INFO: Extracting EXIF for IMG_4798.jpg
# 2023-07-26 20:47:37,578 INFO: Image file "dumbell/images/IMG_4798.jpg" has no valid time stamp
# 2023-07-26 20:47:37,579 INFO: Extracting EXIF for IMG_4784.jpg
# 2023-07-26 20:47:37,581 INFO: Image file "dumbell/images/IMG_4784.jpg" has no valid time stamp
# 2023-07-26 20:47:37,581 INFO: Loading existing EXIF for Dumbell6.jpg
# 2023-07-26 20:47:37,581 INFO: Loading existing EXIF for Dumbell13.jpg
# 2023-07-26 20:47:37,581 INFO: Extracting EXIF for IMG_4787.jpg
# 2023-07-26 20:47:37,583 INFO: Image file "dumbell/images/IMG_4787.jpg" has no valid time stamp
# 2023-07-26 20:47:39,823 INFO: Skip recomputing ROOT_HAHOG features for image Dumbell1.jpg
# 2023-07-26 20:47:39,823 INFO: Skip recomputing ROOT_HAHOG features for image Dumbell10.jpg
# 2023-07-26 20:47:39,823 INFO: Extracting ROOT_HAHOG features for image IMG_4781.jpg
# 2023-07-26 20:47:40,585 DEBUG: Found 3688 points in 0.747624397277832s
# 2023-07-26 20:47:40,585 DEBUG: No segmentation for IMG_4781.jpg, no features masked.
# 2023-07-26 20:47:40,620 INFO: Extracting ROOT_HAHOG features for image IMG_4793.jpg
# 2023-07-26 20:47:41,695 DEBUG: Found 4905 points in 1.062901258468628s
# 2023-07-26 20:47:41,695 DEBUG: No segmentation for IMG_4793.jpg, no features masked.
# 2023-07-26 20:47:41,741 INFO: Skip recomputing ROOT_HAHOG features for image Dumbell7.jpg
# 2023-07-26 20:47:41,741 INFO: Extracting ROOT_HAHOG features for image IMG_4789.jpg
# 2023-07-26 20:47:42,780 DEBUG: Found 5192 points in 1.0273387432098389s
# 2023-07-26 20:47:42,781 DEBUG: No segmentation for IMG_4789.jpg, no features masked.
# 2023-07-26 20:47:42,824 INFO: Extracting ROOT_HAHOG features for image IMG_4800.jpg
# 2023-07-26 20:47:43,645 DEBUG: Found 3834 points in 0.8103621006011963s
# 2023-07-26 20:47:43,646 DEBUG: No segmentation for IMG_4800.jpg, no features masked.
# 2023-07-26 20:47:43,685 INFO: Extracting ROOT_HAHOG features for image IMG_4778.jpg
# 2023-07-26 20:47:44,634 DEBUG: Found 4739 points in 0.9361584186553955s
# 2023-07-26 20:47:44,635 DEBUG: No segmentation for IMG_4778.jpg, no features masked.
# 2023-07-26 20:47:44,678 INFO: Skip recomputing ROOT_HAHOG features for image Dumbell2.jpg
# 2023-07-26 20:47:44,678 INFO: Extracting ROOT_HAHOG features for image IMG_4779.jpg
# 2023-07-26 20:47:45,581 DEBUG: Found 4397 points in 0.8900489807128906s
# 2023-07-26 20:47:45,582 DEBUG: No segmentation for IMG_4779.jpg, no features masked.
# 2023-07-26 20:47:45,618 INFO: Extracting ROOT_HAHOG features for image IMG_4788.jpg
# 2023-07-26 20:47:46,677 DEBUG: Found 5131 points in 1.04594087600708s
# 2023-07-26 20:47:46,677 DEBUG: No segmentation for IMG_4788.jpg, no features masked.
# 2023-07-26 20:47:46,721 INFO: Extracting ROOT_HAHOG features for image IMG_4790.jpg
# 2023-07-26 20:47:47,778 DEBUG: Found 5053 points in 1.046027660369873s
# 2023-07-26 20:47:47,779 DEBUG: No segmentation for IMG_4790.jpg, no features masked.
# 2023-07-26 20:47:47,829 INFO: Extracting ROOT_HAHOG features for image IMG_4799.jpg
# 2023-07-26 20:47:48,809 DEBUG: Found 4766 points in 0.9685053825378418s
# 2023-07-26 20:47:48,809 DEBUG: No segmentation for IMG_4799.jpg, no features masked.
# 2023-07-26 20:47:48,855 INFO: Skip recomputing ROOT_HAHOG features for image Dumbell8.jpg
# 2023-07-26 20:47:48,855 INFO: Extracting ROOT_HAHOG features for image IMG_4796.jpg
# 2023-07-26 20:47:49,931 DEBUG: Found 5247 points in 1.0637462139129639s
# 2023-07-26 20:47:49,932 DEBUG: No segmentation for IMG_4796.jpg, no features masked.
# 2023-07-26 20:47:49,976 INFO: Extracting ROOT_HAHOG features for image IMG_4792.jpg
# 2023-07-26 20:47:51,056 DEBUG: Found 4893 points in 1.067481517791748s
# 2023-07-26 20:47:51,056 DEBUG: No segmentation for IMG_4792.jpg, no features masked.
# 2023-07-26 20:47:51,100 INFO: Extracting ROOT_HAHOG features for image IMG_4794.jpg
# 2023-07-26 20:47:52,194 DEBUG: Found 5168 points in 1.0825412273406982s
# 2023-07-26 20:47:52,195 DEBUG: No segmentation for IMG_4794.jpg, no features masked.
# 2023-07-26 20:47:52,241 INFO: Skip recomputing ROOT_HAHOG features for image Dumbell9.jpg
# 2023-07-26 20:47:52,241 INFO: Extracting ROOT_HAHOG features for image IMG_4782.jpg
# 2023-07-26 20:47:53,041 DEBUG: Found 3966 points in 0.7871813774108887s
# 2023-07-26 20:47:53,041 DEBUG: No segmentation for IMG_4782.jpg, no features masked.
# 2023-07-26 20:47:53,072 INFO: Skip recomputing ROOT_HAHOG features for image Dumbell12.jpg
# 2023-07-26 20:47:53,072 INFO: Extracting ROOT_HAHOG features for image IMG_4791.jpg
# 2023-07-26 20:47:54,131 DEBUG: Found 5033 points in 1.047095537185669s
# 2023-07-26 20:47:54,132 DEBUG: No segmentation for IMG_4791.jpg, no features masked.
# 2023-07-26 20:47:54,177 INFO: Extracting ROOT_HAHOG features for image IMG_4780.jpg
# 2023-07-26 20:47:54,949 DEBUG: Found 3593 points in 0.7592723369598389s
# 2023-07-26 20:47:54,950 DEBUG: No segmentation for IMG_4780.jpg, no features masked.
# 2023-07-26 20:47:54,981 INFO: Extracting ROOT_HAHOG features for image IMG_4801.jpg
# 2023-07-26 20:47:55,945 DEBUG: Found 4696 points in 0.9526877403259277s
# 2023-07-26 20:47:55,946 DEBUG: No segmentation for IMG_4801.jpg, no features masked.
# 2023-07-26 20:47:55,990 INFO: Skip recomputing ROOT_HAHOG features for image Dumbell5.jpg
# 2023-07-26 20:47:55,990 INFO: Extracting ROOT_HAHOG features for image IMG_4776.jpg
# 2023-07-26 20:47:56,989 DEBUG: Found 5021 points in 0.9865491390228271s
# 2023-07-26 20:47:56,990 DEBUG: No segmentation for IMG_4776.jpg, no features masked.
# 2023-07-26 20:47:57,031 INFO: Skip recomputing ROOT_HAHOG features for image Dumbell11.jpg
# 2023-07-26 20:47:57,031 INFO: Extracting ROOT_HAHOG features for image IMG_4786.jpg
# 2023-07-26 20:47:58,098 DEBUG: Found 5147 points in 1.054292917251587s
# 2023-07-26 20:47:58,099 DEBUG: No segmentation for IMG_4786.jpg, no features masked.
# 2023-07-26 20:47:58,144 INFO: Skip recomputing ROOT_HAHOG features for image Dumbell4.jpg
# 2023-07-26 20:47:58,144 INFO: Extracting ROOT_HAHOG features for image IMG_4783.jpg
# 2023-07-26 20:47:58,999 DEBUG: Found 4276 points in 0.842792272567749s
# 2023-07-26 20:47:59,000 DEBUG: No segmentation for IMG_4783.jpg, no features masked.
# 2023-07-26 20:47:59,036 INFO: Extracting ROOT_HAHOG features for image IMG_4785.jpg
# 2023-07-26 20:47:59,784 DEBUG: Found 3649 points in 0.7349405288696289s
# 2023-07-26 20:47:59,784 DEBUG: No segmentation for IMG_4785.jpg, no features masked.
# 2023-07-26 20:47:59,812 INFO: Extracting ROOT_HAHOG features for image IMG_4797.jpg
# 2023-07-26 20:48:00,844 DEBUG: Found 5093 points in 1.0202140808105469s
# 2023-07-26 20:48:00,845 DEBUG: No segmentation for IMG_4797.jpg, no features masked.
# 2023-07-26 20:48:00,888 INFO: Skip recomputing ROOT_HAHOG features for image Dumbell3.jpg
# 2023-07-26 20:48:00,888 INFO: Extracting ROOT_HAHOG features for image IMG_4798.jpg
# 2023-07-26 20:48:01,924 DEBUG: Found 4940 points in 1.0231904983520508s
# 2023-07-26 20:48:01,925 DEBUG: No segmentation for IMG_4798.jpg, no features masked.
# 2023-07-26 20:48:01,971 INFO: Extracting ROOT_HAHOG features for image IMG_4784.jpg
# 2023-07-26 20:48:02,832 DEBUG: Found 4140 points in 0.8476471900939941s
# 2023-07-26 20:48:02,833 DEBUG: No segmentation for IMG_4784.jpg, no features masked.
# 2023-07-26 20:48:02,871 INFO: Skip recomputing ROOT_HAHOG features for image Dumbell6.jpg
# 2023-07-26 20:48:02,872 INFO: Skip recomputing ROOT_HAHOG features for image Dumbell13.jpg
# 2023-07-26 20:48:02,872 INFO: Extracting ROOT_HAHOG features for image IMG_4787.jpg
# 2023-07-26 20:48:03,966 DEBUG: Found 5127 points in 1.0827744007110596s
# 2023-07-26 20:48:03,967 DEBUG: No segmentation for IMG_4787.jpg, no features masked.
# 2023-07-26 20:48:06,266 INFO: Matching 666 image pairs
# 2023-07-26 20:48:06,274 INFO: Computing pair matching with 1 processes
# 2023-07-26 20:48:06,298 DEBUG: No segmentation for Dumbell9.jpg, no features masked.
# 2023-07-26 20:48:06,300 DEBUG: No segmentation for IMG_4781.jpg, no features masked.
# 2023-07-26 20:48:06,814 DEBUG: Matching Dumbell9.jpg and IMG_4781.jpg.  Matcher: FLANN (symmetric) T-desc: 0.515 Matches: FAILED
# 2023-07-26 20:48:06,825 DEBUG: No segmentation for Dumbell4.jpg, no features masked.
# 2023-07-26 20:48:07,227 DEBUG: Matching Dumbell9.jpg and Dumbell4.jpg.  Matcher: FLANN (symmetric) T-desc: 0.402 Matches: FAILED
# 2023-07-26 20:48:07,238 DEBUG: No segmentation for IMG_4797.jpg, no features masked.
# 2023-07-26 20:48:07,648 DEBUG: Matching Dumbell9.jpg and IMG_4797.jpg.  Matcher: FLANN (symmetric) T-desc: 0.409 T-robust: 0.001 T-total: 0.410 Matches: 210 Robust: 170 Success: True
# 2023-07-26 20:48:07,658 DEBUG: No segmentation for IMG_4799.jpg, no features masked.
# 2023-07-26 20:48:08,048 DEBUG: Matching Dumbell9.jpg and IMG_4799.jpg.  Matcher: FLANN (symmetric) T-desc: 0.390 Matches: FAILED
# 2023-07-26 20:48:08,059 DEBUG: No segmentation for IMG_4798.jpg, no features masked.
# 2023-07-26 20:48:08,457 DEBUG: Matching Dumbell9.jpg and IMG_4798.jpg.  Matcher: FLANN (symmetric) T-desc: 0.397 T-robust: 0.002 T-total: 0.400 Matches: 24 Robust: 16 Success: False
# 2023-07-26 20:48:08,465 DEBUG: No segmentation for IMG_4780.jpg, no features masked.
# 2023-07-26 20:48:08,764 DEBUG: Matching Dumbell9.jpg and IMG_4780.jpg.  Matcher: FLANN (symmetric) T-desc: 0.299 Matches: FAILED
# 2023-07-26 20:48:08,775 DEBUG: No segmentation for IMG_4776.jpg, no features masked.
# 2023-07-26 20:48:09,173 DEBUG: Matching Dumbell9.jpg and IMG_4776.jpg.  Matcher: FLANN (symmetric) T-desc: 0.399 Matches: FAILED
# 2023-07-26 20:48:09,183 DEBUG: No segmentation for IMG_4779.jpg, no features masked.
# 2023-07-26 20:48:09,537 DEBUG: Matching Dumbell9.jpg and IMG_4779.jpg.  Matcher: FLANN (symmetric) T-desc: 0.355 Matches: FAILED
# 2023-07-26 20:48:09,548 DEBUG: No segmentation for Dumbell12.jpg, no features masked.
# 2023-07-26 20:48:09,961 DEBUG: Matching Dumbell9.jpg and Dumbell12.jpg.  Matcher: FLANN (symmetric) T-desc: 0.414 Matches: FAILED
# 2023-07-26 20:48:09,971 DEBUG: No segmentation for IMG_4784.jpg, no features masked.
# 2023-07-26 20:48:10,311 DEBUG: Matching Dumbell9.jpg and IMG_4784.jpg.  Matcher: FLANN (symmetric) T-desc: 0.341 Matches: FAILED
# 2023-07-26 20:48:10,321 DEBUG: No segmentation for Dumbell7.jpg, no features masked.
# 2023-07-26 20:48:10,698 DEBUG: Matching Dumbell9.jpg and Dumbell7.jpg.  Matcher: FLANN (symmetric) T-desc: 0.379 Matches: FAILED
# 2023-07-26 20:48:10,709 DEBUG: No segmentation for IMG_4792.jpg, no features masked.
# 2023-07-26 20:48:11,095 DEBUG: Matching Dumbell9.jpg and IMG_4792.jpg.  Matcher: FLANN (symmetric) T-desc: 0.387 Matches: FAILED
# 2023-07-26 20:48:11,105 DEBUG: No segmentation for IMG_4791.jpg, no features masked.
# 2023-07-26 20:48:11,507 DEBUG: Matching Dumbell9.jpg and IMG_4791.jpg.  Matcher: FLANN (symmetric) T-desc: 0.403 Matches: FAILED
# 2023-07-26 20:48:11,519 DEBUG: No segmentation for IMG_4794.jpg, no features masked.
# 2023-07-26 20:48:11,928 DEBUG: Matching Dumbell9.jpg and IMG_4794.jpg.  Matcher: FLANN (symmetric) T-desc: 0.411 Matches: FAILED
# 2023-07-26 20:48:11,939 DEBUG: No segmentation for IMG_4796.jpg, no features masked.
# 2023-07-26 20:48:12,354 DEBUG: Matching Dumbell9.jpg and IMG_4796.jpg.  Matcher: FLANN (symmetric) T-desc: 0.416 T-robust: 0.000 T-total: 0.417 Matches: 52 Robust: 47 Success: True
# 2023-07-26 20:48:12,366 DEBUG: No segmentation for Dumbell1.jpg, no features masked.
# 2023-07-26 20:48:12,803 DEBUG: Matching Dumbell9.jpg and Dumbell1.jpg.  Matcher: FLANN (symmetric) T-desc: 0.438 Matches: FAILED
# 2023-07-26 20:48:12,814 DEBUG: No segmentation for Dumbell10.jpg, no features masked.
# 2023-07-26 20:48:13,153 DEBUG: Matching Dumbell9.jpg and Dumbell10.jpg.  Matcher: FLANN (symmetric) T-desc: 0.340 Matches: FAILED
# 2023-07-26 20:48:13,164 DEBUG: No segmentation for IMG_4793.jpg, no features masked.
# 2023-07-26 20:48:13,549 DEBUG: Matching Dumbell9.jpg and IMG_4793.jpg.  Matcher: FLANN (symmetric) T-desc: 0.387 Matches: FAILED
# 2023-07-26 20:48:13,560 DEBUG: No segmentation for Dumbell8.jpg, no features masked.
# 2023-07-26 20:48:13,967 DEBUG: Matching Dumbell9.jpg and Dumbell8.jpg.  Matcher: FLANN (symmetric) T-desc: 0.408 Matches: FAILED
# 2023-07-26 20:48:13,978 DEBUG: No segmentation for Dumbell3.jpg, no features masked.
# 2023-07-26 20:48:14,414 DEBUG: Matching Dumbell9.jpg and Dumbell3.jpg.  Matcher: FLANN (symmetric) T-desc: 0.437 Matches: FAILED
# 2023-07-26 20:48:14,425 DEBUG: No segmentation for IMG_4788.jpg, no features masked.
# 2023-07-26 20:48:14,883 DEBUG: Matching Dumbell9.jpg and IMG_4788.jpg.  Matcher: FLANN (symmetric) T-desc: 0.460 Matches: FAILED
# 2023-07-26 20:48:14,892 DEBUG: No segmentation for IMG_4800.jpg, no features masked.
# 2023-07-26 20:48:15,205 DEBUG: Matching Dumbell9.jpg and IMG_4800.jpg.  Matcher: FLANN (symmetric) T-desc: 0.313 Matches: FAILED
# 2023-07-26 20:48:15,216 DEBUG: No segmentation for Dumbell13.jpg, no features masked.
# 2023-07-26 20:48:15,594 DEBUG: Matching Dumbell9.jpg and Dumbell13.jpg.  Matcher: FLANN (symmetric) T-desc: 0.381 Matches: FAILED
# 2023-07-26 20:48:15,604 DEBUG: No segmentation for Dumbell11.jpg, no features masked.
# 2023-07-26 20:48:15,966 DEBUG: Matching Dumbell9.jpg and Dumbell11.jpg.  Matcher: FLANN (symmetric) T-desc: 0.362 Matches: FAILED
# 2023-07-26 20:48:15,977 DEBUG: No segmentation for IMG_4786.jpg, no features masked.
# 2023-07-26 20:48:16,386 DEBUG: Matching Dumbell9.jpg and IMG_4786.jpg.  Matcher: FLANN (symmetric) T-desc: 0.410 Matches: FAILED
# 2023-07-26 20:48:16,396 DEBUG: No segmentation for IMG_4778.jpg, no features masked.
# 2023-07-26 20:48:16,784 DEBUG: Matching Dumbell9.jpg and IMG_4778.jpg.  Matcher: FLANN (symmetric) T-desc: 0.389 Matches: FAILED
# 2023-07-26 20:48:16,795 DEBUG: No segmentation for IMG_4801.jpg, no features masked.
# 2023-07-26 20:48:17,169 DEBUG: Matching Dumbell9.jpg and IMG_4801.jpg.  Matcher: FLANN (symmetric) T-desc: 0.376 Matches: FAILED
# 2023-07-26 20:48:17,179 DEBUG: No segmentation for IMG_4783.jpg, no features masked.
# 2023-07-26 20:48:17,522 DEBUG: Matching Dumbell9.jpg and IMG_4783.jpg.  Matcher: FLANN (symmetric) T-desc: 0.344 Matches: FAILED
# 2023-07-26 20:48:17,534 DEBUG: No segmentation for Dumbell5.jpg, no features masked.
# 2023-07-26 20:48:17,998 DEBUG: Matching Dumbell9.jpg and Dumbell5.jpg.  Matcher: FLANN (symmetric) T-desc: 0.464 Matches: FAILED
# 2023-07-26 20:48:18,010 DEBUG: No segmentation for Dumbell2.jpg, no features masked.
# 2023-07-26 20:48:18,446 DEBUG: Matching Dumbell9.jpg and Dumbell2.jpg.  Matcher: FLANN (symmetric) T-desc: 0.437 Matches: FAILED
# 2023-07-26 20:48:18,457 DEBUG: No segmentation for Dumbell6.jpg, no features masked.
# 2023-07-26 20:48:18,880 DEBUG: Matching Dumbell9.jpg and Dumbell6.jpg.  Matcher: FLANN (symmetric) T-desc: 0.424 Matches: FAILED
# 2023-07-26 20:48:18,891 DEBUG: No segmentation for IMG_4789.jpg, no features masked.
# 2023-07-26 20:48:19,303 DEBUG: Matching Dumbell9.jpg and IMG_4789.jpg.  Matcher: FLANN (symmetric) T-desc: 0.413 Matches: FAILED
# 2023-07-26 20:48:19,313 DEBUG: No segmentation for IMG_4787.jpg, no features masked.
# 2023-07-26 20:48:19,729 DEBUG: Matching Dumbell9.jpg and IMG_4787.jpg.  Matcher: FLANN (symmetric) T-desc: 0.416 Matches: FAILED
# 2023-07-26 20:48:19,737 DEBUG: No segmentation for IMG_4785.jpg, no features masked.
# 2023-07-26 20:48:20,047 DEBUG: Matching Dumbell9.jpg and IMG_4785.jpg.  Matcher: FLANN (symmetric) T-desc: 0.310 Matches: FAILED
# 2023-07-26 20:48:20,058 DEBUG: No segmentation for IMG_4790.jpg, no features masked.
# 2023-07-26 20:48:20,458 DEBUG: Matching Dumbell9.jpg and IMG_4790.jpg.  Matcher: FLANN (symmetric) T-desc: 0.401 Matches: FAILED
# 2023-07-26 20:48:20,467 DEBUG: No segmentation for IMG_4782.jpg, no features masked.
# 2023-07-26 20:48:20,791 DEBUG: Matching Dumbell9.jpg and IMG_4782.jpg.  Matcher: FLANN (symmetric) T-desc: 0.325 Matches: FAILED
# 2023-07-26 20:48:20,791 DEBUG: Image Dumbell9.jpg matches: 2 out of 36
# 2023-07-26 20:48:20,973 DEBUG: Matching Dumbell13.jpg and IMG_4797.jpg.  Matcher: FLANN (symmetric) T-desc: 0.182 Matches: FAILED
# 2023-07-26 20:48:21,142 DEBUG: Matching Dumbell13.jpg and IMG_4783.jpg.  Matcher: FLANN (symmetric) T-desc: 0.168 Matches: FAILED
# 2023-07-26 20:48:21,320 DEBUG: Matching Dumbell13.jpg and IMG_4779.jpg.  Matcher: FLANN (symmetric) T-desc: 0.177 T-robust: 0.000 T-total: 0.178 Matches: 86 Robust: 79 Success: True
# 2023-07-26 20:48:21,500 DEBUG: Matching Dumbell13.jpg and IMG_4798.jpg.  Matcher: FLANN (symmetric) T-desc: 0.180 Matches: FAILED
# 2023-07-26 20:48:21,691 DEBUG: Matching Dumbell13.jpg and Dumbell12.jpg.  Matcher: FLANN (symmetric) T-desc: 0.191 Matches: FAILED
# 2023-07-26 20:48:21,852 DEBUG: Matching Dumbell13.jpg and IMG_4785.jpg.  Matcher: FLANN (symmetric) T-desc: 0.159 T-robust: 0.001 T-total: 0.160 Matches: 225 Robust: 202 Success: True
# 2023-07-26 20:48:22,029 DEBUG: Matching Dumbell13.jpg and Dumbell7.jpg.  Matcher: FLANN (symmetric) T-desc: 0.176 Matches: FAILED
# 2023-07-26 20:48:22,215 DEBUG: Matching Dumbell13.jpg and IMG_4790.jpg.  Matcher: FLANN (symmetric) T-desc: 0.186 Matches: FAILED
# 2023-07-26 20:48:22,377 DEBUG: Matching Dumbell13.jpg and IMG_4782.jpg.  Matcher: FLANN (symmetric) T-desc: 0.162 Matches: FAILED
# 2023-07-26 20:48:22,566 DEBUG: Matching Dumbell13.jpg and IMG_4786.jpg.  Matcher: FLANN (symmetric) T-desc: 0.188 Matches: FAILED
# 2023-07-26 20:48:22,735 DEBUG: Matching Dumbell13.jpg and IMG_4801.jpg.  Matcher: FLANN (symmetric) T-desc: 0.169 Matches: FAILED
# 2023-07-26 20:48:22,933 DEBUG: Matching Dumbell13.jpg and Dumbell2.jpg.  Matcher: FLANN (symmetric) T-desc: 0.197 T-robust: 0.001 T-total: 0.197 Matches: 44 Robust: 37 Success: True
# 2023-07-26 20:48:23,126 DEBUG: Matching Dumbell13.jpg and IMG_4787.jpg.  Matcher: FLANN (symmetric) T-desc: 0.193 Matches: FAILED
# 2023-07-26 20:48:23,295 DEBUG: Matching Dumbell13.jpg and IMG_4784.jpg.  Matcher: FLANN (symmetric) T-desc: 0.168 T-robust: 0.000 T-total: 0.168 Matches: 26 Robust: 24 Success: True
# 2023-07-26 20:48:23,468 DEBUG: Matching Dumbell13.jpg and IMG_4799.jpg.  Matcher: FLANN (symmetric) T-desc: 0.173 Matches: FAILED
# 2023-07-26 20:48:23,647 DEBUG: Matching Dumbell13.jpg and IMG_4796.jpg.  Matcher: FLANN (symmetric) T-desc: 0.179 Matches: FAILED
# 2023-07-26 20:48:23,830 DEBUG: Matching Dumbell13.jpg and Dumbell4.jpg.  Matcher: FLANN (symmetric) T-desc: 0.183 Matches: FAILED
# 2023-07-26 20:48:24,006 DEBUG: Matching Dumbell13.jpg and IMG_4793.jpg.  Matcher: FLANN (symmetric) T-desc: 0.175 Matches: FAILED
# 2023-07-26 20:48:24,203 DEBUG: Matching Dumbell13.jpg and Dumbell3.jpg.  Matcher: FLANN (symmetric) T-desc: 0.197 Matches: FAILED
# 2023-07-26 20:48:24,393 DEBUG: Matching Dumbell13.jpg and IMG_4788.jpg.  Matcher: FLANN (symmetric) T-desc: 0.188 T-robust: 0.001 T-total: 0.189 Matches: 23 Robust: 17 Success: False
# 2023-07-26 20:48:24,631 DEBUG: Matching Dumbell13.jpg and Dumbell5.jpg.  Matcher: FLANN (symmetric) T-desc: 0.237 T-robust: 0.000 T-total: 0.237 Matches: 20 Robust: 20 Success: True
# 2023-07-26 20:48:24,811 DEBUG: Matching Dumbell13.jpg and IMG_4800.jpg.  Matcher: FLANN (symmetric) T-desc: 0.180 Matches: FAILED
# 2023-07-26 20:48:25,016 DEBUG: Matching Dumbell13.jpg and Dumbell6.jpg.  Matcher: FLANN (symmetric) T-desc: 0.205 Matches: FAILED
# 2023-07-26 20:48:25,219 DEBUG: Matching Dumbell13.jpg and IMG_4789.jpg.  Matcher: FLANN (symmetric) T-desc: 0.200 T-robust: 0.003 T-total: 0.203 Matches: 28 Robust: 18 Success: False
# 2023-07-26 20:48:25,401 DEBUG: Matching Dumbell13.jpg and Dumbell11.jpg.  Matcher: FLANN (symmetric) T-desc: 0.173 T-robust: 0.008 T-total: 0.181 Matches: 22 Robust: 12 Success: False
# 2023-07-26 20:48:25,559 DEBUG: Matching Dumbell13.jpg and IMG_4780.jpg.  Matcher: FLANN (symmetric) T-desc: 0.157 T-robust: 0.000 T-total: 0.157 Matches: 58 Robust: 51 Success: True
# 2023-07-26 20:48:25,743 DEBUG: Matching Dumbell13.jpg and IMG_4776.jpg.  Matcher: FLANN (symmetric) T-desc: 0.184 Matches: FAILED
# 2023-07-26 20:48:25,927 DEBUG: Matching Dumbell13.jpg and IMG_4794.jpg.  Matcher: FLANN (symmetric) T-desc: 0.184 Matches: FAILED
# 2023-07-26 20:48:26,126 DEBUG: Matching Dumbell13.jpg and Dumbell1.jpg.  Matcher: FLANN (symmetric) T-desc: 0.197 T-robust: 0.001 T-total: 0.198 Matches: 54 Robust: 41 Success: True
# 2023-07-26 20:48:26,285 DEBUG: Matching Dumbell13.jpg and IMG_4781.jpg.  Matcher: FLANN (symmetric) T-desc: 0.159 Matches: FAILED
# 2023-07-26 20:48:26,446 DEBUG: Matching Dumbell13.jpg and Dumbell10.jpg.  Matcher: FLANN (symmetric) T-desc: 0.161 Matches: FAILED
# 2023-07-26 20:48:26,623 DEBUG: Matching Dumbell13.jpg and Dumbell8.jpg.  Matcher: FLANN (symmetric) T-desc: 0.177 Matches: FAILED
# 2023-07-26 20:48:26,802 DEBUG: Matching Dumbell13.jpg and IMG_4792.jpg.  Matcher: FLANN (symmetric) T-desc: 0.178 Matches: FAILED
# 2023-07-26 20:48:26,984 DEBUG: Matching Dumbell13.jpg and IMG_4791.jpg.  Matcher: FLANN (symmetric) T-desc: 0.182 Matches: FAILED
# 2023-07-26 20:48:27,165 DEBUG: Matching Dumbell13.jpg and IMG_4778.jpg.  Matcher: FLANN (symmetric) T-desc: 0.180 T-robust: 0.000 T-total: 0.180 Matches: 34 Robust: 31 Success: True
# 2023-07-26 20:48:27,165 DEBUG: Image Dumbell13.jpg matches: 8 out of 35
# 2023-07-26 20:48:27,344 DEBUG: Matching IMG_4797.jpg and IMG_4779.jpg.  Matcher: FLANN (symmetric) T-desc: 0.179 Matches: FAILED
# 2023-07-26 20:48:27,527 DEBUG: Matching IMG_4797.jpg and IMG_4799.jpg.  Matcher: FLANN (symmetric) T-desc: 0.183 Matches: FAILED
# 2023-07-26 20:48:27,713 DEBUG: Matching IMG_4797.jpg and IMG_4792.jpg.  Matcher: FLANN (symmetric) T-desc: 0.185 Matches: FAILED
# 2023-07-26 20:48:27,899 DEBUG: Matching IMG_4797.jpg and Dumbell11.jpg.  Matcher: FLANN (symmetric) T-desc: 0.186 Matches: FAILED
# 2023-07-26 20:48:28,104 DEBUG: Matching IMG_4797.jpg and Dumbell1.jpg.  Matcher: FLANN (symmetric) T-desc: 0.205 Matches: FAILED
# 2023-07-26 20:48:28,278 DEBUG: Matching IMG_4797.jpg and IMG_4784.jpg.  Matcher: FLANN (symmetric) T-desc: 0.174 Matches: FAILED
# 2023-07-26 20:48:28,471 DEBUG: Matching IMG_4797.jpg and IMG_4790.jpg.  Matcher: FLANN (symmetric) T-desc: 0.193 Matches: FAILED
# 2023-07-26 20:48:28,667 DEBUG: Matching IMG_4797.jpg and IMG_4794.jpg.  Matcher: FLANN (symmetric) T-desc: 0.196 Matches: FAILED
# 2023-07-26 20:48:28,862 DEBUG: Matching IMG_4797.jpg and IMG_4786.jpg.  Matcher: FLANN (symmetric) T-desc: 0.195 Matches: FAILED
# 2023-07-26 20:48:29,066 DEBUG: Matching IMG_4797.jpg and Dumbell12.jpg.  Matcher: FLANN (symmetric) T-desc: 0.203 Matches: FAILED
# 2023-07-26 20:48:29,272 DEBUG: Matching IMG_4797.jpg and Dumbell3.jpg.  Matcher: FLANN (symmetric) T-desc: 0.206 Matches: FAILED
# 2023-07-26 20:48:29,468 DEBUG: Matching IMG_4797.jpg and Dumbell6.jpg.  Matcher: FLANN (symmetric) T-desc: 0.195 Matches: FAILED
# 2023-07-26 20:48:29,663 DEBUG: Matching IMG_4797.jpg and IMG_4789.jpg.  Matcher: FLANN (symmetric) T-desc: 0.195 Matches: FAILED
# 2023-07-26 20:48:29,856 DEBUG: Matching IMG_4797.jpg and IMG_4796.jpg.  Matcher: FLANN (symmetric) T-desc: 0.192 T-robust: 0.001 T-total: 0.193 Matches: 74 Robust: 58 Success: True
# 2023-07-26 20:48:30,052 DEBUG: Matching IMG_4797.jpg and IMG_4798.jpg.  Matcher: FLANN (symmetric) T-desc: 0.194 T-robust: 0.001 T-total: 0.195 Matches: 73 Robust: 58 Success: True
# 2023-07-26 20:48:30,238 DEBUG: Matching IMG_4797.jpg and IMG_4801.jpg.  Matcher: FLANN (symmetric) T-desc: 0.186 Matches: FAILED
# 2023-07-26 20:48:30,435 DEBUG: Matching IMG_4797.jpg and IMG_4788.jpg.  Matcher: FLANN (symmetric) T-desc: 0.196 Matches: FAILED
# 2023-07-26 20:48:30,604 DEBUG: Matching IMG_4797.jpg and IMG_4783.jpg.  Matcher: FLANN (symmetric) T-desc: 0.169 Matches: FAILED
# 2023-07-26 20:48:30,795 DEBUG: Matching IMG_4797.jpg and Dumbell8.jpg.  Matcher: FLANN (symmetric) T-desc: 0.190 Matches: FAILED
# 2023-07-26 20:48:31,003 DEBUG: Matching IMG_4797.jpg and Dumbell5.jpg.  Matcher: FLANN (symmetric) T-desc: 0.209 Matches: FAILED
# 2023-07-26 20:48:31,190 DEBUG: Matching IMG_4797.jpg and IMG_4778.jpg.  Matcher: FLANN (symmetric) T-desc: 0.187 Matches: FAILED
# 2023-07-26 20:48:31,356 DEBUG: Matching IMG_4797.jpg and IMG_4781.jpg.  Matcher: FLANN (symmetric) T-desc: 0.166 Matches: FAILED
# 2023-07-26 20:48:31,516 DEBUG: Matching IMG_4797.jpg and IMG_4780.jpg.  Matcher: FLANN (symmetric) T-desc: 0.159 Matches: FAILED
# 2023-07-26 20:48:31,683 DEBUG: Matching IMG_4797.jpg and IMG_4782.jpg.  Matcher: FLANN (symmetric) T-desc: 0.167 Matches: FAILED
# 2023-07-26 20:48:31,872 DEBUG: Matching IMG_4797.jpg and IMG_4791.jpg.  Matcher: FLANN (symmetric) T-desc: 0.190 Matches: FAILED
# 2023-07-26 20:48:32,042 DEBUG: Matching IMG_4797.jpg and Dumbell10.jpg.  Matcher: FLANN (symmetric) T-desc: 0.170 Matches: FAILED
# 2023-07-26 20:48:32,231 DEBUG: Matching IMG_4797.jpg and Dumbell4.jpg.  Matcher: FLANN (symmetric) T-desc: 0.187 T-robust: 0.001 T-total: 0.188 Matches: 34 Robust: 27 Success: True
# 2023-07-26 20:48:32,410 DEBUG: Matching IMG_4797.jpg and Dumbell7.jpg.  Matcher: FLANN (symmetric) T-desc: 0.179 Matches: FAILED
# 2023-07-26 20:48:32,565 DEBUG: Matching IMG_4797.jpg and IMG_4800.jpg.  Matcher: FLANN (symmetric) T-desc: 0.154 Matches: FAILED
# 2023-07-26 20:48:32,763 DEBUG: Matching IMG_4797.jpg and IMG_4787.jpg.  Matcher: FLANN (symmetric) T-desc: 0.198 Matches: FAILED
# 2023-07-26 20:48:32,965 DEBUG: Matching IMG_4797.jpg and Dumbell2.jpg.  Matcher: FLANN (symmetric) T-desc: 0.201 Matches: FAILED
# 2023-07-26 20:48:33,127 DEBUG: Matching IMG_4797.jpg and IMG_4785.jpg.  Matcher: FLANN (symmetric) T-desc: 0.162 Matches: FAILED
# 2023-07-26 20:48:33,318 DEBUG: Matching IMG_4797.jpg and IMG_4776.jpg.  Matcher: FLANN (symmetric) T-desc: 0.190 Matches: FAILED
# 2023-07-26 20:48:33,502 DEBUG: Matching IMG_4797.jpg and IMG_4793.jpg.  Matcher: FLANN (symmetric) T-desc: 0.185 Matches: FAILED
# 2023-07-26 20:48:33,502 DEBUG: Image IMG_4797.jpg matches: 3 out of 34
# 2023-07-26 20:48:33,664 DEBUG: Matching IMG_4778.jpg and IMG_4781.jpg.  Matcher: FLANN (symmetric) T-desc: 0.160 T-robust: 0.001 T-total: 0.161 Matches: 257 Robust: 232 Success: True
# 2023-07-26 20:48:33,842 DEBUG: Matching IMG_4778.jpg and IMG_4801.jpg.  Matcher: FLANN (symmetric) T-desc: 0.178 Matches: FAILED
# 2023-07-26 20:48:33,992 DEBUG: Matching IMG_4778.jpg and IMG_4800.jpg.  Matcher: FLANN (symmetric) T-desc: 0.150 Matches: FAILED
# 2023-07-26 20:48:34,202 DEBUG: Matching IMG_4778.jpg and Dumbell5.jpg.  Matcher: FLANN (symmetric) T-desc: 0.209 T-robust: 0.001 T-total: 0.209 Matches: 35 Robust: 29 Success: True
# 2023-07-26 20:48:34,392 DEBUG: Matching IMG_4778.jpg and IMG_4798.jpg.  Matcher: FLANN (symmetric) T-desc: 0.190 Matches: FAILED
# 2023-07-26 20:48:34,587 DEBUG: Matching IMG_4778.jpg and IMG_4792.jpg.  Matcher: FLANN (symmetric) T-desc: 0.194 Matches: FAILED
# 2023-07-26 20:48:34,756 DEBUG: Matching IMG_4778.jpg and IMG_4785.jpg.  Matcher: FLANN (symmetric) T-desc: 0.168 T-robust: 0.001 T-total: 0.169 Matches: 47 Robust: 36 Success: True
# 2023-07-26 20:48:34,945 DEBUG: Matching IMG_4778.jpg and IMG_4784.jpg.  Matcher: FLANN (symmetric) T-desc: 0.189 Matches: FAILED
# 2023-07-26 20:48:35,123 DEBUG: Matching IMG_4778.jpg and IMG_4779.jpg.  Matcher: FLANN (symmetric) T-desc: 0.176 T-robust: 0.001 T-total: 0.177 Matches: 218 Robust: 185 Success: True
# 2023-07-26 20:48:35,312 DEBUG: Matching IMG_4778.jpg and Dumbell4.jpg.  Matcher: FLANN (symmetric) T-desc: 0.187 T-robust: 0.002 T-total: 0.189 Matches: 20 Robust: 14 Success: False
# 2023-07-26 20:48:35,514 DEBUG: Matching IMG_4778.jpg and Dumbell1.jpg.  Matcher: FLANN (symmetric) T-desc: 0.201 T-robust: 0.000 T-total: 0.202 Matches: 20 Robust: 19 Success: False
# 2023-07-26 20:48:35,707 DEBUG: Matching IMG_4778.jpg and Dumbell12.jpg.  Matcher: FLANN (symmetric) T-desc: 0.193 Matches: FAILED
# 2023-07-26 20:48:35,867 DEBUG: Matching IMG_4778.jpg and IMG_4780.jpg.  Matcher: FLANN (symmetric) T-desc: 0.158 T-robust: 0.001 T-total: 0.159 Matches: 149 Robust: 124 Success: True
# 2023-07-26 20:48:36,037 DEBUG: Matching IMG_4778.jpg and Dumbell10.jpg.  Matcher: FLANN (symmetric) T-desc: 0.168 T-robust: 0.002 T-total: 0.169 Matches: 580 Robust: 526 Success: True
# 2023-07-26 20:48:36,224 DEBUG: Matching IMG_4778.jpg and IMG_4776.jpg.  Matcher: FLANN (symmetric) T-desc: 0.186 Matches: FAILED
# 2023-07-26 20:48:36,409 DEBUG: Matching IMG_4778.jpg and IMG_4791.jpg.  Matcher: FLANN (symmetric) T-desc: 0.185 Matches: FAILED
# 2023-07-26 20:48:36,595 DEBUG: Matching IMG_4778.jpg and IMG_4794.jpg.  Matcher: FLANN (symmetric) T-desc: 0.186 Matches: FAILED
# 2023-07-26 20:48:36,782 DEBUG: Matching IMG_4778.jpg and IMG_4796.jpg.  Matcher: FLANN (symmetric) T-desc: 0.186 Matches: FAILED
# 2023-07-26 20:48:36,967 DEBUG: Matching IMG_4778.jpg and Dumbell8.jpg.  Matcher: FLANN (symmetric) T-desc: 0.186 Matches: FAILED
# 2023-07-26 20:48:37,136 DEBUG: Matching IMG_4778.jpg and IMG_4783.jpg.  Matcher: FLANN (symmetric) T-desc: 0.169 Matches: FAILED
# 2023-07-26 20:48:37,335 DEBUG: Matching IMG_4778.jpg and Dumbell3.jpg.  Matcher: FLANN (symmetric) T-desc: 0.199 Matches: FAILED
# 2023-07-26 20:48:37,527 DEBUG: Matching IMG_4778.jpg and IMG_4786.jpg.  Matcher: FLANN (symmetric) T-desc: 0.192 Matches: FAILED
# 2023-07-26 20:48:37,695 DEBUG: Matching IMG_4778.jpg and IMG_4782.jpg.  Matcher: FLANN (symmetric) T-desc: 0.164 T-robust: 0.003 T-total: 0.167 Matches: 46 Robust: 29 Success: True
# 2023-07-26 20:48:37,904 DEBUG: Matching IMG_4778.jpg and Dumbell2.jpg.  Matcher: FLANN (symmetric) T-desc: 0.209 Matches: FAILED
# 2023-07-26 20:48:38,103 DEBUG: Matching IMG_4778.jpg and IMG_4787.jpg.  Matcher: FLANN (symmetric) T-desc: 0.199 Matches: FAILED
# 2023-07-26 20:48:38,278 DEBUG: Matching IMG_4778.jpg and Dumbell7.jpg.  Matcher: FLANN (symmetric) T-desc: 0.175 Matches: FAILED
# 2023-07-26 20:48:38,468 DEBUG: Matching IMG_4778.jpg and IMG_4790.jpg.  Matcher: FLANN (symmetric) T-desc: 0.190 Matches: FAILED
# 2023-07-26 20:48:38,662 DEBUG: Matching IMG_4778.jpg and Dumbell6.jpg.  Matcher: FLANN (symmetric) T-desc: 0.193 Matches: FAILED
# 2023-07-26 20:48:38,855 DEBUG: Matching IMG_4778.jpg and IMG_4789.jpg.  Matcher: FLANN (symmetric) T-desc: 0.193 Matches: FAILED
# 2023-07-26 20:48:39,037 DEBUG: Matching IMG_4778.jpg and IMG_4799.jpg.  Matcher: FLANN (symmetric) T-desc: 0.179 T-robust: 0.002 T-total: 0.182 Matches: 27 Robust: 18 Success: False
# 2023-07-26 20:48:39,219 DEBUG: Matching IMG_4778.jpg and IMG_4793.jpg.  Matcher: FLANN (symmetric) T-desc: 0.182 Matches: FAILED
# 2023-07-26 20:48:39,413 DEBUG: Matching IMG_4778.jpg and IMG_4788.jpg.  Matcher: FLANN (symmetric) T-desc: 0.193 Matches: FAILED
# 2023-07-26 20:48:39,590 DEBUG: Matching IMG_4778.jpg and Dumbell11.jpg.  Matcher: FLANN (symmetric) T-desc: 0.177 Matches: FAILED
# 2023-07-26 20:48:39,591 DEBUG: Image IMG_4778.jpg matches: 7 out of 33
# 2023-07-26 20:48:39,781 DEBUG: Matching Dumbell7.jpg and Dumbell3.jpg.  Matcher: FLANN (symmetric) T-desc: 0.191 Matches: FAILED
# 2023-07-26 20:48:39,965 DEBUG: Matching Dumbell7.jpg and IMG_4794.jpg.  Matcher: FLANN (symmetric) T-desc: 0.183 Matches: FAILED
# 2023-07-26 20:48:40,155 DEBUG: Matching Dumbell7.jpg and Dumbell1.jpg.  Matcher: FLANN (symmetric) T-desc: 0.190 Matches: FAILED
# 2023-07-26 20:48:40,335 DEBUG: Matching Dumbell7.jpg and IMG_4776.jpg.  Matcher: FLANN (symmetric) T-desc: 0.179 Matches: FAILED
# 2023-07-26 20:48:40,511 DEBUG: Matching Dumbell7.jpg and IMG_4792.jpg.  Matcher: FLANN (symmetric) T-desc: 0.176 Matches: FAILED
# 2023-07-26 20:48:40,694 DEBUG: Matching Dumbell7.jpg and IMG_4786.jpg.  Matcher: FLANN (symmetric) T-desc: 0.182 T-robust: 0.001 T-total: 0.183 Matches: 79 Robust: 64 Success: True
# 2023-07-26 20:48:40,873 DEBUG: Matching Dumbell7.jpg and IMG_4791.jpg.  Matcher: FLANN (symmetric) T-desc: 0.179 Matches: FAILED
# 2023-07-26 20:48:41,018 DEBUG: Matching Dumbell7.jpg and IMG_4800.jpg.  Matcher: FLANN (symmetric) T-desc: 0.144 Matches: FAILED
# 2023-07-26 20:48:41,173 DEBUG: Matching Dumbell7.jpg and IMG_4782.jpg.  Matcher: FLANN (symmetric) T-desc: 0.156 Matches: FAILED
# 2023-07-26 20:48:41,330 DEBUG: Matching Dumbell7.jpg and IMG_4781.jpg.  Matcher: FLANN (symmetric) T-desc: 0.157 Matches: FAILED
# 2023-07-26 20:48:41,503 DEBUG: Matching Dumbell7.jpg and IMG_4793.jpg.  Matcher: FLANN (symmetric) T-desc: 0.172 Matches: FAILED
# 2023-07-26 20:48:41,690 DEBUG: Matching Dumbell7.jpg and Dumbell2.jpg.  Matcher: FLANN (symmetric) T-desc: 0.187 Matches: FAILED
# 2023-07-26 20:48:41,880 DEBUG: Matching Dumbell7.jpg and Dumbell12.jpg.  Matcher: FLANN (symmetric) T-desc: 0.189 Matches: FAILED
# 2023-07-26 20:48:42,061 DEBUG: Matching Dumbell7.jpg and Dumbell6.jpg.  Matcher: FLANN (symmetric) T-desc: 0.181 Matches: FAILED
# 2023-07-26 20:48:42,245 DEBUG: Matching Dumbell7.jpg and IMG_4789.jpg.  Matcher: FLANN (symmetric) T-desc: 0.183 Matches: FAILED
# 2023-07-26 20:48:42,395 DEBUG: Matching Dumbell7.jpg and IMG_4780.jpg.  Matcher: FLANN (symmetric) T-desc: 0.150 Matches: FAILED
# 2023-07-26 20:48:42,550 DEBUG: Matching Dumbell7.jpg and IMG_4785.jpg.  Matcher: FLANN (symmetric) T-desc: 0.154 Matches: FAILED
# 2023-07-26 20:48:42,746 DEBUG: Matching Dumbell7.jpg and Dumbell5.jpg.  Matcher: FLANN (symmetric) T-desc: 0.196 Matches: FAILED
# 2023-07-26 20:48:42,921 DEBUG: Matching Dumbell7.jpg and Dumbell8.jpg.  Matcher: FLANN (symmetric) T-desc: 0.175 Matches: FAILED
# 2023-07-26 20:48:43,088 DEBUG: Matching Dumbell7.jpg and IMG_4779.jpg.  Matcher: FLANN (symmetric) T-desc: 0.166 Matches: FAILED
# 2023-07-26 20:48:43,273 DEBUG: Matching Dumbell7.jpg and IMG_4787.jpg.  Matcher: FLANN (symmetric) T-desc: 0.185 Matches: FAILED
# 2023-07-26 20:48:43,446 DEBUG: Matching Dumbell7.jpg and IMG_4799.jpg.  Matcher: FLANN (symmetric) T-desc: 0.173 Matches: FAILED
# 2023-07-26 20:48:43,623 DEBUG: Matching Dumbell7.jpg and IMG_4798.jpg.  Matcher: FLANN (symmetric) T-desc: 0.177 Matches: FAILED
# 2023-07-26 20:48:43,795 DEBUG: Matching Dumbell7.jpg and IMG_4801.jpg.  Matcher: FLANN (symmetric) T-desc: 0.171 Matches: FAILED
# 2023-07-26 20:48:43,979 DEBUG: Matching Dumbell7.jpg and IMG_4788.jpg.  Matcher: FLANN (symmetric) T-desc: 0.184 Matches: FAILED
# 2023-07-26 20:48:44,138 DEBUG: Matching Dumbell7.jpg and Dumbell10.jpg.  Matcher: FLANN (symmetric) T-desc: 0.159 Matches: FAILED
# 2023-07-26 20:48:44,303 DEBUG: Matching Dumbell7.jpg and IMG_4784.jpg.  Matcher: FLANN (symmetric) T-desc: 0.165 Matches: FAILED
# 2023-07-26 20:48:44,475 DEBUG: Matching Dumbell7.jpg and Dumbell11.jpg.  Matcher: FLANN (symmetric) T-desc: 0.172 Matches: FAILED
# 2023-07-26 20:48:44,667 DEBUG: Matching Dumbell7.jpg and IMG_4783.jpg.  Matcher: FLANN (symmetric) T-desc: 0.192 Matches: FAILED
# 2023-07-26 20:48:44,851 DEBUG: Matching Dumbell7.jpg and Dumbell4.jpg.  Matcher: FLANN (symmetric) T-desc: 0.183 Matches: FAILED
# 2023-07-26 20:48:45,032 DEBUG: Matching Dumbell7.jpg and IMG_4796.jpg.  Matcher: FLANN (symmetric) T-desc: 0.181 Matches: FAILED
# 2023-07-26 20:48:45,213 DEBUG: Matching Dumbell7.jpg and IMG_4790.jpg.  Matcher: FLANN (symmetric) T-desc: 0.181 Matches: FAILED
# 2023-07-26 20:48:45,213 DEBUG: Image Dumbell7.jpg matches: 1 out of 32
# 2023-07-26 20:48:45,409 DEBUG: Matching IMG_4794.jpg and IMG_4788.jpg.  Matcher: FLANN (symmetric) T-desc: 0.195 Matches: FAILED
# 2023-07-26 20:48:45,615 DEBUG: Matching IMG_4794.jpg and Dumbell5.jpg.  Matcher: FLANN (symmetric) T-desc: 0.206 Matches: FAILED
# 2023-07-26 20:48:45,801 DEBUG: Matching IMG_4794.jpg and IMG_4799.jpg.  Matcher: FLANN (symmetric) T-desc: 0.185 Matches: FAILED
# 2023-07-26 20:48:45,979 DEBUG: Matching IMG_4794.jpg and Dumbell11.jpg.  Matcher: FLANN (symmetric) T-desc: 0.177 Matches: FAILED
# 2023-07-26 20:48:46,169 DEBUG: Matching IMG_4794.jpg and IMG_4776.jpg.  Matcher: FLANN (symmetric) T-desc: 0.190 Matches: FAILED
# 2023-07-26 20:48:46,373 DEBUG: Matching IMG_4794.jpg and Dumbell8.jpg.  Matcher: FLANN (symmetric) T-desc: 0.190 T-robust: 0.014 T-total: 0.204 Matches: 24 Robust: 12 Success: False
# 2023-07-26 20:48:46,565 DEBUG: Matching IMG_4794.jpg and Dumbell6.jpg.  Matcher: FLANN (symmetric) T-desc: 0.192 Matches: FAILED
# 2023-07-26 20:48:46,762 DEBUG: Matching IMG_4794.jpg and IMG_4789.jpg.  Matcher: FLANN (symmetric) T-desc: 0.197 Matches: FAILED
# 2023-07-26 20:48:46,950 DEBUG: Matching IMG_4794.jpg and IMG_4792.jpg.  Matcher: FLANN (symmetric) T-desc: 0.188 Matches: FAILED
# 2023-07-26 20:48:47,141 DEBUG: Matching IMG_4794.jpg and IMG_4798.jpg.  Matcher: FLANN (symmetric) T-desc: 0.190 Matches: FAILED
# 2023-07-26 20:48:47,331 DEBUG: Matching IMG_4794.jpg and IMG_4791.jpg.  Matcher: FLANN (symmetric) T-desc: 0.190 Matches: FAILED
# 2023-07-26 20:48:47,531 DEBUG: Matching IMG_4794.jpg and Dumbell1.jpg.  Matcher: FLANN (symmetric) T-desc: 0.200 Matches: FAILED
# 2023-07-26 20:48:47,690 DEBUG: Matching IMG_4794.jpg and IMG_4781.jpg.  Matcher: FLANN (symmetric) T-desc: 0.159 Matches: FAILED
# 2023-07-26 20:48:47,862 DEBUG: Matching IMG_4794.jpg and Dumbell10.jpg.  Matcher: FLANN (symmetric) T-desc: 0.172 Matches: FAILED
# 2023-07-26 20:48:48,044 DEBUG: Matching IMG_4794.jpg and IMG_4801.jpg.  Matcher: FLANN (symmetric) T-desc: 0.182 Matches: FAILED
# 2023-07-26 20:48:48,216 DEBUG: Matching IMG_4794.jpg and IMG_4783.jpg.  Matcher: FLANN (symmetric) T-desc: 0.171 Matches: FAILED
# 2023-07-26 20:48:48,413 DEBUG: Matching IMG_4794.jpg and Dumbell12.jpg.  Matcher: FLANN (symmetric) T-desc: 0.197 Matches: FAILED
# 2023-07-26 20:48:48,613 DEBUG: Matching IMG_4794.jpg and Dumbell2.jpg.  Matcher: FLANN (symmetric) T-desc: 0.200 Matches: FAILED
# 2023-07-26 20:48:48,807 DEBUG: Matching IMG_4794.jpg and IMG_4790.jpg.  Matcher: FLANN (symmetric) T-desc: 0.194 Matches: FAILED
# 2023-07-26 20:48:48,973 DEBUG: Matching IMG_4794.jpg and IMG_4782.jpg.  Matcher: FLANN (symmetric) T-desc: 0.166 Matches: FAILED
# 2023-07-26 20:48:49,168 DEBUG: Matching IMG_4794.jpg and IMG_4786.jpg.  Matcher: FLANN (symmetric) T-desc: 0.195 Matches: FAILED
# 2023-07-26 20:48:49,366 DEBUG: Matching IMG_4794.jpg and Dumbell4.jpg.  Matcher: FLANN (symmetric) T-desc: 0.198 Matches: FAILED
# 2023-07-26 20:48:49,543 DEBUG: Matching IMG_4794.jpg and IMG_4779.jpg.  Matcher: FLANN (symmetric) T-desc: 0.177 Matches: FAILED
# 2023-07-26 20:48:49,743 DEBUG: Matching IMG_4794.jpg and IMG_4787.jpg.  Matcher: FLANN (symmetric) T-desc: 0.200 Matches: FAILED
# 2023-07-26 20:48:49,914 DEBUG: Matching IMG_4794.jpg and IMG_4784.jpg.  Matcher: FLANN (symmetric) T-desc: 0.171 Matches: FAILED
# 2023-07-26 20:48:50,081 DEBUG: Matching IMG_4794.jpg and IMG_4785.jpg.  Matcher: FLANN (symmetric) T-desc: 0.166 Matches: FAILED
# 2023-07-26 20:48:50,253 DEBUG: Matching IMG_4794.jpg and IMG_4800.jpg.  Matcher: FLANN (symmetric) T-desc: 0.158 T-robust: 0.014 T-total: 0.172 Matches: 21 Robust: 10 Success: False
# 2023-07-26 20:48:50,444 DEBUG: Matching IMG_4794.jpg and IMG_4796.jpg.  Matcher: FLANN (symmetric) T-desc: 0.191 Matches: FAILED
# 2023-07-26 20:48:50,641 DEBUG: Matching IMG_4794.jpg and IMG_4793.jpg.  Matcher: FLANN (symmetric) T-desc: 0.185 T-robust: 0.012 T-total: 0.197 Matches: 25 Robust: 13 Success: False
# 2023-07-26 20:48:50,801 DEBUG: Matching IMG_4794.jpg and IMG_4780.jpg.  Matcher: FLANN (symmetric) T-desc: 0.160 Matches: FAILED
# 2023-07-26 20:48:51,003 DEBUG: Matching IMG_4794.jpg and Dumbell3.jpg.  Matcher: FLANN (symmetric) T-desc: 0.201 T-robust: 0.001 T-total: 0.202 Matches: 75 Robust: 62 Success: True
# 2023-07-26 20:48:51,003 DEBUG: Image IMG_4794.jpg matches: 1 out of 31
# 2023-07-26 20:48:51,177 DEBUG: Matching IMG_4788.jpg and Dumbell10.jpg.  Matcher: FLANN (symmetric) T-desc: 0.174 Matches: FAILED
# 2023-07-26 20:48:51,359 DEBUG: Matching IMG_4788.jpg and IMG_4784.jpg.  Matcher: FLANN (symmetric) T-desc: 0.182 Matches: FAILED
# 2023-07-26 20:48:51,565 DEBUG: Matching IMG_4788.jpg and IMG_4789.jpg.  Matcher: FLANN (symmetric) T-desc: 0.204 T-robust: 0.001 T-total: 0.205 Matches: 138 Robust: 109 Success: True
# 2023-07-26 20:48:51,767 DEBUG: Matching IMG_4788.jpg and Dumbell6.jpg.  Matcher: FLANN (symmetric) T-desc: 0.202 Matches: FAILED
# 2023-07-26 20:48:51,962 DEBUG: Matching IMG_4788.jpg and IMG_4791.jpg.  Matcher: FLANN (symmetric) T-desc: 0.195 Matches: FAILED
# 2023-07-26 20:48:52,164 DEBUG: Matching IMG_4788.jpg and IMG_4786.jpg.  Matcher: FLANN (symmetric) T-desc: 0.200 T-robust: 0.001 T-total: 0.201 Matches: 27 Robust: 20 Success: True
# 2023-07-26 20:48:52,386 DEBUG: Matching IMG_4788.jpg and Dumbell5.jpg.  Matcher: FLANN (symmetric) T-desc: 0.222 Matches: FAILED
# 2023-07-26 20:48:52,541 DEBUG: Matching IMG_4788.jpg and IMG_4800.jpg.  Matcher: FLANN (symmetric) T-desc: 0.155 Matches: FAILED
# 2023-07-26 20:48:52,750 DEBUG: Matching IMG_4788.jpg and Dumbell3.jpg.  Matcher: FLANN (symmetric) T-desc: 0.209 Matches: FAILED
# 2023-07-26 20:48:52,918 DEBUG: Matching IMG_4788.jpg and IMG_4781.jpg.  Matcher: FLANN (symmetric) T-desc: 0.168 Matches: FAILED
# 2023-07-26 20:48:53,125 DEBUG: Matching IMG_4788.jpg and IMG_4787.jpg.  Matcher: FLANN (symmetric) T-desc: 0.205 T-robust: 0.001 T-total: 0.206 Matches: 337 Robust: 305 Success: True
# 2023-07-26 20:48:53,335 DEBUG: Matching IMG_4788.jpg and Dumbell2.jpg.  Matcher: FLANN (symmetric) T-desc: 0.210 Matches: FAILED
# 2023-07-26 20:48:53,531 DEBUG: Matching IMG_4788.jpg and IMG_4776.jpg.  Matcher: FLANN (symmetric) T-desc: 0.196 Matches: FAILED
# 2023-07-26 20:48:53,717 DEBUG: Matching IMG_4788.jpg and IMG_4793.jpg.  Matcher: FLANN (symmetric) T-desc: 0.186 Matches: FAILED
# 2023-07-26 20:48:53,914 DEBUG: Matching IMG_4788.jpg and IMG_4798.jpg.  Matcher: FLANN (symmetric) T-desc: 0.196 Matches: FAILED
# 2023-07-26 20:48:54,096 DEBUG: Matching IMG_4788.jpg and IMG_4801.jpg.  Matcher: FLANN (symmetric) T-desc: 0.183 Matches: FAILED
# 2023-07-26 20:48:54,265 DEBUG: Matching IMG_4788.jpg and IMG_4780.jpg.  Matcher: FLANN (symmetric) T-desc: 0.169 Matches: FAILED
# 2023-07-26 20:48:54,456 DEBUG: Matching IMG_4788.jpg and Dumbell11.jpg.  Matcher: FLANN (symmetric) T-desc: 0.190 Matches: FAILED
# 2023-07-26 20:48:54,652 DEBUG: Matching IMG_4788.jpg and IMG_4785.jpg.  Matcher: FLANN (symmetric) T-desc: 0.197 Matches: FAILED
# 2023-07-26 20:48:54,875 DEBUG: Matching IMG_4788.jpg and IMG_4779.jpg.  Matcher: FLANN (symmetric) T-desc: 0.222 Matches: FAILED
# 2023-07-26 20:48:55,079 DEBUG: Matching IMG_4788.jpg and Dumbell4.jpg.  Matcher: FLANN (symmetric) T-desc: 0.204 Matches: FAILED
# 2023-07-26 20:48:55,268 DEBUG: Matching IMG_4788.jpg and IMG_4799.jpg.  Matcher: FLANN (symmetric) T-desc: 0.189 Matches: FAILED
# 2023-07-26 20:48:55,472 DEBUG: Matching IMG_4788.jpg and Dumbell12.jpg.  Matcher: FLANN (symmetric) T-desc: 0.204 Matches: FAILED
# 2023-07-26 20:48:55,681 DEBUG: Matching IMG_4788.jpg and Dumbell1.jpg.  Matcher: FLANN (symmetric) T-desc: 0.208 Matches: FAILED
# 2023-07-26 20:48:55,858 DEBUG: Matching IMG_4788.jpg and IMG_4783.jpg.  Matcher: FLANN (symmetric) T-desc: 0.178 Matches: FAILED
# 2023-07-26 20:48:56,049 DEBUG: Matching IMG_4788.jpg and Dumbell8.jpg.  Matcher: FLANN (symmetric) T-desc: 0.190 Matches: FAILED
# 2023-07-26 20:48:56,239 DEBUG: Matching IMG_4788.jpg and IMG_4792.jpg.  Matcher: FLANN (symmetric) T-desc: 0.190 Matches: FAILED
# 2023-07-26 20:48:56,435 DEBUG: Matching IMG_4788.jpg and IMG_4796.jpg.  Matcher: FLANN (symmetric) T-desc: 0.196 Matches: FAILED
# 2023-07-26 20:48:56,632 DEBUG: Matching IMG_4788.jpg and IMG_4790.jpg.  Matcher: FLANN (symmetric) T-desc: 0.196 Matches: FAILED
# 2023-07-26 20:48:56,804 DEBUG: Matching IMG_4788.jpg and IMG_4782.jpg.  Matcher: FLANN (symmetric) T-desc: 0.172 Matches: FAILED
# 2023-07-26 20:48:56,804 DEBUG: Image IMG_4788.jpg matches: 3 out of 30
# 2023-07-26 20:48:57,000 DEBUG: Matching IMG_4789.jpg and IMG_4790.jpg.  Matcher: FLANN (symmetric) T-desc: 0.196 Matches: FAILED
# 2023-07-26 20:48:57,172 DEBUG: Matching IMG_4789.jpg and IMG_4782.jpg.  Matcher: FLANN (symmetric) T-desc: 0.172 Matches: FAILED
# 2023-07-26 20:48:57,369 DEBUG: Matching IMG_4789.jpg and IMG_4791.jpg.  Matcher: FLANN (symmetric) T-desc: 0.196 Matches: FAILED
# 2023-07-26 20:48:57,569 DEBUG: Matching IMG_4789.jpg and IMG_4786.jpg.  Matcher: FLANN (symmetric) T-desc: 0.200 Matches: FAILED
# 2023-07-26 20:48:57,744 DEBUG: Matching IMG_4789.jpg and Dumbell10.jpg.  Matcher: FLANN (symmetric) T-desc: 0.175 Matches: FAILED
# 2023-07-26 20:48:57,944 DEBUG: Matching IMG_4789.jpg and Dumbell4.jpg.  Matcher: FLANN (symmetric) T-desc: 0.201 Matches: FAILED
# ...
# 2023-07-26 20:50:26,127 INFO: Adding IMG_4785.jpg to the reconstruction
# 2023-07-26 20:50:26,176 DEBUG: Local bundle sets: interior 7  boundary 0  other 0
# 2023-07-26 20:50:26,400 DEBUG: Ceres Solver Report: Iterations: 5, Initial cost: 2.623830e+02, Final cost: 2.317356e+02, Termination: CONVERGENCE
# 2023-07-26 20:50:26,419 INFO: Removed outliers: 0
# 2023-07-26 20:50:26,421 INFO: -------------------------------------------------------
# 2023-07-26 20:50:26,428 INFO: IMG_4778.jpg resection inliers: 130 / 181
# 2023-07-26 20:50:26,434 DEBUG: Ceres Solver Report: Iterations: 4, Initial cost: 6.449292e+01, Final cost: 6.273946e+01, Termination: CONVERGENCE
# 2023-07-26 20:50:26,434 INFO: Adding IMG_4778.jpg to the reconstruction
# 2023-07-26 20:50:26,465 INFO: Re-triangulating
# 2023-07-26 20:50:26,814 DEBUG: Ceres Solver Report: Iterations: 6, Initial cost: 3.186759e+02, Final cost: 2.976318e+02, Termination: CONVERGENCE
# 2023-07-26 20:50:27,382 DEBUG: Ceres Solver Report: Iterations: 6, Initial cost: 3.279071e+02, Final cost: 3.216628e+02, Termination: CONVERGENCE
# 2023-07-26 20:50:27,402 INFO: Removed outliers: 2
# 2023-07-26 20:50:27,404 INFO: -------------------------------------------------------
# 2023-07-26 20:50:27,410 INFO: IMG_4779.jpg resection inliers: 180 / 207
# 2023-07-26 20:50:27,418 DEBUG: Ceres Solver Report: Iterations: 4, Initial cost: 8.793977e+01, Final cost: 8.688668e+01, Termination: CONVERGENCE
# 2023-07-26 20:50:27,419 INFO: Adding IMG_4779.jpg to the reconstruction
# 2023-07-26 20:50:27,475 DEBUG: Local bundle sets: interior 9  boundary 0  other 0
# 2023-07-26 20:50:27,749 DEBUG: Ceres Solver Report: Iterations: 5, Initial cost: 2.997172e+02, Final cost: 2.883654e+02, Termination: CONVERGENCE
# 2023-07-26 20:50:27,771 INFO: Removed outliers: 0
# 2023-07-26 20:50:27,773 INFO: -------------------------------------------------------
# 2023-07-26 20:50:27,778 INFO: Dumbell13.jpg resection inliers: 121 / 140
# 2023-07-26 20:50:27,784 DEBUG: Ceres Solver Report: Iterations: 4, Initial cost: 8.201606e+01, Final cost: 8.002894e+01, Termination: CONVERGENCE
# 2023-07-26 20:50:27,784 INFO: Adding Dumbell13.jpg to the reconstruction
# 2023-07-26 20:50:27,828 DEBUG: Local bundle sets: interior 10  boundary 0  other 0
# 2023-07-26 20:50:28,149 DEBUG: Ceres Solver Report: Iterations: 6, Initial cost: 3.107542e+02, Final cost: 3.025009e+02, Termination: CONVERGENCE
# 2023-07-26 20:50:28,172 INFO: Removed outliers: 0
# 2023-07-26 20:50:28,174 INFO: -------------------------------------------------------
# 2023-07-26 20:50:28,183 INFO: IMG_4776.jpg resection inliers: 101 / 113
# 2023-07-26 20:50:28,189 DEBUG: Ceres Solver Report: Iterations: 4, Initial cost: 8.326976e+01, Final cost: 8.214770e+01, Termination: CONVERGENCE
# 2023-07-26 20:50:28,189 INFO: Adding IMG_4776.jpg to the reconstruction
# 2023-07-26 20:50:28,212 INFO: Re-triangulating
# 2023-07-26 20:50:28,715 DEBUG: Ceres Solver Report: Iterations: 5, Initial cost: 3.923417e+02, Final cost: 3.829752e+02, Termination: CONVERGENCE
# 2023-07-26 20:50:29,586 DEBUG: Ceres Solver Report: Iterations: 6, Initial cost: 4.031615e+02, Final cost: 3.967323e+02, Termination: CONVERGENCE
# 2023-07-26 20:50:29,618 INFO: Removed outliers: 2
# 2023-07-26 20:50:29,620 INFO: -------------------------------------------------------
# 2023-07-26 20:50:29,630 INFO: Dumbell12.jpg resection inliers: 80 / 121
# 2023-07-26 20:50:29,634 DEBUG: Ceres Solver Report: Iterations: 4, Initial cost: 8.818845e+01, Final cost: 8.660920e+01, Termination: CONVERGENCE
# 2023-07-26 20:50:29,634 INFO: Adding Dumbell12.jpg to the reconstruction
# 2023-07-26 20:50:29,674 DEBUG: Local bundle sets: interior 12  boundary 0  other 0
# 2023-07-26 20:50:29,995 DEBUG: Ceres Solver Report: Iterations: 5, Initial cost: 3.434033e+02, Final cost: 3.349600e+02, Termination: CONVERGENCE
# 2023-07-26 20:50:30,021 INFO: Removed outliers: 0
# 2023-07-26 20:50:30,023 INFO: -------------------------------------------------------
# 2023-07-26 20:50:30,031 INFO: Dumbell3.jpg resection inliers: 86 / 115
# 2023-07-26 20:50:30,036 DEBUG: Ceres Solver Report: Iterations: 5, Initial cost: 1.990721e+01, Final cost: 1.750740e+01, Termination: CONVERGENCE
# 2023-07-26 20:50:30,036 INFO: Adding Dumbell3.jpg to the reconstruction
# 2023-07-26 20:50:30,089 DEBUG: Local bundle sets: interior 13  boundary 0  other 0
# 2023-07-26 20:50:30,580 DEBUG: Ceres Solver Report: Iterations: 11, Initial cost: 4.129461e+02, Final cost: 3.634999e+02, Termination: NO_CONVERGENCE
# 2023-07-26 20:50:30,607 INFO: Removed outliers: 2
# 2023-07-26 20:50:30,609 INFO: -------------------------------------------------------
# 2023-07-26 20:50:30,614 INFO: Dumbell1.jpg resection inliers: 91 / 112
# 2023-07-26 20:50:30,619 DEBUG: Ceres Solver Report: Iterations: 4, Initial cost: 1.544889e+01, Final cost: 1.391104e+01, Termination: CONVERGENCE
# 2023-07-26 20:50:30,619 INFO: Adding Dumbell1.jpg to the reconstruction
# 2023-07-26 20:50:30,658 DEBUG: Local bundle sets: interior 14  boundary 0  other 0
# 2023-07-26 20:50:31,039 DEBUG: Ceres Solver Report: Iterations: 6, Initial cost: 3.937707e+02, Final cost: 3.836943e+02, Termination: CONVERGENCE
# 2023-07-26 20:50:31,067 INFO: Removed outliers: 0
# 2023-07-26 20:50:31,069 INFO: -------------------------------------------------------
# 2023-07-26 20:50:31,077 INFO: Dumbell10.jpg resection inliers: 94 / 107
# 2023-07-26 20:50:31,082 DEBUG: Ceres Solver Report: Iterations: 5, Initial cost: 8.871751e+01, Final cost: 8.683878e+01, Termination: CONVERGENCE
# 2023-07-26 20:50:31,082 INFO: Adding Dumbell10.jpg to the reconstruction
# 2023-07-26 20:50:31,124 INFO: Re-triangulating
# 2023-07-26 20:50:31,906 DEBUG: Ceres Solver Report: Iterations: 7, Initial cost: 5.193650e+02, Final cost: 4.990855e+02, Termination: CONVERGENCE
# 2023-07-26 20:50:33,013 DEBUG: Ceres Solver Report: Iterations: 6, Initial cost: 6.177800e+02, Final cost: 5.400120e+02, Termination: CONVERGENCE
# 2023-07-26 20:50:33,048 INFO: Removed outliers: 2
# 2023-07-26 20:50:33,051 INFO: -------------------------------------------------------
# 2023-07-26 20:50:33,057 INFO: Dumbell2.jpg resection inliers: 48 / 68
# 2023-07-26 20:50:33,060 DEBUG: Ceres Solver Report: Iterations: 4, Initial cost: 3.642949e+01, Final cost: 3.585055e+01, Termination: CONVERGENCE
# 2023-07-26 20:50:33,061 INFO: Adding Dumbell2.jpg to the reconstruction
# 2023-07-26 20:50:33,101 DEBUG: Local bundle sets: interior 16  boundary 0  other 0
# 2023-07-26 20:50:33,468 DEBUG: Ceres Solver Report: Iterations: 4, Initial cost: 4.626467e+02, Final cost: 4.512457e+02, Termination: CONVERGENCE
# 2023-07-26 20:50:33,500 INFO: Removed outliers: 0
# 2023-07-26 20:50:33,502 INFO: -------------------------------------------------------
# 2023-07-26 20:50:33,513 INFO: IMG_4794.jpg resection inliers: 10 / 15
# 2023-07-26 20:50:33,515 DEBUG: Ceres Solver Report: Iterations: 4, Initial cost: 7.932144e+01, Final cost: 7.912050e+01, Termination: CONVERGENCE
# 2023-07-26 20:50:33,515 INFO: Adding IMG_4794.jpg to the reconstruction
# 2023-07-26 20:50:33,534 DEBUG: Local bundle sets: interior 8  boundary 9  other 0
# 2023-07-26 20:50:33,778 DEBUG: Ceres Solver Report: Iterations: 4, Initial cost: 3.430836e+02, Final cost: 3.426801e+02, Termination: CONVERGENCE
# 2023-07-26 20:50:33,799 INFO: Removed outliers: 0
# 2023-07-26 20:50:33,801 INFO: -------------------------------------------------------
# 2023-07-26 20:50:33,813 INFO: IMG_4792.jpg resection inliers: 9 / 12
# 2023-07-26 20:50:33,823 INFO: Dumbell11.jpg resection inliers: 7 / 9
# 2023-07-26 20:50:33,832 INFO: Some images can not be added
# 2023-07-26 20:50:33,832 INFO: -------------------------------------------------------
# 2023-07-26 20:50:34,442 DEBUG: Ceres Solver Report: Iterations: 4, Initial cost: 5.637715e+02, Final cost: 5.630328e+02, Termination: CONVERGENCE
# 2023-07-26 20:50:34,477 INFO: Removed outliers: 0
# 2023-07-26 20:50:34,544 INFO: {'points_count': 4898, 'cameras_count': 17, 'observations_count': 12293, 'average_track_length': 2.509799918334014, 'average_track_length_notwo': 6.942090395480226}
# 2023-07-26 20:50:34,544 INFO: Starting reconstruction with IMG_4800.jpg and IMG_4801.jpg
# 2023-07-26 20:50:34,567 INFO: Two-view reconstruction inliers: 483 / 491
# 2023-07-26 20:50:34,603 INFO: Triangulated: 417
# 2023-07-26 20:50:34,612 DEBUG: Ceres Solver Report: Iterations: 4, Initial cost: 1.851867e+01, Final cost: 1.750970e+01, Termination: CONVERGENCE
# 2023-07-26 20:50:34,661 DEBUG: Ceres Solver Report: Iterations: 3, Initial cost: 1.761596e+01, Final cost: 1.725134e+01, Termination: CONVERGENCE
# 2023-07-26 20:50:35,089 DEBUG: Ceres Solver Report: Iterations: 101, Initial cost: 4.866305e+01, Final cost: 4.257589e+01, Termination: NO_CONVERGENCE
# 2023-07-26 20:50:35,092 INFO: Removed outliers: 0
# 2023-07-26 20:50:35,092 INFO: -------------------------------------------------------
# 2023-07-26 20:50:35,139 INFO: IMG_4799.jpg resection inliers: 7 / 12
# 2023-07-26 20:50:35,147 INFO: Some images can not be added
# 2023-07-26 20:50:35,147 INFO: -------------------------------------------------------
# 2023-07-26 20:50:35,389 DEBUG: Ceres Solver Report: Iterations: 55, Initial cost: 4.257589e+01, Final cost: 3.409837e+01, Termination: CONVERGENCE
# 2023-07-26 20:50:35,391 INFO: Removed outliers: 0
# 2023-07-26 20:50:35,397 INFO: {'points_count': 416, 'cameras_count': 2, 'observations_count': 832, 'average_track_length': 2.0, 'average_track_length_notwo': -1}
# 2023-07-26 20:50:35,397 INFO: Starting reconstruction with IMG_4787.jpg and IMG_4788.jpg
# 2023-07-26 20:50:35,431 INFO: Two-view reconstruction inliers: 304 / 305
# 2023-07-26 20:50:35,453 INFO: Triangulated: 304
# 2023-07-26 20:50:35,459 DEBUG: Ceres Solver Report: Iterations: 3, Initial cost: 4.066793e+00, Final cost: 3.756976e+00, Termination: CONVERGENCE
# 2023-07-26 20:50:35,490 DEBUG: Ceres Solver Report: Iterations: 3, Initial cost: 3.831533e+00, Final cost: 3.749778e+00, Termination: CONVERGENCE
# 2023-07-26 20:50:35,539 DEBUG: Ceres Solver Report: Iterations: 9, Initial cost: 1.498710e+01, Final cost: 1.128512e+01, Termination: CONVERGENCE
# 2023-07-26 20:50:35,541 INFO: Removed outliers: 0
# 2023-07-26 20:50:35,542 INFO: -------------------------------------------------------
# 2023-07-26 20:50:35,551 INFO: IMG_4786.jpg resection inliers: 9 / 10
# 2023-07-26 20:50:35,555 INFO: IMG_4789.jpg resection inliers: 9 / 9
# 2023-07-26 20:50:35,562 INFO: Some images can not be added
# 2023-07-26 20:50:35,562 INFO: -------------------------------------------------------
# 2023-07-26 20:50:35,608 DEBUG: Ceres Solver Report: Iterations: 8, Initial cost: 1.431948e+01, Final cost: 1.128512e+01, Termination: CONVERGENCE
# 2023-07-26 20:50:35,610 INFO: Removed outliers: 0
# 2023-07-26 20:50:35,615 INFO: {'points_count': 304, 'cameras_count': 2, 'observations_count': 608, 'average_track_length': 2.0, 'average_track_length_notwo': -1}
# 2023-07-26 20:50:35,615 INFO: Starting reconstruction with IMG_4792.jpg and IMG_4793.jpg
# 2023-07-26 20:50:35,628 INFO: Two-view reconstruction inliers: 229 / 231
# 2023-07-26 20:50:35,652 INFO: Triangulated: 230
# 2023-07-26 20:50:35,658 DEBUG: Ceres Solver Report: Iterations: 3, Initial cost: 2.844670e+00, Final cost: 2.497564e+00, Termination: CONVERGENCE
# 2023-07-26 20:50:35,689 DEBUG: Ceres Solver Report: Iterations: 3, Initial cost: 2.573276e+00, Final cost: 2.470463e+00, Termination: CONVERGENCE
# 2023-07-26 20:50:35,719 DEBUG: Ceres Solver Report: Iterations: 6, Initial cost: 1.258329e+01, Final cost: 8.546647e+00, Termination: CONVERGENCE
# 2023-07-26 20:50:35,721 INFO: Removed outliers: 0
# 2023-07-26 20:50:35,722 INFO: -------------------------------------------------------
# 2023-07-26 20:50:35,727 INFO: IMG_4791.jpg resection inliers: 21 / 21
# 2023-07-26 20:50:35,729 DEBUG: Ceres Solver Report: Iterations: 5, Initial cost: 2.630975e+00, Final cost: 2.199699e+00, Termination: CONVERGENCE
# 2023-07-26 20:50:35,729 INFO: Adding IMG_4791.jpg to the reconstruction
# 2023-07-26 20:50:35,747 INFO: Re-triangulating
# 2023-07-26 20:50:35,821 DEBUG: Ceres Solver Report: Iterations: 10, Initial cost: 3.110596e+01, Final cost: 2.311179e+01, Termination: CONVERGENCE
# 2023-07-26 20:50:35,919 DEBUG: Ceres Solver Report: Iterations: 10, Initial cost: 2.362307e+01, Final cost: 2.311179e+01, Termination: CONVERGENCE
# 2023-07-26 20:50:35,921 INFO: Removed outliers: 2
# 2023-07-26 20:50:35,921 INFO: -------------------------------------------------------
# 2023-07-26 20:50:35,927 INFO: IMG_4790.jpg resection inliers: 5 / 7
# 2023-07-26 20:50:35,931 INFO: Some images can not be added
# 2023-07-26 20:50:35,932 INFO: -------------------------------------------------------
# 2023-07-26 20:50:35,985 DEBUG: Ceres Solver Report: Iterations: 6, Initial cost: 2.379259e+01, Final cost: 2.040002e+01, Termination: CONVERGENCE
# 2023-07-26 20:50:35,989 INFO: Removed outliers: 0
# 2023-07-26 20:50:35,996 INFO: {'points_count': 423, 'cameras_count': 3, 'observations_count': 867, 'average_track_length': 2.049645390070922, 'average_track_length_notwo': 3.0}
# 2023-07-26 20:50:35,996 INFO: Starting reconstruction with Dumbell7.jpg and IMG_4786.jpg
# 2023-07-26 20:50:36,009 INFO: Two-view reconstruction inliers: 64 / 64
# 2023-07-26 20:50:36,015 INFO: Triangulated: 62
# 2023-07-26 20:50:36,017 DEBUG: Ceres Solver Report: Iterations: 3, Initial cost: 4.614694e-01, Final cost: 4.251575e-01, Termination: CONVERGENCE
# 2023-07-26 20:50:36,027 DEBUG: Ceres Solver Report: Iterations: 3, Initial cost: 4.313155e-01, Final cost: 4.139628e-01, Termination: CONVERGENCE
# 2023-07-26 20:50:36,039 DEBUG: Ceres Solver Report: Iterations: 8, Initial cost: 1.069565e+01, Final cost: 6.468955e+00, Termination: CONVERGENCE
# 2023-07-26 20:50:36,040 INFO: Removed outliers: 0
# 2023-07-26 20:50:36,040 INFO: -------------------------------------------------------
# 2023-07-26 20:50:36,045 INFO: Some images can not be added
# 2023-07-26 20:50:36,045 INFO: -------------------------------------------------------
# 2023-07-26 20:50:36,056 DEBUG: Ceres Solver Report: Iterations: 8, Initial cost: 1.059122e+01, Final cost: 6.468955e+00, Termination: CONVERGENCE
# 2023-07-26 20:50:36,057 INFO: Removed outliers: 0
# 2023-07-26 20:50:36,058 INFO: {'points_count': 62, 'cameras_count': 2, 'observations_count': 124, 'average_track_length': 2.0, 'average_track_length_notwo': -1}
# 2023-07-26 20:50:36,058 INFO: Starting reconstruction with Dumbell11.jpg and Dumbell4.jpg
# 2023-07-26 20:50:36,080 INFO: Two-view reconstruction inliers: 63 / 63
# 2023-07-26 20:50:36,087 INFO: Triangulated: 63
# 2023-07-26 20:50:36,089 DEBUG: Ceres Solver Report: Iterations: 3, Initial cost: 5.547280e-01, Final cost: 5.305783e-01, Termination: CONVERGENCE
# 2023-07-26 20:50:36,098 DEBUG: Ceres Solver Report: Iterations: 3, Initial cost: 5.357024e-01, Final cost: 5.258603e-01, Termination: CONVERGENCE
# 2023-07-26 20:50:36,111 DEBUG: Ceres Solver Report: Iterations: 8, Initial cost: 1.141014e+01, Final cost: 6.920933e+00, Termination: CONVERGENCE
# 2023-07-26 20:50:36,111 INFO: Removed outliers: 0
# 2023-07-26 20:50:36,112 INFO: -------------------------------------------------------
# 2023-07-26 20:50:36,116 INFO: Some images can not be added
# 2023-07-26 20:50:36,116 INFO: -------------------------------------------------------
# 2023-07-26 20:50:36,128 DEBUG: Ceres Solver Report: Iterations: 8, Initial cost: 1.135206e+01, Final cost: 6.920934e+00, Termination: CONVERGENCE
# 2023-07-26 20:50:36,129 INFO: Removed outliers: 0
# 2023-07-26 20:50:36,130 INFO: {'points_count': 63, 'cameras_count': 2, 'observations_count': 126, 'average_track_length': 2.0, 'average_track_length_notwo': -1}
# 2023-07-26 20:50:36,130 INFO: Reconstruction 0: 17 images, 4898 points
# 2023-07-26 20:50:36,130 INFO: Reconstruction 1: 3 images, 423 points
# 2023-07-26 20:50:36,130 INFO: Reconstruction 2: 2 images, 416 points
# 2023-07-26 20:50:36,130 INFO: Reconstruction 3: 2 images, 304 points
# 2023-07-26 20:50:36,130 INFO: Reconstruction 4: 2 images, 62 points
# 2023-07-26 20:50:36,130 INFO: Reconstruction 5: 2 images, 63 points
# 2023-07-26 20:50:36,130 INFO: 6 partial reconstructions in total.

# %%
def get_colors_from_ply(plyfile):
    '''
    Function to read the colors from a .ply file
    returns an RGB array scaled between [0,1]
    '''
    with open(plyfile, 'r') as f:
        colors = []
        columns = {}
        col_idx = 0
        header_done = False
        for line in f.readlines():
            if line.startswith('property'):
                columns[line.split()[-1]] = col_idx
                col_idx += 1
            if header_done:
                line_list = line.split()
                colors.append([float(line_list[columns['diffuse_red']]),
                              float(line_list[columns['diffuse_green']]),
                              float(line_list[columns['diffuse_blue']])
                              ])
            if line.startswith('end_header'):
                header_done = True
        colors = np.array(colors)/255
    return colors

# %%
# read point cloud data
pcd = o3d.io.read_point_cloud("dumbell/reconstruction.ply", format='ply')
# store the colors
pcd.colors = o3d.utility.Vector3dVector(get_colors_from_ply('dumbell/reconstruction.ply'))

# convert to array
points = np.asarray(pcd.points)
colors = np.asarray(pcd.colors)

fig = go.Figure(
    data=[
        go.Scatter3d(
            x=points[:,0], y=points[:,1], z=points[:,2], 
            mode='markers',
            marker=dict(size=5, color=colors)
        )
    ],
    layout=dict(
        scene=dict(
            xaxis=dict(visible=False),
            yaxis=dict(visible=False),
            zaxis=dict(visible=False)
        )
    )
)
fig.write_html('vis-sparse.html')

# %% [markdown]
# OpenSfM has various functions to refine the 3d reconstruction.
# See https://opensfm.readthedocs.io/en/latest/using.html for more details.
#
# We will be using the `undistort` and `compute_depthmaps` functions to create a dense reconstruction of the scene

# %%
# !opensfm undistort dumbell/
# Out:
# 2023-07-26 20:52:50,157 DEBUG: Undistorting the reconstruction
# 2023-07-26 20:52:50,417 DEBUG: Undistorting image IMG_4782.jpg
# 2023-07-26 20:52:50,512 DEBUG: Undistorting image IMG_4783.jpg
# 2023-07-26 20:52:50,605 DEBUG: Undistorting image IMG_4784.jpg
# 2023-07-26 20:52:50,699 DEBUG: Undistorting image Dumbell5.jpg
# 2023-07-26 20:52:53,723 DEBUG: Undistorting image IMG_4780.jpg
# 2023-07-26 20:52:53,820 DEBUG: Undistorting image IMG_4781.jpg
# 2023-07-26 20:52:53,913 DEBUG: Undistorting image IMG_4785.jpg
# 2023-07-26 20:52:54,007 DEBUG: Undistorting image IMG_4778.jpg
# 2023-07-26 20:52:54,097 DEBUG: Undistorting image IMG_4779.jpg
# 2023-07-26 20:52:54,189 DEBUG: Undistorting image Dumbell13.jpg
# 2023-07-26 20:52:54,278 DEBUG: Undistorting image IMG_4776.jpg
# 2023-07-26 20:52:54,369 DEBUG: Undistorting image Dumbell12.jpg
# 2023-07-26 20:52:54,464 DEBUG: Undistorting image Dumbell3.jpg
# 2023-07-26 20:52:57,274 DEBUG: Undistorting image Dumbell1.jpg
# 2023-07-26 20:52:59,995 DEBUG: Undistorting image Dumbell10.jpg
# 2023-07-26 20:53:00,086 DEBUG: Undistorting image Dumbell2.jpg
# 2023-07-26 20:53:02,801 DEBUG: Undistorting image IMG_4794.jpg

# %%
# !opensfm compute_depthmaps dumbell/
# Out:
# 2023-07-26 20:53:05,249 INFO: Computing neighbors
# 2023-07-26 20:53:05,684 INFO: Using precomputed raw depthmap IMG_4782.jpg
# 2023-07-26 20:53:05,684 INFO: Using precomputed raw depthmap IMG_4783.jpg
# 2023-07-26 20:53:05,684 INFO: Using precomputed raw depthmap IMG_4784.jpg
# 2023-07-26 20:53:05,684 INFO: Computing depthmap for image Dumbell5.jpg with PATCH_MATCH_SAMPLE
# 2023-07-26 20:53:38,880 INFO: Computing depthmap for image IMG_4780.jpg with PATCH_MATCH_SAMPLE
# 2023-07-26 20:54:11,475 INFO: Computing depthmap for image IMG_4781.jpg with PATCH_MATCH_SAMPLE
# 2023-07-26 20:54:43,984 INFO: Computing depthmap for image IMG_4785.jpg with PATCH_MATCH_SAMPLE
# 2023-07-26 20:55:16,522 INFO: Computing depthmap for image IMG_4778.jpg with PATCH_MATCH_SAMPLE
# 2023-07-26 20:55:48,451 INFO: Computing depthmap for image IMG_4779.jpg with PATCH_MATCH_SAMPLE
# 2023-07-26 20:56:20,787 INFO: Computing depthmap for image Dumbell13.jpg with PATCH_MATCH_SAMPLE
# 2023-07-26 20:56:49,307 INFO: Computing depthmap for image IMG_4776.jpg with PATCH_MATCH_SAMPLE
# 2023-07-26 20:57:21,906 INFO: Using precomputed raw depthmap Dumbell12.jpg
# 2023-07-26 20:57:21,906 INFO: Computing depthmap for image Dumbell3.jpg with PATCH_MATCH_SAMPLE
# 2023-07-26 20:57:54,471 INFO: Computing depthmap for image Dumbell1.jpg with PATCH_MATCH_SAMPLE
# 2023-07-26 20:58:23,538 INFO: Computing depthmap for image Dumbell10.jpg with PATCH_MATCH_SAMPLE
# 2023-07-26 20:58:55,444 INFO: Using precomputed raw depthmap Dumbell2.jpg
# 2023-07-26 20:58:55,444 INFO: Computing depthmap for image IMG_4794.jpg with PATCH_MATCH_SAMPLE
# 2023-07-26 20:59:23,667 INFO: Cleaning depthmap for image IMG_4782.jpg
# 2023-07-26 20:59:27,453 INFO: Cleaning depthmap for image IMG_4783.jpg
# 2023-07-26 20:59:31,262 INFO: Cleaning depthmap for image IMG_4784.jpg
# 2023-07-26 20:59:34,962 INFO: Cleaning depthmap for image Dumbell5.jpg
# 2023-07-26 20:59:39,133 INFO: Cleaning depthmap for image IMG_4780.jpg
# 2023-07-26 20:59:42,803 INFO: Cleaning depthmap for image IMG_4781.jpg
# 2023-07-26 20:59:46,238 INFO: Cleaning depthmap for image IMG_4785.jpg
# 2023-07-26 20:59:49,778 INFO: Cleaning depthmap for image IMG_4778.jpg
# 2023-07-26 20:59:53,028 INFO: Cleaning depthmap for image IMG_4779.jpg
# 2023-07-26 20:59:56,311 INFO: Cleaning depthmap for image Dumbell13.jpg
# 2023-07-26 20:59:58,617 INFO: Cleaning depthmap for image IMG_4776.jpg
# 2023-07-26 21:00:01,704 INFO: Using precomputed clean depthmap Dumbell12.jpg
# 2023-07-26 21:00:01,704 INFO: Cleaning depthmap for image Dumbell3.jpg
# 2023-07-26 21:00:04,822 INFO: Cleaning depthmap for image Dumbell1.jpg
# 2023-07-26 21:00:07,369 INFO: Cleaning depthmap for image Dumbell10.jpg
# 2023-07-26 21:00:10,220 INFO: Using precomputed clean depthmap Dumbell2.jpg
# 2023-07-26 21:00:10,220 INFO: Cleaning depthmap for image IMG_4794.jpg
# 2023-07-26 21:00:12,054 INFO: Pruning depthmap for image IMG_4782.jpg
# 2023-07-26 21:00:14,013 INFO: Pruning depthmap for image IMG_4783.jpg
# 2023-07-26 21:00:16,191 INFO: Pruning depthmap for image IMG_4784.jpg
# 2023-07-26 21:00:17,906 INFO: Pruning depthmap for image Dumbell5.jpg
# 2023-07-26 21:00:20,858 INFO: Pruning depthmap for image IMG_4780.jpg
# 2023-07-26 21:00:22,438 INFO: Pruning depthmap for image IMG_4781.jpg
# 2023-07-26 21:00:24,017 INFO: Pruning depthmap for image IMG_4785.jpg
# 2023-07-26 21:00:25,570 INFO: Pruning depthmap for image IMG_4778.jpg
# 2023-07-26 21:00:26,980 INFO: Pruning depthmap for image IMG_4779.jpg
# 2023-07-26 21:00:28,849 INFO: Pruning depthmap for image Dumbell13.jpg
# 2023-07-26 21:00:29,745 INFO: Pruning depthmap for image IMG_4776.jpg
# 2023-07-26 21:00:31,738 INFO: Using precomputed pruned depthmap Dumbell12.jpg
# 2023-07-26 21:00:31,738 INFO: Pruning depthmap for image Dumbell3.jpg
# 2023-07-26 21:00:33,076 INFO: Pruning depthmap for image Dumbell1.jpg
# 2023-07-26 21:00:34,214 INFO: Pruning depthmap for image Dumbell10.jpg
# 2023-07-26 21:00:35,121 INFO: Using precomputed pruned depthmap Dumbell2.jpg
# 2023-07-26 21:00:35,122 INFO: Pruning depthmap for image IMG_4794.jpg
# 2023-07-26 21:00:36,110 INFO: Merging depthmaps

# %%
pcd_dense = o3d.io.read_point_cloud('dumbell/undistorted/depthmaps/merged.ply', format='ply')
pcd_dense.colors = o3d.utility.Vector3dVector(get_colors_from_ply("dumbell/undistorted/depthmaps/merged.ply"))
points_dense = np.asarray(pcd_dense.points)
colors_dense = np.asarray(pcd_dense.colors)

fig = go.Figure(
    data=[
        go.Scatter3d(
            x=points_dense[:,0], y=points_dense[:,1], z=points_dense[:,2], 
            mode='markers',
            marker=dict(size=1, color=colors_dense)
        )
    ],
    layout=dict(
        scene=dict(
            xaxis=dict(visible=False),
            yaxis=dict(visible=False),
            zaxis=dict(visible=False)
        )
    )
)
fig.write_html('vis-dense.html')

# %% [markdown]
# ### Exercise
# We will now let you try out 3D reconstruction for yourself using OpenSfM! First, we need to make sure you have the proper file structure to make this work. Create a directory called "workspace/" (or whatever else you want). In that directory, create a directory called "images/". From the kitchen_example/ directory, copy "config.yaml" and paste it in workspace/. Take two or more images of your work space and upload them to workspace/images. Now run the commands above to reconstruct the scene and visualize it. Is the reconstruction accurate? What about your scene might make it difficult for the reconstruction to work well?
#
# Go to workspace/reports and examine the files there. They will give you a sense of how many features were extracted, how many features were matched, and whether some reconstructions are only partial. Do you have multiple partial reconstructions or one larger reconstruction? If you have partial reconstructions, why do you think that is?

# %% [markdown]
# # Additional resources:
# This technique is one of the methods used in [photogrammetry](https://en.wikipedia.org/wiki/Photogrammetry), which is used to construct 3D representations of physical objects and locations using photographs and video.
#
# Here are some links to photogrammetry software, tools, and information:
#
# **Free**:
# - [OpenDroneMap](https://www.opendronemap.org/)
# - [COLMAP](https://colmap.github.io/index.html)
# - [Meshroom](https://alicevision.org/#meshroom)
# - [MicMac](https://micmac.ensg.eu/index.php/Accueil)
# - [OpenMVG](https://github.com/openMVG/openMVG)
#
# **Paid**:
# - [Pix4D](https://www.pix4d.com/)
# - [3DF Zephyr](https://www.3dflow.net/3df-zephyr-photogrammetry-software/)
# - [Agisoft Metascape](https://www.agisoft.com/)
# - [Autodesk ReCap](https://www.autodesk.com/products/recap/overview)
